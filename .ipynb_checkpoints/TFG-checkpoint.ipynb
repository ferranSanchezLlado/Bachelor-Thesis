# %% [markdown]
# # TFG hateval2019

# %%
# some imports
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Python ≥3.6 is required
import sys
assert sys.version_info >= (3, 6)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
import random

seed_val = 42
np.random.seed(seed_val)
random.seed(seed_val)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.rc('font', size=12) 
plt.rc('figure', figsize = (12, 5))

# Settings for the visualizations
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

import pandas as pd
pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 50)


from nltk.corpus import stopwords
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# <style>.container { width:100% !important; }</style>

# %%
english_train = pd.read_csv('./hateval2019/hateval2019_en_train.csv',index_col=0)
english_dev = pd.read_csv('./hateval2019/hateval2019_en_dev.csv',index_col=0)
english_test = pd.read_csv('./hateval2019/hateval2019_en_test.csv',index_col=0)

spanish_train = pd.read_csv('./hateval2019/hateval2019_es_train.csv',index_col=0)
spanish_dev = pd.read_csv('./hateval2019/hateval2019_es_dev.csv',index_col=0)
spanish_test = pd.read_csv('./hateval2019/hateval2019_es_test.csv',index_col=0)

# %%
print(english_train.shape, english_dev.shape, english_test.shape)
print(spanish_train.shape, spanish_dev.shape, spanish_test.shape)
# Out:
# (9000, 4) (1000, 4) (3000, 4)
# (4500, 4) (500, 4) (1600, 4)

# %%
print(english_test.head())
print(spanish_train.head())
# Out:
#                                                     text  HS  TR  AG
# id
# 34243  @local1025 @njdotcom @GovMurphy Oh, I could ha...   0   0   0
# 30593  Several of the wild fires in #california and #...   0   0   0
# 31427  @JudicialWatch My question is how do you reset...   0   0   0
# 31694  #Europe, you've got a problem!   We must hurry...   1   0   0
# 31865  This is outrageous! #StopIllegalImmigration  #...   1   0   0
#                                                     text  HS  TR  AG
# id
# 20001  Easyjet quiere duplicar el número de mujeres p...   1   0   0
# 20002  El gobierno debe crear un control estricto de ...   1   0   0
# 20003  Yo veo a mujeres destruidas por acoso laboral ...   0   0   0
# 20004  — Yo soy respetuoso con los demás, sólamente l...   0   0   0
# 20007  Antonio Caballero y como ser de mal gusto e ig...   0   0   0

# %% [markdown]
# ## Basic statistical analysis

# %%
def plot_top_barchart(text, just_stopwords=True, k=10):
    """Plots a barchart of the `k` most common words in a corpus. 
    Depending on the option `just_stopwords` it will count the stopwords
    or the rest.
    """
    stop = set(stopwords.words('english'))
    
    new = text.str.split().values.tolist()
    corpus = [word for i in new for word in i]

    counter = Counter(corpus)
    most = counter.most_common()
    x, y = [], []
    for word,count in most:
        if len(x) >= k:
            break
        if just_stopwords ^ (word not in stop):
            x.append(word)
            y.append(count)
            
    sns.barplot(x=y,y=x)
    
def plot_top_ngrams_barchart(text, n=2, k=10):
    """Plots a barchart of the `k` most common n-grams words in a corpus. 
    """
    new = text.str.split().values.tolist()
    corpus = [word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
        words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:k]

    top_n_bigrams = _get_top_ngram(text,n)[:k]
    x,y = map(list,zip(*top_n_bigrams))
    sns.barplot(x=y,y=x)
    
    
def print_distribution_features(data):
    """Prints feature distribution of the dataset hateval2019.
    TR and AG are always dependent on HS being `True`. As checked on the last line.
    """
    print("Distribution of features:")
    print(f"HS: {100 * np.sum(data['HS'] == True) / data.shape[0]}%")
    print(f"HS -> TR: {100 * np.sum((data['HS'] == True) & (data['TR'] == True)) / np.sum(data['HS'] == True)}%")
    print(f"HS -> AG: {100 * np.sum((data['HS'] == True) & (data['AG'] == True)) / np.sum(data['HS'] == True)}%")
    print(f"HS -> TR & AG: {100 * np.sum((data['HS'] == True) & (data['TR'] == True) & (data['AG'] == True)) / np.sum(data['HS'] == True)}%")
    print(f"!HS & (TR | AG): {100 * np.sum((data['HS'] == False) & ((data['TR'] == True) | (data['AG'] == True))) / data.shape[0]}%")


def _aux_print_distribution_search_pattern(data, pattern, k=10):
    """Auxiliar method that prints the information related to a specific search.
    Such as the mentions of this pattern in each tweet, the number of unique mentions,
    the `k` most common words that fulfill the pattern.
    
    `pattern` has to be a regex to be searched and `data` has to be from the hateval2019
    dataset.
    """
    data_text = data["text"].str.findall(pattern)
    n_data = data_text.map(lambda x: len(x))
    print(f"Number of mentions per tweet (MIN, MEAN, MAX): ({n_data.min()}, {n_data.mean()}, {n_data.max()})")
    n_data_users = data_text.map(lambda x: len(x) > 0)
    print(f"Number of tweets that contain a mention: {n_data_users.mean()}")
    
    print("Most Common mentions:")
    data_1d = data_text.explode()
    most_common_data = pd.DataFrame({"Mention": data_1d.value_counts()[:k].index, "Count": data_1d.value_counts()[:k].values}).set_index("Mention")
    
    for feature in ["HS", "TR", "AG"]: # Calculates percentage the ratio of all features of the tweets that mention the data.
        most_common_data[feature] = most_common_data.index.map(lambda mention: np.mean(data.loc[data_1d[data_1d == mention].index][feature]))
    for feature in ["TR", "AG"]: # Changes the percentage of the two other features to represent if HS is True what is the percentage ratio.
        # Avoids divistion by zero, by letting be zero. As checked it will always be 0/0, so we can ignore it.
        most_common_data[feature] = np.divide(most_common_data[feature], most_common_data["HS"], out=np.zeros(most_common_data.shape[0]), where=most_common_data["HS"]!=0)
        most_common_data.rename(columns={feature:f"HS -> {feature}"}, inplace=True)

    print(most_common_data) 
    return most_common_data
    

def print_twitter_information(data):
    """Prints information related with twitter features: mentions to users and hashtags.
    Also prints the most common links.
    (trening topics).
    """
    print("\nUsers:")
    _aux_print_distribution_search_pattern(data, r"@\w*")
    
    print("\nHashtags:")
    _aux_print_distribution_search_pattern(data, r"#\w*")
    
    print("\nLinks:")
    _aux_print_distribution_search_pattern(data, r"https?\S*")
    
    print("\nNon-ascii:")
    _aux_print_distribution_search_pattern(data, r"[^\x00-\x7F]")
    
def print_tweet_characteristics(data):
    """Prints general information about the string corpus.
    """
    print("\nTweets: (MIN, MEAN, MAX)")
    n_characters = data["text"].str.len()
    print(f"Number of characters: ({n_characters.min()}, {n_characters.mean()}, {n_characters.max()})")
    n_words = data["text"].str.split().map(lambda x: len(x))
    print(f"Mean of Number of words: ({n_words.min()}, {n_words.mean()}, {n_words.max()})")
    avg_word_lenght = data["text"].str.split().map(lambda x : np.mean([len(i) for i in x]))
    print(f"Mean of Avarage word lenght: ({avg_word_lenght.min()}, {avg_word_lenght.mean()}, {avg_word_lenght.max()})")
    
    plt.figure(1)
    plt.subplot(131)

    # Characters
    n_characters.hist()
    plt.title("Number of characters")
    plt.subplot(132)
    # Words
    n_words.hist()
    plt.title("Number of words")
    plt.subplot(133)
    # Mean Characters in Words
    avg_word_lenght.hist()
    plt.title("Avarage word lenght")
    plt.show()
    

def basic_statistics_plot(orig_data, HS=None, TR=None, AG=None):
    """Method that prints and plots basic information about the dataset.
    `HS`, `TR`, `AG` will allow to filter by specific values of the features.
    """
    true_array = np.ones(orig_data.shape[0], dtype=bool)
    
    data = orig_data.loc[(true_array if HS is None else orig_data["HS"] == HS) &
                (true_array if TR is None else orig_data["TR"] == TR) &
                (true_array if AG is None else orig_data["AG"] == AG)].copy()
    
    data["text"] = data["text"].apply(lambda x: x.lower())
    
    print_distribution_features(data) # Basic feature information
    print_twitter_information(data) # Unique characteristics of tweets (like users and hashtags)
    print_tweet_characteristics(data) # Basic text information

    # Most common words
    plt.figure(2)
    plt.subplot(121)
    plot_top_barchart(data["text"], just_stopwords=True)
    plt.title("Most common stopwords")
    plt.subplot(122)
    plot_top_barchart(data["text"], just_stopwords=False)
    plt.title("Most common non-stopwords")
    
    # Most common n-grams
    plt.figure(3)
    plt.subplot(121)
    plot_top_ngrams_barchart(data["text"], n=2)
    plt.title("Most common bigrams")
    plt.subplot(122)
    plot_top_ngrams_barchart(data["text"], n=3)
    plt.title("Most common trigrams")
    plt.show()

# %%
print("English:")
basic_statistics_plot(pd.concat([english_train, english_dev, english_test]))
# Out:
# English:
# Distribution of features:
# HS: 42.07692307692308%
# HS -> TR: 38.19012797074954%
# HS -> AG: 43.089579524680076%
# HS -> TR & AG: 13.875685557586838%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.7923846153846154, 42)
# Number of tweets that contain a mention: 0.4179230769230769
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @realdonaldtrump    549  0.553734  0.101974  0.608553
# @potus              189  0.566138  0.093458  0.579439
# @isupport_israel    105  0.580952  0.131148  0.442623
# @anncoulter         102  0.627451  0.843750  0.250000
# @youtube             71  0.309859  0.090909  0.454545
# @housegop            66  0.878788  0.034483  0.672414
# @foxnews             65  0.538462  0.200000  0.400000
# @                    60  0.416667  0.480000  0.400000
# @refugees            59  0.016949  0.000000  0.000000
# @realjameswoods      58  0.293103  0.235294  0.529412
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 1.0751538461538461, 27)
# Number of tweets that contain a mention: 0.31361538461538463
# Most Common mentions:
#                 Count        HS  HS -> TR  HS -> AG
# Mention
# #buildthatwall    871  0.594719  0.040541  0.666023
# #maga             630  0.549206  0.057803  0.627168
# #buildthewall     476  0.733193  0.057307  0.656160
# #nodaca           386  0.577720  0.035874  0.573991
# #trump            281  0.572954  0.043478  0.552795
# #deportthemall    265  0.883019  0.055556  0.705128
# #sendthemback     252  0.730159  0.016304  0.538043
# #illegalaliens    246  0.369919  0.021978  0.637363
# #noamnesty        218  0.738532  0.068323  0.689441
# #immigration      201  0.587065  0.042373  0.567797
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.42438461538461536, 4)
# Number of tweets that contain a mention: 0.37884615384615383
# Most Common mentions:
#                          Count        HS  HS -> TR  HS -> AG
# Mention
# https://t.co/qzfjsqwwj8     24  0.000000       0.0  0.000000
# http://t.co/6n4v9kbtya      19  0.263158       0.0  0.000000
# https://t.co/hccqmsq9vl     10  0.400000       0.0  0.250000
# https://t.co/91x12t4ljg      8  0.000000       0.0  0.000000
# https://t.co/sn5zuuu6nv      7  0.571429       0.0  0.500000
# https://t.co/c0ghvd6imb      4  0.750000       0.0  0.333333
# https://t.co/ersjopu1hw      4  0.750000       0.0  0.333333
# https://t.co/hu0pk06p0j      3  0.666667       0.0  1.000000
# http                         3  0.666667       0.0  0.000000
# https://t.co/9yaxwywws0      3  0.000000       0.0  0.000000
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.47584615384615386, 48)
# Number of tweets that contain a mention: 0.18715384615384614
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# ’         1049  0.354623  0.443548  0.298387
# 😂          504  0.521825  0.764259  0.216730
# …          470  0.291489  0.642336  0.299270
# “          340  0.332353  0.309735  0.318584
# ”          320  0.334375  0.317757  0.336449
# ÿ          203  0.458128  0.021505  0.365591
# ð          202  0.460396  0.021505  0.365591
# ‘          195  0.241026  0.148936  0.382979
# â          169  0.165680  0.035714  0.464286
# ️          116  0.474138  0.672727  0.272727
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (10, 141.56215384615385, 851)
# Mean of Number of words: (1, 21.619846153846154, 93)
# Mean of Avarage word lenght: (2.5, 5.836345554093726, 51.666666666666664)

# %%
print("Spanish:")
basic_statistics_plot(pd.concat([spanish_train, spanish_dev, spanish_test]))
# Out:
# Spanish:
# Distribution of features:
# HS: 41.5%
# HS -> TR: 61.66484118291347%
# HS -> AG: 78.56882073749544%
# HS -> TR & AG: 56.626506024096386%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.7271212121212122, 50)
# Number of tweets that contain a mention: 0.4637878787878788
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @barbijaputa        104  0.038462  0.750000  0.750000
# @sanchezcastejon     65  0.523077  0.088235  0.823529
# @guardiacivil        39  0.358974  0.142857  0.500000
# @elmundoes           28  0.428571  0.000000  0.583333
# @youtube             25  0.120000  1.000000  1.000000
# @anaisbernal         22  0.000000  0.000000  0.000000
# @zurine3             19  0.000000  0.000000  0.000000
# @interiorgob         17  0.470588  0.125000  0.500000
# @relatofeminista     17  0.176471  0.333333  0.333333
# @policia             17  0.470588  0.250000  0.875000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.19484848484848485, 22)
# Number of tweets that contain a mention: 0.10257575757575757
# Most Common mentions:
#                  Count        HS  HS -> TR  HS -> AG
# Mention
# #ceuta              40  0.150000       0.0  0.333333
# #otgala7            27  0.148148       1.0  0.750000
# #inmigrantes        19  0.105263       0.0  0.500000
# #inmigración        17  0.529412       0.0  1.000000
# #inmigracion        12  0.083333       0.0  0.000000
# #españa             12  0.500000       0.0  0.666667
# #eleccionesya       10  0.700000       0.0  0.285714
# #refugiados         10  0.200000       0.0  0.000000
# #indocumentados      9  0.000000       0.0  0.000000
# #arandina            7  0.000000       0.0  0.000000
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.3362121212121212, 4)
# Number of tweets that contain a mention: 0.31545454545454543
# Most Common mentions:
#                          Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/s7p45pnkxk      2  1.0       0.0       1.0
# https://t.co/s6ursjjugy      2  0.5       0.0       0.0
# https://t.co/eap7pkrma3      2  1.0       0.0       1.0
# https://t.co/wm7yeqgvxd      2  1.0       0.5       1.0
# https://t.co/cpexso5ai1      2  1.0       0.0       1.0
# https://t.co/47cdr1xuoy      2  0.0       0.0       0.0
# https://t.co/2pr0yptnca      2  1.0       0.0       1.0
# https://t.co/myqvt7kt8m      2  0.5       0.0       1.0
# https://t.co/4qgbnyklpo      2  0.0       0.0       0.0
# https://t.co/wl4iwqn2nx      1  0.0       0.0       0.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 2.101060606060606, 60)
# Number of tweets that contain a mention: 0.7410606060606061
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# á         2866  0.411026  0.515280  0.790323
# í         2269  0.362715  0.373026  0.715674
# ó         1826  0.319825  0.333904  0.654110
# ñ         1467  0.398091  0.380137  0.720890
# é         1226  0.340946  0.497608  0.729665
# ú          746  0.414209  0.686084  0.799353
# ¿          355  0.447887  0.283019  0.402516
# 😂          265  0.430189  0.885965  0.780702
# ü          242  0.272727  0.484848  0.696970
# ¡          198  0.444444  0.318182  0.727273
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (6, 130.32954545454547, 846)
# Mean of Number of words: (1, 21.29909090909091, 88)
# Mean of Avarage word lenght: (1.9090909090909092, 5.406306823839929, 18.0)

# %%
print("TRAIN:\n")
basic_statistics_plot(english_train)
print("\n\nTRAIN with HS:\n")
basic_statistics_plot(english_train, HS=True)
print("\n\nDEV:\n")
basic_statistics_plot(english_dev)
print("\n\nTEST:\n")
basic_statistics_plot(english_test)
# Out:
# TRAIN:
#
# Distribution of features:
# HS: 42.03333333333333%
# HS -> TR: 35.448057097541636%
# HS -> AG: 41.210679355009255%
# HS -> TR & AG: 12.344699973565953%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.6873333333333334, 20)
# Number of tweets that contain a mention: 0.3913333333333333
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @realdonaldtrump    281  0.758007  0.122066  0.586854
# @potus               93  0.860215  0.125000  0.562500
# @isupport_israel     92  0.597826  0.127273  0.436364
# @refugees            55  0.000000  0.000000  0.000000
# @youtube             53  0.339623  0.111111  0.500000
# @anncoulter          41  0.756098  0.741935  0.258065
# @mailonline          36  0.527778  0.105263  0.368421
# @tyrusmaina          35  0.000000  0.000000  0.000000
# @                    35  0.485714  0.470588  0.411765
# @housegop            32  0.906250  0.034483  0.655172
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.7606666666666667, 21)
# Number of tweets that contain a mention: 0.2597777777777778
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# #buildthatwall      373  1.000000  0.048257  0.672922
# #maga               246  0.894309  0.068182  0.645455
# #buildthewall       217  0.940092  0.078431  0.627451
# #immigration        147  0.585034  0.046512  0.616279
# #trump              145  0.751724  0.055046  0.596330
# #nodaca             132  1.000000  0.053030  0.696970
# #womensuck          123  0.967480  0.302521  0.151261
# #stoptheinvasion     99  0.696970  0.115942  0.623188
# #noamnesty           95  1.000000  0.094737  0.726316
# #sendthemback        78  0.820513  0.000000  0.515625
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.5356666666666666, 4)
# Number of tweets that contain a mention: 0.47633333333333333
# Most Common mentions:
#                          Count        HS  HS -> TR  HS -> AG
# Mention
# https://t.co/qzfjsqwwj8     22  0.000000       0.0  0.000000
# http://t.co/6n4v9kbtya      19  0.263158       0.0  0.000000
# https://t.co/hccqmsq9vl     10  0.400000       0.0  0.250000
# https://t.co/91x12t4ljg      7  0.000000       0.0  0.000000
# https://t.co/sn5zuuu6nv      6  0.666667       0.0  0.500000
# https://t.co/c0ghvd6imb      4  0.750000       0.0  0.333333
# https://t.co/7fgo8dfr2e      3  0.000000       0.0  0.000000
# https://t.co/ersjopu1hw      3  1.000000       0.0  0.333333
# https://                     3  0.333333       0.0  1.000000
# http                         3  0.666667       0.0  0.000000
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.5485555555555556, 48)
# Number of tweets that contain a mention: 0.2078888888888889
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# ’          968  0.367769  0.452247  0.297753
# …          348  0.318966  0.594595  0.270270
# “          318  0.336478  0.308411  0.336449
# ”          295  0.342373  0.316832  0.356436
# 😂          241  0.526971  0.685039  0.228346
# ÿ          182  0.478022  0.022989  0.390805
# ð          181  0.480663  0.022989  0.390805
# ‘          177  0.259887  0.152174  0.391304
# â          159  0.163522  0.038462  0.423077
# ️           78  0.576923  0.688889  0.288889
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (10, 140.0991111111111, 330)
# Mean of Number of words: (1, 21.342666666666666, 63)
# Mean of Avarage word lenght: (2.5, 5.870516094341512, 44.0)
# TRAIN with HS:
#
# Distribution of features:
# HS: 100.0%
# HS -> TR: 35.448057097541636%
# HS -> AG: 41.210679355009255%
# HS -> TR & AG: 12.344699973565953%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.7869415807560137, 20)
# Number of tweets that contain a mention: 0.4557229711868887
# Most Common mentions:
#                   Count   HS  HS -> TR  HS -> AG
# Mention
# @realdonaldtrump    213  1.0  0.122066  0.586854
# @potus               80  1.0  0.125000  0.562500
# @isupport_israel     55  1.0  0.127273  0.436364
# @anncoulter          31  1.0  0.741935  0.258065
# @housegop            29  1.0  0.034483  0.655172
# @senategop           23  1.0  0.043478  0.565217
# @foxnews             21  1.0  0.333333  0.333333
# @icegov              20  1.0  0.150000  0.650000
# @mailonline          19  1.0  0.105263  0.368421
# @youtube             18  1.0  0.111111  0.500000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 1.1311128733809146, 19)
# Number of tweets that contain a mention: 0.331218609569125
# Most Common mentions:
#                   Count   HS  HS -> TR  HS -> AG
# Mention
# #buildthatwall      373  1.0  0.048257  0.672922
# #maga               220  1.0  0.068182  0.645455
# #buildthewall       204  1.0  0.078431  0.627451
# #nodaca             132  1.0  0.053030  0.696970
# #womensuck          119  1.0  0.302521  0.151261
# #trump              109  1.0  0.055046  0.596330
# #noamnesty           95  1.0  0.094737  0.726316
# #immigration         86  1.0  0.046512  0.616279
# #deportthemall       76  1.0  0.065789  0.750000
# #stoptheinvasion     69  1.0  0.115942  0.623188
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.30399154110494314, 3)
# Number of tweets that contain a mention: 0.2899814961670632
# Most Common mentions:
#                                Count   HS  HS -> TR  HS -> AG
# Mention
# http://t.co/6n4v9kbtya             5  1.0       0.0  0.000000
# https://t.co/hccqmsq9vl            4  1.0       0.0  0.250000
# https://t.co/sn5zuuu6nv            4  1.0       0.0  0.500000
# https://t.co/c0ghvd6imb            3  1.0       0.0  0.333333
# https://t.co/ersjopu1hw            3  1.0       0.0  0.333333
# https://t.co/cgkvjfkqqr            2  1.0       0.0  0.000000
# https://t.co/vhh7jstfhf            2  1.0       0.0  0.500000
# http                               2  1.0       0.0  0.000000
# https://t.co/lgn8jaahftaccess      2  1.0       0.0  0.500000
# https://t.co/nigsdkjqqm            2  1.0       0.0  0.000000
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.4969600845889506, 48)
# Number of tweets that contain a mention: 0.1697065820777161
# Most Common mentions:
#          Count   HS  HS -> TR  HS -> AG
# Mention
# ’          356  1.0  0.452247  0.297753
# 😂          127  1.0  0.685039  0.228346
# …          111  1.0  0.594595  0.270270
# “          107  1.0  0.308411  0.336449
# ”          101  1.0  0.316832  0.356436
# ð           87  1.0  0.022989  0.390805
# ÿ           87  1.0  0.022989  0.390805
# ‘           46  1.0  0.152174  0.391304
# ️           45  1.0  0.688889  0.288889
# ‡           35  1.0  0.000000  0.542857
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (10, 142.64102564102564, 320)
# Mean of Number of words: (1, 22.187681734073486, 63)
# Mean of Avarage word lenght: (2.8, 5.62872932740279, 44.0)
# DEV:
#
# Distribution of features:
# HS: 42.7%
# HS -> TR: 51.288056206088996%
# HS -> AG: 47.7751756440281%
# HS -> TR & AG: 25.526932084309134%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.922, 42)
# Number of tweets that contain a mention: 0.504
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @anncoulter          47  0.680851  0.968750  0.218750
# @realdonaldtrump     35  0.571429  0.150000  0.550000
# @isupport_israel     13  0.461538  0.166667  0.500000
# @potus               11  0.909091  0.000000  0.600000
# @youtube              9  0.111111  0.000000  0.000000
# @corybooker           9  0.555556  1.000000  0.000000
# @senkamalaharris      9  1.000000  1.000000  0.111111
# @donaldjtrumpjr       7  0.857143  0.833333  0.166667
# @housegop             6  1.000000  0.000000  1.000000
# @bensasse             5  0.000000  0.000000  0.000000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.73, 18)
# Number of tweets that contain a mention: 0.24
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# #buildthatwall       32  1.000000  0.031250  0.562500
# #buildthewall        25  0.880000  0.000000  0.590909
# #maga                21  0.904762  0.157895  0.578947
# #trump               19  0.789474  0.066667  0.666667
# #immigration         18  0.666667  0.083333  0.500000
# #stoptheinvasion     16  0.750000  0.166667  0.583333
# #nodaca              15  0.933333  0.000000  0.571429
# #refugees            15  0.266667  0.000000  0.250000
# #noamnesty           12  1.000000  0.000000  0.750000
# #walkaway            12  0.833333  0.000000  0.400000
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.422, 3)
# Number of tweets that contain a mention: 0.364
# Most Common mentions:
#                                            Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/qzfjsqwwj8                        2  0.0       0.0       0.0
# https://t.co/v3iiymkzi2#againstallenemies      1  1.0       0.0       1.0
# https://t.co/85yivhlfz5                        1  0.0       0.0       0.0
# https://t.co/8jvqfizyzc                        1  0.0       0.0       0.0
# https://t.co/ajcn87u3j6                        1  0.0       0.0       0.0
# https://t.co/utpm3aera3                        1  0.0       0.0       0.0
# https://t.co/tn3v3simrq                        1  0.0       0.0       0.0
# https://t.co/fe4pbeeovg                        1  0.0       0.0       0.0
# https://t.co/j1hjouh9om                        1  0.0       0.0       0.0
# https://t.co/ak42vyuscd                        1  0.0       0.0       0.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.321, 20)
# Number of tweets that contain a mention: 0.115
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# ’           61  0.147541       0.0  0.444444
# …           32  0.000000       0.0  0.000000
# ð           21  0.285714       0.0  0.000000
# ÿ           21  0.285714       0.0  0.000000
# ”           19  0.210526       0.0  0.000000
# “           16  0.250000       0.0  0.000000
# ‘           16  0.062500       0.0  0.000000
# —           11  0.000000       0.0  0.000000
# ˜           10  0.200000       0.0  0.000000
# â           10  0.200000       0.0  1.000000
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (10, 157.727, 851)
# Mean of Number of words: (1, 24.547, 93)
# Mean of Avarage word lenght: (3.0, 5.8428570096100145, 30.0)
# TEST:
#
# Distribution of features:
# HS: 42.0%
# HS -> TR: 41.98412698412698%
# HS -> AG: 47.142857142857146%
# HS -> TR & AG: 14.523809523809524%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 1.0643333333333334, 40)
# Number of tweets that contain a mention: 0.469
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @realdonaldtrump    233  0.304721  0.028169  0.690141
# @potus               85  0.200000  0.000000  0.647059
# @realjameswoods      41  0.073171  0.000000  0.333333
# @foxnews             32  0.312500  0.000000  0.600000
# @speakerryan         29  0.379310  0.090909  0.454545
# @housegop            28  0.821429  0.043478  0.608696
# @icegov              23  0.739130  0.000000  0.764706
# @senategop           22  0.818182  0.000000  0.722222
# @gop                 22  0.454545  0.000000  0.500000
# @                    20  0.300000  0.333333  0.333333
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 2.1336666666666666, 27)
# Number of tweets that contain a mention: 0.49966666666666665
# Most Common mentions:
#                 Count        HS  HS -> TR  HS -> AG
# Mention
# #buildthatwall    466  0.242489  0.017699  0.672566
# #maga             363  0.294766  0.018692  0.598131
# #nodaca           239  0.322176  0.012987  0.363636
# #buildthewall     234  0.525641  0.032520  0.715447
# #illegalaliens    210  0.276190  0.017241  0.586207
# #deportthemall    180  0.827778  0.053691  0.677852
# #sendthemback     163  0.680982  0.027027  0.567568
# #walkaway         129  0.162791  0.000000  0.476190
# #americafirst     125  0.216000  0.037037  0.555556
# #kag              119  0.176471  0.000000  0.428571
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.09133333333333334, 1)
# Number of tweets that contain a mention: 0.09133333333333334
# Most Common mentions:
#                          Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/cmwmcf2kp3      2  0.5       1.0       1.0
# https://t.co/oeof6brqqj      2  0.5       1.0       0.0
# https://t.co/nolwubionv      2  0.0       0.0       0.0
# https://t.co/ll0a3p780u      2  0.0       0.0       0.0
# https://t.co/rm7vtgc70a      2  0.0       0.0       0.0
# https://t.co/dbnbxezc06      2  0.5       1.0       0.0
# https://t.co/kr6nbspwhq      2  0.0       0.0       0.0
# https://t.co/u58iip7uy4      1  0.0       0.0       0.0
# https://t.co/fwsc0unfhz      1  0.0       0.0       0.0
# https://t.co/o8lrbl69b0      1  1.0       1.0       0.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.30933333333333335, 20)
# Number of tweets that contain a mention: 0.149
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# 😂          262  0.519084  0.838235  0.205882
# …           90  0.288889  0.846154  0.423077
# ️           34  0.235294  0.750000  0.125000
# 😭           33  0.575758  0.947368  0.842105
# 💯           23  0.652174  0.666667  0.266667
# 🙄           23  0.652174  0.733333  0.200000
# ’           20  0.350000  0.571429  0.142857
# 😍           20  0.150000  0.000000  1.000000
# 😘           17  0.588235  0.700000  0.500000
# 🖕           16  0.750000  0.916667  0.166667
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (15, 140.563, 803)
# Mean of Number of words: (1, 21.475666666666665, 90)
# Mean of Avarage word lenght: (2.7, 5.731663448178275, 51.666666666666664)

# %%
print("TRAIN:\n")
basic_statistics_plot(spanish_train)
print("\n\nTRAIN with HS:\n")
basic_statistics_plot(spanish_train, HS=True)
print("\n\nDEV:\n")
basic_statistics_plot(spanish_dev)
print("\n\nTEST:\n")
basic_statistics_plot(spanish_test)
# Out:
# TRAIN:
#
# Distribution of features:
# HS: 41.266666666666666%
# HS -> TR: 60.796984383414106%
# HS -> AG: 80.88314485729671%
# HS -> TR & AG: 56.70436187399031%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.6551111111111111, 16)
# Number of tweets that contain a mention: 0.4351111111111111
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @sanchezcastejon     24  0.708333  0.117647  0.941176
# @youtube             23  0.043478  1.000000  1.000000
# @barbijaputa         21  0.142857  0.666667  0.666667
# @anaisbernal         15  0.000000  0.000000  0.000000
# @zurine3             13  0.000000  0.000000  0.000000
# @relatofeminista     12  0.166667  0.500000  0.500000
# @leticiadolera       12  0.000000  0.000000  0.000000
# @_eckoyg             11  0.000000  0.000000  0.000000
# @irantzuvarela       11  0.090909  0.000000  0.000000
# @                    10  0.400000  0.250000  1.000000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.18622222222222223, 22)
# Number of tweets that contain a mention: 0.09844444444444445
# Most Common mentions:
#                  Count        HS  HS -> TR  HS -> AG
# Mention
# #inmigración        10  0.600000  0.000000       1.0
# #otgala7             9  0.000000  0.000000       0.0
# #inmigrantes         9  0.111111  0.000000       1.0
# #refugiados          8  0.125000  0.000000       0.0
# #indocumentados      7  0.000000  0.000000       0.0
# #arandina            6  0.000000  0.000000       0.0
# #otgala9             6  0.000000  0.000000       0.0
# #otgala8             5  0.200000  1.000000       0.0
# #moromierdas         5  1.000000  0.000000       1.0
# #venezuela           5  0.600000  0.666667       1.0
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.33244444444444443, 4)
# Number of tweets that contain a mention: 0.30933333333333335
# Most Common mentions:
#                          Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/eap7pkrma3      2  1.0       0.0       1.0
# https://t.co/4qgbnyklpo      2  0.0       0.0       0.0
# https://t.co/47cdr1xuoy      2  0.0       0.0       0.0
# https://t.co/s6ursjjugy      2  0.5       0.0       0.0
# https://t.co/myqvt7kt8m      2  0.5       0.0       1.0
# https://t.co/2pr0yptnca      2  1.0       0.0       1.0
# https://t.co/z9uyywo52d      1  0.0       0.0       0.0
# https://t.co/yxlc61aryr      1  0.0       0.0       0.0
# https://t.co/kdf5vca7jw      1  0.0       0.0       0.0
# https://t.co/h1yy5r2ydo      1  0.0       0.0       0.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 2.191333333333333, 60)
# Number of tweets that contain a mention: 0.7568888888888889
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# á         2048  0.406250  0.502404  0.819712
# í         1590  0.359119  0.350263  0.737303
# ó         1270  0.314173  0.330827  0.706767
# ñ         1039  0.389798  0.367901  0.748148
# é          880  0.328409  0.494810  0.757785
# ú          535  0.428037  0.659389  0.803493
# ¿          267  0.464419  0.250000  0.395161
# ü          208  0.274038  0.508772  0.701754
# 😂          190  0.500000  0.894737  0.821053
# ¡          117  0.427350  0.380000  0.720000
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (6, 128.28822222222223, 313)
# Mean of Number of words: (1, 21.07888888888889, 59)
# Mean of Avarage word lenght: (1.9090909090909092, 5.37989396405569, 17.0)
# TRAIN with HS:
#
# Distribution of features:
# HS: 100.0%
# HS -> TR: 60.796984383414106%
# HS -> AG: 80.88314485729671%
# HS -> TR & AG: 56.70436187399031%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.6806677436725902, 8)
# Number of tweets that contain a mention: 0.464728056004308
# Most Common mentions:
#                   Count   HS  HS -> TR  HS -> AG
# Mention
# @sanchezcastejon     17  1.0  0.117647  0.941176
# @lortegadiaz          7  1.0  1.000000  1.000000
# @lopezdoriga          6  1.0  1.000000  1.000000
# @nicolasmaduro        6  1.0  0.333333  0.833333
# @beeluarzola          5  1.0  1.000000  1.000000
# @drodriguezven        5  1.0  0.800000  1.000000
# @adacolau             5  1.0  0.200000  1.000000
# @marianorajoy         4  1.0  0.000000  1.000000
# @salvameoficial       4  1.0  1.000000  1.000000
# @elisacarrio          4  1.0  1.000000  1.000000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.12116316639741519, 9)
# Number of tweets that contain a mention: 0.07539041464728057
# Most Common mentions:
#                         Count   HS  HS -> TR  HS -> AG
# Mention
# #inmigración                6  1.0  0.000000  1.000000
# #moromierdas                5  1.0  0.000000  1.000000
# #stopinvasion               4  1.0  0.250000  0.500000
# #barcelona                  4  1.0  0.000000  0.750000
# #españa                     3  1.0  0.000000  0.666667
# #venezuela                  3  1.0  0.666667  1.000000
# #eleccionesgeneralesya      3  1.0  0.000000  0.333333
# #femimoda                   2  1.0  0.000000  0.500000
# #humor                      2  1.0  0.000000  0.000000
# #chileprimero               2  1.0  0.000000  1.000000
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.2929456112008616, 2)
# Number of tweets that contain a mention: 0.28379106085083466
# Most Common mentions:
#                          Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/2pr0yptnca      2  1.0       0.0       1.0
# https://t.co/eap7pkrma3      2  1.0       0.0       1.0
# https://t.co/jcvqgiid6n      1  1.0       0.0       0.0
# https://t.co/xm35d5jdxp      1  1.0       0.0       1.0
# https://t.co/xxb1l522xm      1  1.0       0.0       1.0
# https://t.co/c7mzwxal9p      1  1.0       0.0       0.0
# https://t.co/qe3pf9kahc      1  1.0       0.0       1.0
# https://t.co/u8wxi3hjgu      1  1.0       0.0       1.0
# https://t.co/bd83gt1iod      1  1.0       0.0       1.0
# https://t.co/c522uhhajl      1  1.0       1.0       1.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 1.9649973074851912, 42)
# Number of tweets that contain a mention: 0.7189014539579968
# Most Common mentions:
#          Count   HS  HS -> TR  HS -> AG
# Mention
# á          832  1.0  0.502404  0.819712
# í          571  1.0  0.350263  0.737303
# ñ          405  1.0  0.367901  0.748148
# ó          399  1.0  0.330827  0.706767
# é          289  1.0  0.494810  0.757785
# ú          229  1.0  0.659389  0.803493
# ¿          124  1.0  0.250000  0.395161
# 😂           95  1.0  0.894737  0.821053
# ü           57  1.0  0.508772  0.701754
# ¡           50  1.0  0.380000  0.720000
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (16, 123.12277867528272, 313)
# Mean of Number of words: (2, 20.03069466882068, 59)
# Mean of Avarage word lenght: (1.9090909090909092, 5.497396607113844, 15.2)
# DEV:
#
# Distribution of features:
# HS: 44.4%
# HS -> TR: 61.711711711711715%
# HS -> AG: 79.27927927927928%
# HS -> TR & AG: 57.207207207207205%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.654, 5)
# Number of tweets that contain a mention: 0.444
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @zurine3              4  0.000000       0.0  0.000000
# @relatofeminista      3  0.333333       0.0  0.000000
# @nicolasmaduro        3  0.000000       0.0  0.000000
# @sanchezcastejon      3  0.333333       0.0  1.000000
# @guardiacivil         3  0.333333       0.0  1.000000
# @elmundoes            3  1.000000       0.0  0.666667
# @lasextatv            2  0.500000       0.0  0.000000
# @pablocasado_         2  0.500000       0.0  1.000000
# @dalasreview          2  0.000000       0.0  0.000000
# @barbijaputa          2  0.000000       0.0  0.000000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.242, 11)
# Number of tweets that contain a mention: 0.12
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# #otgala7              4  0.000000       0.0       0.0
# #inmigracion          3  0.333333       0.0       0.0
# #qatar                3  0.000000       0.0       0.0
# #camilavallejo        3  1.000000       1.0       1.0
# #migrantes            2  0.000000       0.0       0.0
# #indocumentados       2  0.000000       0.0       0.0
# #inmigrantes          2  0.000000       0.0       0.0
# #inmigración          2  1.000000       0.0       1.0
# #todassomosdiana      1  0.000000       0.0       0.0
# #carmena              1  1.000000       0.0       1.0
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.32, 2)
# Number of tweets that contain a mention: 0.3
# Most Common mentions:
#                          Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/twuzlrne8m      1  0.0       0.0       0.0
# https://t.co/59pinbdgnr      1  1.0       0.0       0.0
# https://t.co/4kladtudgy      1  0.0       0.0       0.0
# https://t.co/xkuilibt9j      1  0.0       0.0       0.0
# https://t.co/sqmbri13wj      1  1.0       1.0       1.0
# https://t.co/u9pv1noorb      1  0.0       0.0       0.0
# https://t.co/21n1d8femp      1  0.0       0.0       0.0
# https://t.co/tahdcpzdnm      1  0.0       0.0       0.0
# https://t.co/b6bfpcf0xg      1  1.0       0.0       0.0
# https://t.co/drrkqxbpgj      1  0.0       0.0       0.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 2.22, 31)
# Number of tweets that contain a mention: 0.772
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# á          224  0.446429  0.520000  0.760000
# í          191  0.460733  0.352273  0.738636
# ó          132  0.348485  0.456522  0.739130
# ñ          131  0.396947  0.346154  0.673077
# é          102  0.470588  0.520833  0.791667
# ú           73  0.424658  0.806452  0.870968
# ü           23  0.173913  0.000000  0.750000
# 😂           22  0.409091  0.777778  0.222222
# ¿           22  0.318182  0.285714  0.571429
# ¡           19  0.210526  0.000000  1.000000
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (16, 130.32, 308)
# Mean of Number of words: (2, 21.52, 60)
# Mean of Avarage word lenght: (3.2222222222222223, 5.386292979373705, 14.5)
# TEST:
#
# Distribution of features:
# HS: 41.25%
# HS -> TR: 64.0909090909091%
# HS -> AG: 71.81818181818181%
# HS -> TR & AG: 56.21212121212121%
# !HS & (TR | AG): 0.0%
#
# Users:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.9525, 50)
# Number of tweets that contain a mention: 0.550625
# Most Common mentions:
#                   Count        HS  HS -> TR  HS -> AG
# Mention
# @barbijaputa         81  0.012346    1.0000  1.000000
# @sanchezcastejon     38  0.421053    0.0625  0.687500
# @guardiacivil        31  0.290323    0.0000  0.222222
# @elmundoes           18  0.333333    0.0000  0.500000
# @interiorgob         13  0.461538    0.0000  0.333333
# @psoe                11  0.454545    0.0000  0.800000
# @abc_es              10  0.300000    0.0000  1.000000
# @elisacarrio          9  1.000000    1.0000  1.000000
# @vikidonda            7  0.857143    1.0000  1.000000
# @updayesp             7  0.571429    0.0000  0.500000
#
# Hashtags:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.204375, 14)
# Number of tweets that contain a mention: 0.10875
# Most Common mentions:
#                    Count        HS  HS -> TR  HS -> AG
# Mention
# #ceuta                35  0.114286       0.0  0.000000
# #otgala7              14  0.285714       1.0  0.750000
# #inmigrantes           8  0.125000       0.0  0.000000
# #eleccionesya          7  0.857143       0.0  0.166667
# #españa                6  0.333333       0.0  0.500000
# #guardiacivil          5  0.200000       0.0  0.000000
# #inmigración           5  0.200000       0.0  1.000000
# #fronterasseguras      4  0.750000       0.0  0.666667
# #stopislam             4  1.000000       0.0  0.250000
# #inmigracion           4  0.000000       0.0  0.000000
#
# Links:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 0.351875, 2)
# Number of tweets that contain a mention: 0.3375
# Most Common mentions:
#                          Count   HS  HS -> TR  HS -> AG
# Mention
# https://t.co/x0kuh1rqmy      1  0.0       0.0       0.0
# https://t.co/l9na3eefeb      1  1.0       1.0       1.0
# https://t.co/64z80y2pwu      1  0.0       0.0       0.0
# https://t.co/vz7mzpnnjw      1  0.0       0.0       0.0
# https://t.co/fwxgowzszh      1  1.0       1.0       1.0
# https://t.co/s9jcbeej4n      1  0.0       0.0       0.0
# https://t.co/gdaxejstop      1  1.0       0.0       0.0
# https://t.co/rmf8zlvmuc      1  0.0       0.0       0.0
# https://t.co/nlwf985srp      1  1.0       0.0       0.0
# https://t.co/jdfvl3ygwy      1  1.0       1.0       1.0
#
# Non-ascii:
# Number of mentions per tweet (MIN, MEAN, MAX): (0, 1.81, 16)
# Number of tweets that contain a mention: 0.686875
# Most Common mentions:
#          Count        HS  HS -> TR  HS -> AG
# Mention
# á          594  0.414141  0.556911  0.703252
# í          488  0.336066  0.463415  0.628049
# ó          424  0.327830  0.302158  0.474820
# ñ          297  0.427609  0.433071  0.653543
# é          244  0.331967  0.493827  0.592593
# …          141  0.219858  0.903226  0.806452
# ú          138  0.355072  0.734694  0.734694
# ¿           66  0.424242  0.428571  0.392857
# ¡           62  0.548387  0.264706  0.705882
# 😂           53  0.188679  0.900000  0.900000
#
# Tweets: (MIN, MEAN, MAX)
# Number of characters: (6, 136.07375, 846)
# Mean of Number of words: (1, 21.849375, 88)
# Mean of Avarage word lenght: (2.857142857142857, 5.4868473183787945, 18.0)

# %% [markdown]
# ## Tf-Idf
# ### Preprocessing
#
# DONE:
#
# - Remove links
# - Lowercase all characters
# - Remove emojis (or replaced)
# - Remove stopwords
# - Correct spelling mistakes
# - Remove numbers (or replace by word "number")
# - Replace ”&” for "and"
# - Standardize blank spaces
# - Normalize contractions
# - Lemmatization
# - Substitution of abbreviations
# - Remove punctuation (Spanish)

# %%
from datetime import datetime, timedelta

def init_print_progress(n, k=10, measure_remaining_time=True, measure_avarage_time=True):
    """Inicializes the auxialiar `_print_progress()` establishing the behaviour of when
    and what should be printed.
    
    Parameters
    ----------
    n: int
        Number of iterations the auxiliar method will be called.
    k: int, default=10
        Number of iterations of when the printed data will be updated.
    measure_remaining_time: bool, default=True
        If the printed progress should display the remaining time.
    measure_avarage_time: bool, default=True
        If the remaining time should be calculated using an avarage.
        Recomended if the task load should be similar.
    """
    _print_progress._i = 1 # Number of iterations done
    _print_progress._k = k # Module of when the print will be called
    _print_progress._n = n # Total iterations to be complated
    
    _print_progress._measure_remaining_time = measure_remaining_time # If time should be tracked
    _print_progress._measure_avarage_time = measure_avarage_time # If an avarage should be used
    if measure_remaining_time:
        _print_progress._datetime = datetime.now() # Time of completion of last k iterations
        _print_progress.avargetime = timedelta() # Avarage time of the k iterations
    
def _print_progress():
    """Auxiliar method that will track progress of a fucntion. Should be called each time
    an iterations is done. Before starting the tracking, the function `init_print_progress()`
    should be called once.
    """
    _i, _k, _n = _print_progress._i, _print_progress._k, _print_progress._n
    if _i % _k == 0 or _i == _n: #Every k iterations prints or it's the last iteration
        _measure_remaining_time = _print_progress._measure_remaining_time
        if _measure_remaining_time:
            next_datetime = datetime.now()
            diff_time = next_datetime - _print_progress._datetime # Time elapsed between now and the previous k iteration
            if _print_progress._measure_remaining_time:
                _print_progress.avargetime = (_print_progress.avargetime * (_i//_k - 1) + diff_time) / (_i//_k) # Updates avarge time by adding the new elapsed time to the avarage
            else:
                _print_progress.avargetime = diff_time # Avarage time isn't tracked
            time_remaining = ((_print_progress.avargetime) / _k * (_n - _i)).total_seconds() #Calculates the time remaining
            _print_progress._datetime = next_datetime # Upadates the last time
            
        print(" "*100, end='\r') # Cleans the output
        print(f"{_i}/{_n} ({round(100*_i/_n, 2)}%)", end='') # Prints the current percentage of completion
        # Prints the calculated remaining time if specified in the inicialization. Also last iteration ends with '\n' leaving the percentage completion
        print(f" [time remaining: {int(time_remaining//3600)}:{int(time_remaining/60%60):02d}:{int(time_remaining%60):02d}]" if _measure_remaining_time else "", end='\r' if _i < _n else '\n')
    _print_progress._i += 1 # Increments the number of iterations that had happened

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler

from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize.regexp import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
import re
from spellchecker import SpellChecker
from pycontractions import Contractions
import json
import os.path
import pickle
import unicodedata

# TODO: Comprovar si: nltk.download('wordnet')


def load_dictonaries():
    """Loads the data inside the json files of all dictonaries.
    This way we avoid reconstructing the dictonary each instance.
    """
    with open('./data/simple_emojis.json') as f:
        replace_emojis.simple_emojis = json.load(f)
        
    with open('./data/complex_emojis.json') as f:
        replace_emojis.complex_emojis = json.load(f)
        
    with open('./data/abbreviations.json') as f:
        replace_abbreviations.abbreviations = json.load(f) 

def replace_emojis(text, lenguage):
    """Replaces all emojis with the meaning in the dictionary. Extra 
    spaces are added to both sides to avoid case where a word or 
    another emoji aren't separated.
    """
    simple_emojis = replace_emojis.simple_emojis
    for emoji, meaning in simple_emojis.items():
        text = text.replace(emoji, f" {meaning[lenguage]} ")
        
    complex_emojis = replace_emojis.complex_emojis
    for emoji, meaning in complex_emojis.items():
        text = text.replace(emoji, f" {meaning[lenguage]} ")
        
    return text

def strip_accents(text):
    return ''.join(c for c in unicodedata.normalize('NFD', text)
                  if unicodedata.category(c) != 'Mn')

def replace_abbreviations(text, lenguage):
    """Replaces all exact abbreviations with the meaning in the dictionary.
    Will try to replace exact match of the abbreviation if it's translated
    in the meaning dictonary.
    """
    abbreviations = replace_abbreviations.abbreviations 
    for abbreviation, meaning in abbreviations.items():
        if lenguage in meaning:
            text = re.sub(r"\b" + abbreviation + r"\b", meaning[lenguage], text)

    return text

def direct_replacement(data, lenguage='en'):
    """
    Performs replacement or removal of diffent parts of text series. Currently does:
        - Lowercase
        - Standerization of contractions and other characters
        - Link removal
        - Digits removal
        - Emoji replacement with it's meaning or removal in case it's not found
        - Removes accents
    """
    def _replacement(text):
        # Lowercase and replace & and Standerize contractions and other special characters
        text = text.replace("’", "'").replace("‘", "'").replace("…", "...").replace("”", "\"\"").replace("“", "\"\"").lower()
        
        # Remove links
        text = re.sub(r"https?\S*", "", text)
        
        # Remove digits
        text = re.sub(r"\d+", "", text)
        
        # Replace emojis
        text = replace_emojis(text, lenguage)
        
        # Remove emojis in case they where not replaced
        regrex_pattern = re.compile(pattern = "["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags = re.UNICODE)
        text = regrex_pattern.sub(r'', text)
                          
        # Replace abbreviations
        text = replace_abbreviations(text, lenguage)
        
        # Removes accents
        text = strip_accents(text)
        
        return text

    load_dictonaries()
    return data.apply(lambda text: _replacement(text))

def expand_contractions(data):
    """
    Expand contractions of all the dataset through the context using a deep learning model.
    Currently it's using the model of word2vec.
    """
    # Download link: https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
    cont = Contractions('./models/GoogleNews-vectors-negative300.bin')
    cont.load_models()
    
    data_expanded = list(cont.expand_texts(data, precise=False))
    
    return pd.Series(data_expanded, index=data.index, dtype=data.dtype, name=data.name)
    

def tokenization_text(text, language='en'):
    """
    Transforms the text into a serie of tokens that will contain only words, hashtags or users.
    Also corrects the text using Levenshtein Distance of 2. Then, lemmatises the tokens and 
    removes the stopwords.
    """
    # Tokenise words without digits while ignoring punctuation, except Users and Hashtags
    tokeniser = RegexpTokenizer(r'[#@]?[^\d\W]+')
    tokens = tokeniser.tokenize(text)
    
    # Corrector with Levenshtein Distance of 2
    spell = SpellChecker(language=language, distance=2)
    tokens = [spell.correction(token) for token in tokens]
    
    # Lemmatization 
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(token, pos='v') for token in tokens]
    
    # Remove stopwords
    keywords= [lemma for lemma in lemmas if lemma not in stopwords.words('english' if language == 'en' else 'spanish')]
    
    _print_progress() # Auxiliar method to track the progress

    return keywords

# Tf-Idf vectorizer
english_vectorizer = TfidfVectorizer(analyzer=tokenization_text, max_features=3500, max_df=0.65)
spanish_vectorizer = TfidfVectorizer(analyzer=lambda text: tokenization_text(text, lenguage='es'), max_features=3500, max_df=0.65)

# Pipeline to generate the Tf-Idf matrix of the dataset
english_pipe = Pipeline([
    ('direct_replacement', FunctionTransformer(func=direct_replacement, validate=False)),
    ('expand_contractions', FunctionTransformer(func=expand_contractions, validate=False)),
    ('tfidfVectorizer', english_vectorizer)
])

# Pipeline to generate the Tf-Idf matrix of the dataset
spanish_pipe = Pipeline([
    ('direct_replacement', FunctionTransformer(func=direct_replacement, validate=False , kw_args={"lenguage": "es"})),
    ('tfidfVectorizer', spanish_vectorizer)
])

# %% [markdown]
# ### Save and load preprocessing

# %%
from scipy import sparse

if not 'is_TfIDF_fitted' in globals(): #Avoids redefinition, so rexecuting cell doesn't rewrite the value
    is_TfIDF_fitted = {}

def load_Tfidf_processing(pipe, train_data, data, path, name, lenguage):
    global is_TfIDF_fitted
    
    if os.path.isfile(path):
        X_basic = sparse.load_npz(path)
        print(f"Preprocessing {name} data loaded succesfully")
    else:
        init_print_progress(train_data.shape[0])
        if data.equals(train_data) and not is_TfIDF_fitted.get(lenguage, False):
            X_basic = pipe.fit_transform(train_data['text'])
            is_TfIDF_fitted[lenguage] = True
        else:
            if not is_TfIDF_fitted.get(lenguage, False):
                print("Pipe will be fitted first.")
                pipe.fit(train_data['text'])
                is_TfIDF_fitted[lenguage] = True

            init_print_progress(data.shape[0])
            X_basic = pipe.transform(data['text'])

        sparse.save_npz(path, X_basic)
        
    return X_basic

# %%
train_path, dev_path, test_path = "./data/X_train_basic_english.npz", "./data/X_dev_basic_english.npz", "./data/X_test_basic_english.npz"

X_basic_train_english = load_Tfidf_processing(english_pipe, english_train, english_train, train_path, "train", "English")
X_basic_dev_english = load_Tfidf_processing(english_pipe, english_train, english_dev, dev_path, "dev", "English")
X_basic_test_english = load_Tfidf_processing(english_pipe, english_train, english_test, test_path, "test", "English")
# Out:
# Preprocessing train data loaded succesfully
# Preprocessing dev data loaded succesfully
# Preprocessing test data loaded succesfully

# %%
train_path, dev_path, test_path = "./data/X_train_basic_spanish.npz", "./data/X_dev_basic_spanish.npz", "./data/X_test_basic_spanish.npz"

X_basic_train_spanish = load_Tfidf_processing(spanish_pipe, spanish_train, spanish_train, train_path, "train", "Spanish")
X_basic_dev_spanish = load_Tfidf_processing(spanish_pipe, spanish_train, spanish_dev, dev_path, "dev", "Spanish")
X_basic_test_spanish = load_Tfidf_processing(spanish_pipe, spanish_train, spanish_test, test_path, "test", "Spanish")
# Out:
# Preprocessing train data loaded succesfully
# Preprocessing dev data loaded succesfully
# Preprocessing test data loaded succesfully

# %%
dict(sorted(english_vectorizer.vocabulary_.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'ðÿ_xf_': 3499,
#  'âž_xd_': 3498,
#  'â_xd_': 3497,
#  'â_x_': 3496,
#  'ºðÿ': 3495,
#  '²ðÿ': 3494,
#  'ªðÿ': 3493,
#  'zone': 3492,
#  'zero': 3491,
#  'zealot': 3490,
#  'yrs': 3489,
#  'yr': 3488,
#  'youtube': 3487,
#  'youth': 3486,
#  'younger': 3485,
#  'young': 3484,
#  'york': 3483,
#  'yo': 3482,
#  'yet': 3481,
#  'yesterday': 3480,
#  'yes': 3479,
#  'yep': 3478,
#  'yemen': 3477,
#  'yell': 3476,
#  'years': 3475,
#  'year': 3474,
#  'yeah': 3473,
#  'yea': 3472,
#  'ya': 3471,
#  'xenophobic': 3470,
#  'wrong': 3469,
#  'write': 3468,
#  'wrap': 3467,
#  'wow': 3466,
#  'would': 3465,
#  'worthless': 3464,
#  'worth': 3463,
#  'worst': 3462,
#  'worship': 3461,
#  'worse': 3460,
#  'worry': 3459,
#  'worldcup': 3458,
#  'world': 3457,
#  'workplace': 3456,
#  'workers': 3455,
#  'worker': 3454,
#  'work': 3453,
#  'word': 3452,
#  'wonderful': 3451,
#  'wonder': 3450,
#  'womens': 3449,
#  'women': 3448,
#  'woman': 3447,
#  'wolf': 3446,
#  'wive': 3445,
#  'without': 3444,
#  'within': 3443,
#  'withhold': 3442,
#  'witch': 3441,
#  'wit': 3440,
#  'wish': 3439,
#  'wise': 3438,
#  'wipe': 3437,
#  'wink': 3436,
#  'wing': 3435,
#  'wine': 3434,
#  'windrush': 3433,
#  'win': 3432,
#  'wild': 3431,
#  'wife': 3430,
#  'wif': 3429,
#  'widow': 3428,
#  'wide': 3427,
#  'wi': 3426,
#  'whose': 3425,
#  'whore': 3424,
#  'whole': 3423,
#  'whoever': 3422,
#  'white': 3421,
#  'whine': 3420,
#  'whilst': 3419,
#  'whether': 3418,
#  'wherever': 3417,
#  'whenever': 3416,
#  'whatever': 3415,
#  'wet': 3414,
#  'western': 3413,
#  'west': 3412,
#  'well': 3411,
#  'welfare': 3410,
#  'welcome': 3409,
#  'weird': 3408,
#  'weinstein': 3407,
#  'weight': 3406,
#  'weeks': 3405,
#  'weekend': 3404,
#  'week': 3403,
#  'wednesday': 3402,
#  'wed': 3401,
#  'website': 3400,
#  'weary': 3399,
#  'wear': 3398,
#  'weapons': 3397,
#  'wealthy': 3396,
#  'wealth': 3395,
#  'weak': 3394,
#  'ways': 3393,
#  'way': 3392,
#  'wave': 3391,
#  'watson': 3390,
#  'water': 3389,
#  'watch': 3388,
#  'wat': 3387,
#  'waste': 3386,
#  'washington': 3385,
#  'wash': 3384,
#  'warrant': 3383,
#  'warn': 3382,
#  'warm': 3381,
#  'war': 3380,
#  'want': 3379,
#  'wallet': 3378,
#  'wall': 3377,
#  'walkway': 3376,
#  'walk': 3375,
#  'wakeup': 3374,
#  'wake': 3373,
#  'wait': 3372,
#  'wage': 3371,
#  'wag': 3370,
#  'vulnerable': 3369,
#  'vow': 3368,
#  'voters': 3367,
#  'voter': 3366,
#  'vote': 3365,
#  'volunteer': 3364,
#  'voluntary': 3363,
#  'voice': 3362,
#  'vital': 3361,
#  'visit': 3360,
#  'visa': 3359,
#  'virtue': 3358,
#  'virginia': 3357,
#  'virgin': 3356,
#  'viral': 3355,
#  'violent': 3354,
#  'violence': 3353,
#  'violations': 3352,
#  'violate': 3351,
#  'village': 3350,
#  'vile': 3349,
#  'viktor': 3348,
#  'view': 3347,
#  'videos': 3346,
#  'video': 3345,
#  'victory': 3344,
#  'victoria': 3343,
#  'victims': 3342,
#  'victimless': 3341,
#  'victimize': 3340,
#  'victim': 3339,
#  'via': 3338,
#  'veterans': 3337,
#  'vet': 3336,
#  'versus': 3335,
#  'version': 3334,
#  'verify': 3333,
#  'venezuela': 3332,
#  'vaughn': 3331,
#  'vast': 3330,
#  'value': 3329,
#  'valley': 3328,
#  'valid': 3327,
#  'vaginas': 3326,
#  'vagina': 3325,
#  'vacation': 3324,
#  'utter': 3323,
#  'usually': 3322,
#  'useless': 3321,
#  'useful': 3320,
#  'use': 3319,
#  'usd': 3318,
#  'usaid': 3317,
#  'usa': 3316,
#  'us': 3315,
#  'urge': 3314,
#  'ur': 3313,
#  'upside': 3312,
#  'upset': 3311,
#  'upon': 3310,
#  'uphold': 3309,
#  'update': 3308,
#  'upcoming': 3307,
#  'unsafe': 3306,
#  'unpost': 3305,
#  'unlike': 3304,
#  'unless': 3303,
#  'university': 3302,
#  'unite': 3301,
#  'union': 3300,
#  'ungrateful': 3299,
#  'unfortunately': 3298,
#  'unfair': 3297,
#  'uneducated': 3296,
#  'undocumented': 3295,
#  'understand': 3294,
#  'undermine': 3293,
#  'uncover': 3292,
#  'unbelievable': 3291,
#  'unaccompanied': 3290,
#  'unacceptable': 3289,
#  'una': 3288,
#  'un': 3287,
#  'ummm': 3286,
#  'ukraine': 3285,
#  'uk': 3284,
#  'ugly': 3283,
#  'ugh': 3282,
#  'uganda': 3281,
#  'u': 3280,
#  'typical': 3279,
#  'type': 3278,
#  'two': 3277,
#  'twitter': 3276,
#  'twist': 3275,
#  'twice': 3274,
#  'tweet': 3273,
#  'twat': 3272,
#  'turn': 3271,
#  'turks': 3270,
#  'turkish': 3269,
#  'turkey': 3268,
#  'tunnel': 3267,
#  'tunisia': 3266,
#  'tune': 3265,
#  'tuesday': 3264,
#  'tryna': 3263,
#  'tryin': 3262,
#  'try': 3261,
#  'truths': 3260,
#  'truth': 3259,
#  'trust': 3258,
#  'trumpet': 3257,
#  'trump': 3256,
#  'truly': 3255,
#  'true': 3254,
#  'trudeau': 3253,
#  'truck': 3252,
#  'trouble': 3251,
#  'troop': 3250,
#  'trip': 3249,
#  'trick': 3248,
#  'trend': 3247,
#  'tree': 3246,
#  'treatment': 3245,
#  'treat': 3244,
#  'treason': 3243,
#  'travel': 3242,
#  'trauma': 3241,
#  'trashy': 3240,
#  'trash': 3239,
#  'trap': 3238,
#  'transportation': 3237,
#  'transport': 3236,
#  'transfer': 3235,
#  'trans': 3234,
#  'traitor': 3233,
#  'train': 3232,
#  'trailer': 3231,
#  'traffic': 3230,
#  'trade': 3229,
#  'track': 3228,
#  'toy': 3227,
#  'toxic': 3226,
#  'towns': 3225,
#  'town': 3224,
#  'tower': 3223,
#  'towards': 3222,
#  'toward': 3221,
#  'tourists': 3220,
#  'tourist': 3219,
#  'tour': 3218,
#  'tough': 3217,
#  'touch': 3216,
#  'totally': 3215,
#  'total': 3214,
#  'tory': 3213,
#  'torture': 3212,
#  'toronto': 3211,
#  'tories': 3210,
#  'top': 3209,
#  'tonight': 3208,
#  'tongue': 3207,
#  'tomorrow': 3206,
#  'tom': 3205,
#  'tolerate': 3204,
#  'tolerant': 3203,
#  'tolerance': 3202,
#  'together': 3201,
#  'today': 3200,
#  'tits': 3199,
#  'title': 3198,
#  'tire': 3197,
#  'tip': 3196,
#  'tiny': 3195,
#  'tinder': 3194,
#  'time': 3193,
#  'till': 3192,
#  'tight': 3191,
#  'tie': 3190,
#  'ticket': 3189,
#  'thus': 3188,
#  'thumb': 3187,
#  'thugs': 3186,
#  'thru': 3185,
#  'throw': 3184,
#  'throat': 3183,
#  'thrive': 3182,
#  'threesome': 3181,
#  'three': 3180,
#  'threats': 3179,
#  'threaten': 3178,
#  'threat': 3177,
#  'thread': 3176,
#  'thousands': 3175,
#  'though': 3174,
#  'thot': 3173,
#  'tho': 3172,
#  'third': 3171,
#  'think': 3170,
#  'things': 3169,
#  'thing': 3168,
#  'thin': 3167,
#  'thieve': 3166,
#  'thick': 3165,
#  'theresa': 3164,
#  'therefore': 3163,
#  'theme': 3162,
#  'thehell': 3161,
#  'theft': 3160,
#  'thank': 3159,
#  'thailand': 3158,
#  'tha': 3157,
#  'texts': 3156,
#  'texting': 3155,
#  'text': 3154,
#  'texas': 3153,
#  'testify': 3152,
#  'test': 3151,
#  'terrorists': 3150,
#  'terrorist': 3149,
#  'terrorism': 3148,
#  'terror': 3147,
#  'territory': 3146,
#  'terrify': 3145,
#  'terrible': 3144,
#  'term': 3143,
#  'tent': 3142,
#  'tens': 3141,
#  'ten': 3140,
#  'temporary': 3139,
#  'temple': 3138,
#  'temp': 3137,
#  'tellin': 3136,
#  'tell': 3135,
#  'telegraph': 3134,
#  'teeth': 3133,
#  'teens': 3132,
#  'teen': 3131,
#  'ted': 3130,
#  'tech': 3129,
#  'tease': 3128,
#  'tear': 3127,
#  'team': 3126,
#  'teachers': 3125,
#  'teacher': 3124,
#  'teach': 3123,
#  'tbe': 3122,
#  'taylor': 3121,
#  'taxpayers': 3120,
#  'taxpayer': 3119,
#  'tax': 3118,
#  'tattoo': 3117,
#  'taste': 3116,
#  'target': 3115,
#  'tap': 3114,
#  'tanzania': 3113,
#  'talkin': 3112,
#  'talk': 3111,
#  'talent': 3110,
#  'take': 3109,
#  'tag': 3108,
#  'tackle': 3107,
#  'table': 3106,
#  'system': 3105,
#  'syrians': 3104,
#  'syrian': 3103,
#  'syria': 3102,
#  'symbols': 3101,
#  'switch': 3100,
#  'swim': 3099,
#  'sweetie': 3098,
#  'sweet': 3097,
#  'sweep': 3096,
#  'swedish': 3095,
#  'sweden': 3094,
#  'sweat': 3093,
#  'swear': 3092,
#  'swap': 3091,
#  'swamy': 3090,
#  'swamp': 3089,
#  'swallow': 3088,
#  'sustainable': 3087,
#  'suspend': 3086,
#  'suspect': 3085,
#  'survivors': 3084,
#  'survive': 3083,
#  'surround': 3082,
#  'surprise': 3081,
#  'surge': 3080,
#  'surely': 3079,
#  'sure': 3078,
#  'supreme': 3077,
#  'suppose': 3076,
#  'supporters': 3075,
#  'supporter': 3074,
#  'support': 3073,
#  'supply': 3072,
#  'super': 3071,
#  'sunglasses': 3070,
#  'sunday': 3069,
#  'sun': 3068,
#  'summit': 3067,
#  'summer': 3066,
#  'sum': 3065,
#  'suit': 3064,
#  'suicide': 3063,
#  'suh': 3062,
#  'suggest': 3061,
#  'suffer': 3060,
#  'sue': 3059,
#  'suddenly': 3058,
#  'sudden': 3057,
#  'sudanese': 3056,
#  'sudan': 3055,
#  'suck': 3054,
#  'successful': 3053,
#  'success': 3052,
#  'succeed': 3051,
#  'subway': 3050,
#  'subscribe': 3049,
#  'submit': 3048,
#  'subject': 3047,
#  'sub': 3046,
#  'style': 3045,
#  'sturgeon': 3044,
#  'stupidity': 3043,
#  'stupid': 3042,
#  'stun': 3041,
#  'stuff': 3040,
#  'study': 3039,
#  'students': 3038,
#  'student': 3037,
#  'stu': 3036,
#  'struggle': 3035,
#  'stronger': 3034,
#  'strong': 3033,
#  'stroll': 3032,
#  'stroke': 3031,
#  'strip': 3030,
#  'string': 3029,
#  'strike': 3028,
#  'strict': 3027,
#  'stretch': 3026,
#  'stress': 3025,
#  'strengthen': 3024,
#  'strength': 3023,
#  'streets': 3022,
#  'street': 3021,
#  'stream': 3020,
#  'strangers': 3019,
#  'stranger': 3018,
#  'strange': 3017,
#  'strain': 3016,
#  'straight': 3015,
#  'story': 3014,
#  'storm': 3013,
#  'stories': 3012,
#  'store': 3011,
#  'stop': 3010,
#  'stone': 3009,
#  'stock': 3008,
#  'stink': 3007,
#  'still': 3006,
#  'stick': 3005,
#  'sterile': 3004,
#  'stephen': 3003,
#  'step': 3002,
#  'stem': 3001,
#  'steal': 3000,
#  'stay': 2999,
#  'status': 2998,
#  'statue': 2997,
#  'stats': 2996,
#  'statistics': 2995,
#  'station': 2994,
#  'statement': 2993,
#  'state': 2992,
#  'start': 2991,
#  'star': 2990,
#  'standards': 2989,
#  'standard': 2988,
#  'stand': 2987,
#  'stance': 2986,
#  'stan': 2985,
#  'stamp': 2984,
#  'stake': 2983,
#  'stage': 2982,
#  'staff': 2981,
#  'stadium': 2980,
#  'stab': 2979,
#  'sri': 2978,
#  'squint': 2977,
#  'square': 2976,
#  'spur': 2975,
#  'spring': 2974,
#  'spread': 2973,
#  'spot': 2972,
#  'sport': 2971,
#  'sponsor': 2970,
#  'split': 2969,
#  'spinet': 2968,
#  'spin': 2967,
#  'spice': 2966,
#  'spend': 2965,
#  'speed': 2964,
#  'speech': 2963,
#  'specific': 2962,
#  'species': 2961,
#  'specially': 2960,
#  'special': 2959,
#  'speaker': 2958,
#  'speak': 2957,
#  'sparkle': 2956,
#  'spark': 2955,
#  'spank': 2954,
#  'spanish': 2953,
#  'spain': 2952,
#  'space': 2951,
#  'sovereignty': 2950,
#  'sovereign': 2949,
#  'southern': 2948,
#  'south': 2947,
#  'source': 2946,
#  'sound': 2945,
#  'sort': 2944,
#  'sorry': 2943,
#  'sop': 2942,
#  'soon': 2941,
#  'sons': 2940,
#  'song': 2939,
#  'son': 2938,
#  'sometimes': 2937,
#  'something': 2936,
#  'someone': 2935,
#  'somebody': 2934,
#  'somalis': 2933,
#  'somalia': 2932,
#  'somali': 2931,
#  'solve': 2930,
#  'solutions': 2929,
#  'solution': 2928,
#  'solidarity': 2927,
#  'solid': 2926,
#  'sole': 2925,
#  'soldier': 2924,
#  'sol': 2923,
#  'soil': 2922,
#  'soft': 2921,
#  'society': 2920,
#  'socialwelfare': 2919,
#  'socialists': 2918,
#  'socialist': 2917,
#  'socialism': 2916,
#  'social': 2915,
#  'soccer': 2914,
#  'soar': 2913,
#  'snowflakes': 2912,
#  'snowflake': 2911,
#  'sneak': 2910,
#  'snapchat': 2909,
#  'snap': 2908,
#  'snake': 2907,
#  'smugglers': 2906,
#  'smuggle': 2905,
#  'smoke': 2904,
#  'smith': 2903,
#  'smirk': 2902,
#  'smile': 2901,
#  'smell': 2900,
#  'smear': 2899,
#  'smarter': 2898,
#  'smart': 2897,
#  'small': 2896,
#  'smack': 2895,
#  'slutty': 2894,
#  'sluts': 2893,
#  'slut': 2892,
#  'slum': 2891,
#  'slow': 2890,
#  'slovenian': 2889,
#  'slippery': 2888,
#  'slip': 2887,
#  'slightly': 2886,
#  'slide': 2885,
#  'sleep': 2884,
#  'slavery': 2883,
#  'slave': 2882,
#  'slap': 2881,
#  'slam': 2880,
#  'slag': 2879,
#  'sky': 2878,
#  'skull': 2877,
#  'skip': 2876,
#  'skinny': 2875,
#  'skin': 2874,
#  'skills': 2873,
#  'skilled': 2872,
#  'skank': 2871,
#  'skag': 2870,
#  'size': 2869,
#  'six': 2868,
#  'situations': 2867,
#  'situation': 2866,
#  'sit': 2865,
#  'sisters': 2864,
#  'sister': 2863,
#  'sissy': 2862,
#  'sis': 2861,
#  'sir': 2860,
#  'sink': 2859,
#  'single': 2858,
#  'sing': 2857,
#  'since': 2856,
#  'simply': 2855,
#  'simple': 2854,
#  'similar': 2853,
#  'silver': 2852,
#  'silly': 2851,
#  'silent': 2850,
#  'silence': 2849,
#  'significant': 2848,
#  'signal': 2847,
#  'sign': 2846,
#  'sight': 2845,
#  'sideways': 2844,
#  'side': 2843,
#  'sick': 2842,
#  'sicily': 2841,
#  'shutdown': 2840,
#  'shut': 2839,
#  'shrug': 2838,
#  'show': 2837,
#  'shove': 2836,
#  'shoutout': 2835,
#  'shout': 2834,
#  'shots': 2833,
#  'shorter': 2832,
#  'short': 2831,
#  'shore': 2830,
#  'shoppers': 2829,
#  'shop': 2828,
#  'shoot': 2827,
#  'shoe': 2826,
#  'shock': 2825,
#  'shitty': 2824,
#  'shithole': 2823,
#  'shit': 2822,
#  'shirt': 2821,
#  'ship': 2820,
#  'shine': 2819,
#  'shin': 2818,
#  'shimmy': 2817,
#  'shift': 2816,
#  'sheriff': 2815,
#  'shelter': 2814,
#  'sharpen': 2813,
#  'sharia': 2812,
#  'share': 2811,
#  'shameless': 2810,
#  'shameful': 2809,
#  'shame': 2808,
#  'sham': 2807,
#  'shall': 2806,
#  'shake': 2805,
#  'sexy': 2804,
#  'sexually': 2803,
#  'sexual': 2802,
#  'sexist': 2801,
#  'sexism': 2800,
#  'sex': 2799,
#  'several': 2798,
#  'settle': 2797,
#  'set': 2796,
#  'sessions': 2795,
#  'servo': 2794,
#  'service': 2793,
#  'serve': 2792,
#  'seriously': 2791,
#  'serious': 2790,
#  'series': 2789,
#  'sept': 2788,
#  'separation': 2787,
#  'separate': 2786,
#  'sentence': 2785,
#  'sense': 2784,
#  'send': 2783,
#  'senator': 2782,
#  'senate': 2781,
#  'sell': 2780,
#  'selfish': 2779,
#  'self': 2778,
#  'seem': 2777,
#  'seekers': 2776,
#  'seek': 2775,
#  'see': 2774,
#  'security': 2773,
#  'secure': 2772,
#  'secret': 2771,
#  'second': 2770,
#  'seat': 2769,
#  'season': 2768,
#  'search': 2767,
#  'seal': 2766,
#  'sea': 2765,
#  'scumbags': 2764,
#  'scumbag': 2763,
#  'scum': 2762,
#  'screw': 2761,
#  'screen': 2760,
#  'scream': 2759,
#  'scout': 2758,
#  'scots': 2757,
#  'scotland': 2756,
#  'science': 2755,
#  'school': 2754,
#  'scheme': 2753,
#  'schedule': 2752,
#  'scene': 2751,
#  'scar': 2750,
#  'scam': 2749,
#  'scale': 2748,
#  'say': 2747,
#  'saw': 2746,
#  'save': 2745,
#  'savage': 2744,
#  'saudi': 2743,
#  'saturday': 2742,
#  'sara': 2741,
#  'sandwich': 2740,
#  'sanctuary': 2739,
#  'san': 2738,
#  'salve': 2737,
#  'sake': 2736,
#  'safety': 2735,
#  'safe': 2734,
#  'sadly': 2733,
#  'sad': 2732,
#  'sacred': 2731,
#  'sack': 2730,
#  'sabata': 2729,
#  'sa': 2728,
#  'ryan': 2727,
#  'russian': 2726,
#  'russia': 2725,
#  'rush': 2724,
#  'run': 2723,
#  'rule': 2722,
#  'ruin': 2721,
#  'rude': 2720,
#  'rub': 2719,
#  'row': 2718,
#  'route': 2717,
#  'round': 2716,
#  'rot': 2715,
#  'root': 2714,
#  'room': 2713,
#  'roll': 2712,
#  'role': 2711,
#  'rohingya': 2710,
#  'rock': 2709,
#  'rob': 2708,
#  'roast': 2707,
#  'roam': 2706,
#  'roads': 2705,
#  'road': 2704,
#  'risk': 2703,
#  'rise': 2702,
#  'rip': 2701,
#  'riot': 2700,
#  'ring': 2699,
#  'right': 2698,
#  'ridiculous': 2697,
#  'ride': 2696,
#  'rid': 2695,
#  'rich': 2694,
#  'reward': 2693,
#  'revoke': 2692,
#  'review': 2691,
#  'reveal': 2690,
#  'reuters': 2689,
#  'reunite': 2688,
#  'reunification': 2687,
#  'retweet': 2686,
#  'return': 2685,
#  'retire': 2684,
#  'retard': 2683,
#  'result': 2682,
#  'restore': 2681,
#  'restaurant': 2680,
#  'rest': 2679,
#  'responsible': 2678,
#  'responsibility': 2677,
#  'response': 2676,
#  'respond': 2675,
#  'respect': 2674,
#  'resources': 2673,
#  'resistance': 2672,
#  'resist': 2671,
#  'resign': 2670,
#  'residents': 2669,
#  'residency': 2668,
#  'resettlement': 2667,
#  'resettle': 2666,
#  'research': 2665,
#  'rescue': 2664,
#  'require': 2663,
#  'request': 2662,
#  'republicans': 2661,
#  'republican': 2660,
#  'republic': 2659,
#  'representative': 2658,
#  'represent': 2657,
#  'reportedly': 2656,
#  'report': 2655,
#  'reply': 2654,
#  'replacement': 2653,
#  'replace': 2652,
#  'repeat': 2651,
#  'repatriation': 2650,
#  'repatriate': 2649,
#  'rep': 2648,
#  'renewal': 2647,
#  'renew': 2646,
#  'remove': 2645,
#  'reminder': 2644,
#  'remind': 2643,
#  'remember': 2642,
#  'remain': 2641,
#  'rely': 2640,
#  'religious': 2639,
#  'religion': 2638,
#  'relieve': 2637,
#  'relief': 2636,
#  'relevant': 2635,
#  'release': 2634,
#  'relationships': 2633,
#  'relationship': 2632,
#  'reject': 2631,
#  'reign': 2630,
#  'regular': 2629,
#  'registration': 2628,
#  'register': 2627,
#  'region': 2626,
#  'regime': 2625,
#  'regardless': 2624,
#  'regard': 2623,
#  'refuse': 2622,
#  'refugees': 2621,
#  'refugee': 2620,
#  'refuge': 2619,
#  'reform': 2618,
#  'refer': 2617,
#  'reduce': 2616,
#  'red': 2615,
#  'record': 2614,
#  'recognize': 2613,
#  'recently': 2612,
#  'recent': 2611,
#  'receive': 2610,
#  'rebuild': 2609,
#  'reason': 2608,
#  'really': 2607,
#  'realize': 2606,
#  'reality': 2605,
#  'real': 2604,
#  'ready': 2603,
#  'read': 2602,
#  'reaction': 2601,
#  'reach': 2600,
#  'rather': 2599,
#  'rate': 2598,
#  'rat': 2597,
#  'rare': 2596,
#  'rapper': 2595,
#  'rapists': 2594,
#  'rapist': 2593,
#  'rapidly': 2592,
#  'rape': 2591,
#  'rap': 2590,
#  'rant': 2589,
#  'range': 2588,
#  'random': 2587,
#  'rampant': 2586,
#  'ram': 2585,
#  'rally': 2584,
#  'raise': 2583,
#  'raid': 2582,
#  'rage': 2581,
#  'rag': 2580,
#  'radio': 2579,
#  'radical': 2578,
#  'racists': 2577,
#  'racist': 2576,
#  'racism': 2575,
#  'racial': 2574,
#  'race': 2573,
#  'rabbit': 2572,
#  'quote': 2571,
#  'quite': 2570,
#  'quit': 2569,
#  'quiet': 2568,
#  'quickly': 2567,
#  'quick': 2566,
#  'question': 2565,
#  'queen': 2564,
#  'quarter': 2563,
#  'qualify': 2562,
#  'putin': 2561,
#  'put': 2560,
#  'pussy': 2559,
#  'push': 2558,
#  'pursue': 2557,
#  'purpose': 2556,
#  'purge': 2555,
#  'pure': 2554,
#  'puppets': 2553,
#  'punish': 2552,
#  'punch': 2551,
#  'pump': 2550,
#  'pull': 2549,
#  'publish': 2548,
#  'public': 2547,
#  'psycho': 2546,
#  'provide': 2545,
#  'prove': 2544,
#  'proud': 2543,
#  'protesters': 2542,
#  'protest': 2541,
#  'protection': 2540,
#  'protect': 2539,
#  'prostitute': 2538,
#  'prosecute': 2537,
#  'propose': 2536,
#  'proposal': 2535,
#  'property': 2534,
#  'properly': 2533,
#  'proper': 2532,
#  'propaganda': 2531,
#  'proof': 2530,
#  'pronounce': 2529,
#  'promote': 2528,
#  'promise': 2527,
#  'prolong': 2526,
#  'project': 2525,
#  'progressive': 2524,
#  'programme': 2523,
#  'program': 2522,
#  'profit': 2521,
#  'profile': 2520,
#  'professor': 2519,
#  'professional': 2518,
#  'produce': 2517,
#  'process': 2516,
#  'problems': 2515,
#  'problematic': 2514,
#  'problem': 2513,
#  'probe': 2512,
#  'probably': 2511,
#  'pro': 2510,
#  'prize': 2509,
#  'privilege': 2508,
#  'private': 2507,
#  'prisons': 2506,
#  'prison': 2505,
#  'priorities': 2504,
#  'prior': 2503,
#  'print': 2502,
#  'principles': 2501,
#  'princess': 2500,
#  ...}

# %%
dict(sorted(spanish_vectorizer.vocabulary_.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'zona': 3499,
#  'zero': 3498,
#  'zapatera': 3497,
#  'zagreb': 3496,
#  'youtube': 3495,
#  'yo': 3494,
#  'yemen': 3493,
#  'yaaah': 3492,
#  'ya': 3491,
#  'xu': 3490,
#  'xenofobia': 3489,
#  'wow': 3488,
#  'woman': 3487,
#  'win': 3486,
#  'widen': 3485,
#  'white': 3484,
#  'whatsapp': 3483,
#  'wey': 3482,
#  'war': 3481,
#  'want': 3480,
#  'wagon': 3479,
#  'waaaay': 3478,
#  'vulgar': 3477,
#  'vuelve': 3476,
#  'vuelva': 3475,
#  'vuelta': 3474,
#  'voz': 3473,
#  'voy': 3472,
#  'vox': 3471,
#  'voter': 3470,
#  'vote': 3469,
#  'votans': 3468,
#  'vos': 3467,
#  'vomitando': 3466,
#  'vomit': 3465,
#  'volvos': 3464,
#  'volvo': 3463,
#  'volver': 3462,
#  'volga': 3461,
#  'volar': 3460,
#  'voland': 3459,
#  'voces': 3458,
#  'vivo': 3457,
#  'vivir': 3456,
#  'vivimos': 3455,
#  'vivien': 3454,
#  'vives': 3453,
#  'vive': 3452,
#  'viva': 3451,
#  'vital': 3450,
#  'visto': 3449,
#  'viste': 3448,
#  'vista': 3447,
#  'visitor': 3446,
#  'visita': 3445,
#  'visit': 3444,
#  'visa': 3443,
#  'virgen': 3442,
#  'violin': 3441,
#  'violentamente': 3440,
#  'violent': 3439,
#  'violence': 3438,
#  'viole': 3437,
#  'violators': 3436,
#  'violator': 3435,
#  'violations': 3434,
#  'violation': 3433,
#  'violate': 3432,
#  'viola': 3431,
#  'vino': 3430,
#  'vines': 3429,
#  'vincenzo': 3428,
#  'vince': 3427,
#  'villa': 3426,
#  'viernes': 3425,
#  'vienen': 3424,
#  'viene': 3423,
#  'viejo': 3422,
#  'vieja': 3421,
#  'videos': 3420,
#  'video': 3419,
#  'vida': 3418,
#  'victoria': 3417,
#  'victims': 3416,
#  'victim': 3415,
#  'vibora': 3414,
#  'viaje': 3413,
#  'via': 3412,
#  'vi': 3411,
#  'vez': 3410,
#  'veto': 3409,
#  'vete': 3408,
#  'vestiges': 3407,
#  'vestige': 3406,
#  'vestido': 3405,
#  'ves': 3404,
#  'verte': 3403,
#  'verse': 3402,
#  'vero': 3401,
#  'verification': 3400,
#  'vergüenza': 3399,
#  'verguenza': 3398,
#  'verge': 3397,
#  'verde': 3396,
#  'verdade': 3395,
#  'verdad': 3394,
#  'verbs': 3393,
#  'vera': 3392,
#  'ver': 3391,
#  'veo': 3390,
#  'ventura': 3389,
#  'ventana': 3388,
#  'vent': 3387,
#  'venir': 3386,
#  'vengo': 3385,
#  'vengan': 3384,
#  'venga': 3383,
#  'venezuela': 3382,
#  'venezolanos': 3381,
#  'venezolano': 3380,
#  'vendor': 3379,
#  'vender': 3378,
#  'vende': 3377,
#  'vend': 3376,
#  'ven': 3375,
#  'vemos': 3374,
#  'vein': 3373,
#  'vegas': 3372,
#  'vegan': 3371,
#  'vedran': 3370,
#  'veces': 3369,
#  'vayas': 3368,
#  'vayan': 3367,
#  'vaya': 3366,
#  'vasco': 3365,
#  'vas': 3364,
#  'vary': 3363,
#  'various': 3362,
#  'vanilla': 3361,
#  'vandenberghe': 3360,
#  'van': 3359,
#  'vamos': 3358,
#  'value': 3357,
#  'valpariso': 3356,
#  'valor': 3355,
#  'valet': 3354,
#  'vales': 3353,
#  'valencian': 3352,
#  'valencia': 3351,
#  'vale': 3350,
#  'vais': 3349,
#  'vain': 3348,
#  'vaginas': 3347,
#  'vacation': 3346,
#  'vacate': 3345,
#  'vaca': 3344,
#  'va': 3343,
#  'uy': 3342,
#  'utilize': 3341,
#  'ustedes': 3340,
#  'usted': 3339,
#  'uso': 3338,
#  'use': 3337,
#  'usar': 3336,
#  'usa': 3335,
#  'us': 3334,
#  'urine': 3333,
#  'urgent': 3332,
#  'urge': 3331,
#  'uproar': 3330,
#  'unos': 3329,
#  'uno': 3328,
#  'universidad': 3327,
#  'universe': 3326,
#  'universal': 3325,
#  'units': 3324,
#  'unique': 3323,
#  'union': 3322,
#  'unico': 3321,
#  'unga': 3320,
#  'undo': 3319,
#  'unas': 3318,
#  'una': 3317,
#  'un': 3316,
#  'ultra': 3315,
#  'ultimo': 3314,
#  'ultima': 3313,
#  'ue': 3312,
#  'ubicación': 3311,
#  'u': 3310,
#  'título': 3309,
#  'twos': 3308,
#  'two': 3307,
#  'twitter': 3306,
#  'tweet': 3305,
#  'tuyo': 3304,
#  'tuya': 3303,
#  'tuve': 3302,
#  'tuscan': 3301,
#  'tus': 3300,
#  'turista': 3299,
#  'tuo': 3298,
#  'tundra': 3297,
#  'tudor': 3296,
#  'tub': 3295,
#  'tu': 3294,
#  'tryto': 3293,
#  'trump': 3292,
#  'troll': 3291,
#  'trocar': 3290,
#  'triste': 3289,
#  'tribunal': 3288,
#  'tres': 3287,
#  'tren': 3286,
#  'tremendo': 3285,
#  'tree': 3284,
#  'trayendo': 3283,
#  'travis': 3282,
#  'travesty': 3281,
#  'trata': 3280,
#  'trash': 3279,
#  'trap': 3278,
#  'transform': 3277,
#  'tranquil': 3276,
#  'traje': 3275,
#  'traitor': 3274,
#  'traian': 3273,
#  'trager': 3272,
#  'traer': 3271,
#  'traen': 3270,
#  'trae': 3269,
#  'trade': 3268,
#  'track': 3267,
#  'trace': 3266,
#  'trabajo': 3265,
#  'trabajar': 3264,
#  'trabajando': 3263,
#  'trabajadores': 3262,
#  'trabaja': 3261,
#  'toy': 3260,
#  'tourism': 3259,
#  'totalmente': 3258,
#  'total': 3257,
#  'torture': 3256,
#  'torres': 3255,
#  'toro': 3254,
#  'tornados': 3253,
#  'tornado': 3252,
#  'torino': 3251,
#  'toque': 3250,
#  'topic': 3249,
#  'top': 3248,
#  'tonya': 3247,
#  'tonto': 3246,
#  'tonterías': 3245,
#  'tonterias': 3244,
#  'tone': 3243,
#  'tomato': 3242,
#  'tomas': 3241,
#  'tomar': 3240,
#  'toma': 3239,
#  'todos': 3238,
#  'todo': 3237,
#  'todavía': 3236,
#  'todas': 3235,
#  'toda': 3234,
#  'tock': 3233,
#  'toca': 3232,
#  'tiro': 3231,
#  'tire': 3230,
#  'tipo': 3229,
#  'tio': 3228,
#  'time': 3227,
#  'tierra': 3226,
#  'tienes': 3225,
#  'tienen': 3224,
#  'tiene': 3223,
#  'tienda': 3222,
#  'tiempo': 3221,
#  'tie': 3220,
#  'tibia': 3219,
#  'tian': 3218,
#  'tia': 3217,
#  'ti': 3216,
#  'texas': 3215,
#  'tetas': 3214,
#  'test': 3213,
#  'terrorists': 3212,
#  'terrorist': 3211,
#  'terrorism': 3210,
#  'territory': 3209,
#  'territories': 3208,
#  'terrible': 3207,
#  'terminar': 3206,
#  'terminal': 3205,
#  'term': 3204,
#  'tequila': 3203,
#  'tepid': 3202,
#  'tens': 3201,
#  'tennis': 3200,
#  'tenido': 3199,
#  'tenia': 3198,
#  'tengo': 3197,
#  'tengas': 3196,
#  'tengan': 3195,
#  'tenga': 3194,
#  'tenes': 3193,
#  'tener': 3192,
#  'tenemos': 3191,
#  'tendrils': 3190,
#  'tendre': 3189,
#  'tender': 3188,
#  'tendency': 3187,
#  'tend': 3186,
#  'ten': 3185,
#  'temporary': 3184,
#  'temporal': 3183,
#  'tell': 3182,
#  'telefono': 3181,
#  'tele': 3180,
#  'teas': 3179,
#  'tear': 3178,
#  'team': 3177,
#  'tea': 3176,
#  'te': 3175,
#  'taste': 3174,
#  'tas': 3173,
#  'tartar': 3172,
#  'tartan': 3171,
#  'target': 3170,
#  'tarde': 3169,
#  'taquitos': 3168,
#  'taqueria': 3167,
#  'taoists': 3166,
#  'tanto': 3165,
#  'tanta': 3164,
#  'tango': 3163,
#  'tan': 3162,
#  'tampon': 3161,
#  'tambien': 3160,
#  'tamales': 3159,
#  'talent': 3158,
#  'tal': 3157,
#  'tacos': 3156,
#  'taco': 3155,
#  'table': 3154,
#  'ta': 3153,
#  'syria': 3152,
#  'susan': 3151,
#  'sus': 3150,
#  'sure': 3149,
#  'sur': 3148,
#  'supuesto': 3147,
#  'supuestamente': 3146,
#  'supongo': 3145,
#  'supercar': 3144,
#  'super': 3143,
#  'suntan': 3142,
#  'sundial': 3141,
#  'sumo': 3140,
#  'sultan': 3139,
#  'suit': 3138,
#  'suicide': 3137,
#  'sugar': 3136,
#  'sufrir': 3135,
#  'sufrimiento': 3134,
#  'suficiente': 3133,
#  'suerte': 3132,
#  'sueno': 3131,
#  'suede': 3130,
#  'sudoku': 3129,
#  'sudah': 3128,
#  'sudacas': 3127,
#  'suckas': 3126,
#  'subvenciones': 3125,
#  'subsaharianos': 3124,
#  'subsahariano': 3123,
#  'subnormal': 3122,
#  'subir': 3121,
#  'sube': 3120,
#  'suba': 3119,
#  'sub': 3118,
#  'su': 3117,
#  'studios': 3116,
#  'studio': 3115,
#  'still': 3114,
#  'statues': 3113,
#  'star': 3112,
#  'sport': 3111,
#  'spare': 3110,
#  'spain': 3109,
#  'soy': 3108,
#  'sos': 3107,
#  'sorte': 3106,
#  'sorta': 3105,
#  'sort': 3104,
#  'soprano': 3103,
#  'sonriente': 3102,
#  'sonriendo': 3101,
#  'son': 3100,
#  'somos': 3099,
#  'solution': 3098,
#  'solucionar': 3097,
#  'solo': 3096,
#  'solidarity': 3095,
#  'solidaridad': 3094,
#  'soldados': 3093,
#  'soldado': 3092,
#  'solar': 3091,
#  'solamente': 3090,
#  'sola': 3089,
#  'sol': 3088,
#  'sois': 3087,
#  'sofrito': 3086,
#  'sofa': 3085,
#  'soda': 3084,
#  'socio': 3083,
#  'societal': 3082,
#  'socials': 3081,
#  'socialite': 3080,
#  'socialists': 3079,
#  'socialist': 3078,
#  'social': 3077,
#  'sobre': 3076,
#  'sob': 3075,
#  'slide': 3074,
#  'situations': 3073,
#  'situation': 3072,
#  'sit': 3071,
#  'sister': 3070,
#  'sirvienta': 3069,
#  'sirius': 3068,
#  'siri': 3067,
#  'siren': 3066,
#  'siquiera': 3065,
#  'sinvergüenza': 3064,
#  'sino': 3063,
#  'sinceramente': 3062,
#  'sin': 3061,
#  'simplement': 3060,
#  'simple': 3059,
#  'similar': 3058,
#  'simi': 3057,
#  'silo': 3056,
#  'silla': 3055,
#  'silencio': 3054,
#  'siguiente': 3053,
#  'sigues': 3052,
#  'sigue': 3051,
#  'signo': 3050,
#  'significant': 3049,
#  'significa': 3048,
#  'sign': 3047,
#  'siete': 3046,
#  'siesta': 3045,
#  'siento': 3044,
#  'sientes': 3043,
#  'siente': 3042,
#  'siempre': 3041,
#  'sido': 3040,
#  'side': 3039,
#  'si': 3038,
#  'show': 3037,
#  'shelton': 3036,
#  'shado': 3035,
#  'sexualmente': 3034,
#  'sexualize': 3033,
#  'sexual': 3032,
#  'sexo': 3031,
#  'sevillista': 3030,
#  'sevilla': 3029,
#  'servo': 3028,
#  'service': 3027,
#  'serve': 3026,
#  'serrano': 3025,
#  'serio': 3024,
#  'series': 3023,
#  'serie': 3022,
#  'seria': 3021,
#  'sera': 3020,
#  'ser': 3019,
#  'sequitos': 3018,
#  'sequitas': 3017,
#  'september': 3016,
#  'separatists': 3015,
#  'separate': 3014,
#  'sepa': 3013,
#  'sentir': 3012,
#  'senores': 3011,
#  'senora': 3010,
#  'senor': 3009,
#  'semen': 3008,
#  'semejante': 3007,
#  'semana': 3006,
#  'seldom': 3005,
#  'seiza': 3004,
#  'seis': 3003,
#  'seguro': 3002,
#  'seguridad': 3001,
#  'segura': 3000,
#  'segundo': 2999,
#  'seguir': 2998,
#  'seguidores': 2997,
#  'segue': 2996,
#  'see': 2995,
#  'secula': 2994,
#  'section': 2993,
#  'secretary': 2992,
#  'secret': 2991,
#  'seco': 2990,
#  'seas': 2989,
#  'sean': 2988,
#  'seal': 2987,
#  'sea': 2986,
#  'se': 2985,
#  'score': 2984,
#  'scepter': 2983,
#  'scene': 2982,
#  'scare': 2981,
#  'scar': 2980,
#  'scan': 2979,
#  'say': 2978,
#  'sauna': 2977,
#  'satan': 2976,
#  'sarcoma': 2975,
#  'sara': 2974,
#  'santos': 2973,
#  'santino': 2972,
#  'santi': 2971,
#  'santa': 2970,
#  'sanitation': 2969,
#  'sangre': 2968,
#  'sandal': 2967,
#  'sanchez': 2966,
#  'san': 2965,
#  'samosa': 2964,
#  'salvo': 2963,
#  'salve': 2962,
#  'salvaje': 2961,
#  'salvage': 2960,
#  'salvador': 2959,
#  'salute': 2958,
#  'saludando': 2957,
#  'salud': 2956,
#  'salton': 2955,
#  'salt': 2954,
#  'salsa': 2953,
#  'salon': 2952,
#  'saliva': 2951,
#  'salir': 2950,
#  'salio': 2949,
#  'salim': 2948,
#  'saliendo': 2947,
#  'salgan': 2946,
#  'sales': 2945,
#  'sale': 2944,
#  'salads': 2943,
#  'salad': 2942,
#  'sais': 2941,
#  'sahara': 2940,
#  'sacramento': 2939,
#  'sack': 2938,
#  'saboreando': 2937,
#  'sabiduría': 2936,
#  'sabian': 2935,
#  'sabia': 2934,
#  'sabes': 2933,
#  'saber': 2932,
#  'sabe': 2931,
#  'ryo': 2930,
#  'russia': 2929,
#  'rumba': 2928,
#  'rule': 2927,
#  'ruin': 2926,
#  'rubies': 2925,
#  'rubia': 2924,
#  'ruben': 2923,
#  'roto': 2922,
#  'rotate': 2921,
#  'rota': 2920,
#  'rostro': 2919,
#  'rope': 2918,
#  'ropa': 2917,
#  'rompers': 2916,
#  'romper': 2915,
#  'romp': 2914,
#  'romanos': 2913,
#  'roman': 2912,
#  'rolando': 2911,
#  'rojo': 2910,
#  'rodrigo': 2909,
#  'rodian': 2908,
#  'rocco': 2907,
#  'robo': 2906,
#  'roban': 2905,
#  'rob': 2904,
#  'roar': 2903,
#  'road': 2902,
#  'rivera': 2901,
#  'rival': 2900,
#  'rise': 2899,
#  'risa': 2898,
#  'riqueza': 2897,
#  'riend': 2896,
#  'ridicule': 2895,
#  'rid': 2894,
#  'rico': 2893,
#  'rican': 2892,
#  'rica': 2891,
#  'reyna': 2890,
#  'reyes': 2889,
#  'rey': 2888,
#  'reviens': 2887,
#  'revert': 2886,
#  'reverse': 2885,
#  'reveal': 2884,
#  'rev': 2883,
#  'return': 2882,
#  'retros': 2881,
#  'retrasado': 2880,
#  'retire': 2879,
#  'retina': 2878,
#  'resume': 2877,
#  'result': 2876,
#  'resto': 2875,
#  'restate': 2874,
#  'respuesta': 2873,
#  'responsable': 2872,
#  'responsabilidad': 2871,
#  'respond': 2870,
#  'respire': 2869,
#  'respecter': 2868,
#  'respect': 2867,
#  'resist': 2866,
#  'resign': 2865,
#  'resent': 2864,
#  'rescatados': 2863,
#  'rescan': 2862,
#  'require': 2861,
#  'repugnant': 2860,
#  'republican': 2859,
#  'repression': 2858,
#  'representante': 2857,
#  'represent': 2856,
#  'reporter': 2855,
#  'report': 2854,
#  'repeat': 2853,
#  'repast': 2852,
#  'repartee': 2851,
#  'rent': 2850,
#  'remix': 2849,
#  'remedios': 2848,
#  'religions': 2847,
#  'religion': 2846,
#  'relation': 2845,
#  'rein': 2844,
#  'reiben': 2843,
#  'regular': 2842,
#  'regress': 2841,
#  'regresar': 2840,
#  'regimen': 2839,
#  'regale': 2838,
#  'regal': 2837,
#  'refugiados': 2836,
#  'refugees': 2835,
#  'refuge': 2834,
#  'referirse': 2833,
#  'refer': 2832,
#  'redo': 2831,
#  'recuperate': 2830,
#  'recuerdo': 2829,
#  'recover': 2828,
#  'record': 2827,
#  'reclaimer': 2826,
#  'reckon': 2825,
#  'reciter': 2824,
#  'recite': 2823,
#  'recipe': 2822,
#  'recess': 2821,
#  'rear': 2820,
#  'realmente': 2819,
#  'realize': 2818,
#  'real': 2817,
#  'reaffirm': 2816,
#  'razon': 2815,
#  'raza': 2814,
#  'ray': 2813,
#  'rater': 2812,
#  'rate': 2811,
#  'rata': 2810,
#  'rat': 2809,
#  'raro': 2808,
#  'rapido': 2807,
#  'raoul': 2806,
#  'ramos': 2805,
#  'ramona': 2804,
#  'ramiro': 2803,
#  'ramble': 2802,
#  'rail': 2801,
#  'rag': 2800,
#  'radio': 2799,
#  'radical': 2798,
#  'radiant': 2797,
#  'racists': 2796,
#  'racist': 2795,
#  'racism': 2794,
#  'rabid': 2793,
#  'rabe': 2792,
#  'quiz': 2791,
#  'quite': 2790,
#  'quitarnos': 2789,
#  'quita': 2788,
#  'quit': 2787,
#  'quisiera': 2786,
#  'quinn': 2785,
#  'quiet': 2784,
#  'quiero': 2783,
#  'quieres': 2782,
#  'quieren': 2781,
#  'quiere': 2780,
#  'quien': 2779,
#  'qui': 2778,
#  'queue': 2777,
#  'queso': 2776,
#  'query': 2775,
#  'quero': 2774,
#  'queriendo': 2773,
#  'querida': 2772,
#  'queria': 2771,
#  'queres': 2770,
#  'querer': 2769,
#  'queremos': 2768,
#  'queen': 2767,
#  'quedo': 2766,
#  'quedarte': 2765,
#  'quedar': 2764,
#  'quedan': 2763,
#  'queda': 2762,
#  'que': 2761,
#  'quantas': 2760,
#  'quando': 2759,
#  'puñetero': 2758,
#  'puñetazo': 2757,
#  'putrid': 2756,
#  'putos': 2755,
#  'puto': 2754,
#  'putit': 2753,
#  'putin': 2752,
#  'putea': 2751,
#  'putas': 2750,
#  'puta': 2749,
#  'pushers': 2748,
#  'push': 2747,
#  'puro': 2746,
#  'puritanism': 2745,
#  'pure': 2744,
#  'pura': 2743,
#  'punto': 2742,
#  'punta': 2741,
#  'pulsars': 2740,
#  'pulsar': 2739,
#  'pues': 2738,
#  'puerto': 2737,
#  'puerta': 2736,
#  'puedo': 2735,
#  'puedes': 2734,
#  'pueden': 2733,
#  'puede': 2732,
#  'pueda': 2731,
#  'pueblo': 2730,
#  'pudiera': 2729,
#  'publico': 2728,
#  'publicize': 2727,
#  'publican': 2726,
#  "public's": 2725,
#  'public': 2724,
#  'pruebas': 2723,
#  'proximo': 2722,
#  'proxima': 2721,
#  'provoker': 2720,
#  'provocation': 2719,
#  'provocarme': 2718,
#  'provocando': 2717,
#  'provocadora': 2716,
#  'provincial': 2715,
#  'prove': 2714,
#  'protest': 2713,
#  'protection': 2712,
#  'protect': 2711,
#  'prostitute': 2710,
#  'proprio': 2709,
#  'propos': 2708,
#  'proper': 2707,
#  'pronto': 2706,
#  'promoter': 2705,
#  'promo': 2704,
#  'prohibit': 2703,
#  'progress': 2702,
#  'program': 2701,
#  'professionals': 2700,
#  'professional': 2699,
#  'products': 2698,
#  'production': 2697,
#  'product': 2696,
#  'produce': 2695,
#  'process': 2694,
#  'problemas': 2693,
#  'problema': 2692,
#  'pro': 2691,
#  'privilege': 2690,
#  'prision': 2689,
#  'prioridad': 2688,
#  'print': 2687,
#  'primo': 2686,
#  'primers': 2685,
#  'primero': 2684,
#  'primera': 2683,
#  'primer': 2682,
#  'primary': 2681,
#  'prima': 2680,
#  'priest': 2679,
#  'pri': 2678,
#  'previa': 2677,
#  'pretend': 2676,
#  'press': 2675,
#  'preso': 2674,
#  'presidente': 2673,
#  'presento': 2672,
#  'presenta': 2671,
#  'present': 2670,
#  'presence': 2669,
#  'prepare': 2668,
#  'preparando': 2667,
#  'preocupante': 2666,
#  'preoccupy': 2665,
#  'prendre': 2664,
#  'prender': 2663,
#  'prenda': 2662,
#  'premo': 2661,
#  'preguntas': 2660,
#  'prefer': 2659,
#  'precursor': 2658,
#  'preciso': 2657,
#  'precisa': 2656,
#  'precis': 2655,
#  'precious': 2654,
#  'post': 2653,
#  'positron': 2652,
#  'pose': 2651,
#  'pos': 2650,
#  'portuguese': 2649,
#  'porter': 2648,
#  'portal': 2647,
#  'porta': 2646,
#  'port': 2645,
#  'porque': 2644,
#  'porno': 2643,
#  'porfavor': 2642,
#  'pore': 2641,
#  'por': 2640,
#  'poquito': 2639,
#  'populism': 2638,
#  'popular': 2637,
#  'poor': 2636,
#  'poo': 2635,
#  'ponte': 2634,
#  'ponied': 2633,
#  'pongo': 2632,
#  'pongal': 2631,
#  'ponga': 2630,
#  'ponerte': 2629,
#  'poner': 2628,
#  'pone': 2627,
#  'pon': 2626,
#  'políticamente': 2625,
#  'poll': 2624,
#  'politicos': 2623,
#  'politico': 2622,
#  'political': 2621,
#  'policies': 2620,
#  'policia': 2619,
#  'poem': 2618,
#  'podria': 2617,
#  'poderia': 2616,
#  'poder': 2615,
#  'podemos': 2614,
#  'podemitas': 2613,
#  'pod': 2612,
#  'pocus': 2611,
#  'poco': 2610,
#  'poca': 2609,
#  'pobre': 2608,
#  'población': 2607,
#  'po': 2606,
#  'plus': 2605,
#  'plena': 2604,
#  'pleas': 2603,
#  'plea': 2602,
#  'plazas': 2601,
#  'plaza': 2600,
#  'playa': 2599,
#  'play': 2598,
#  'plata': 2597,
#  'plat': 2596,
#  'plantas': 2595,
#  'planeta': 2594,
#  'plan': 2593,
#  'placer': 2592,
#  'piss': 2591,
#  'pirate': 2590,
#  'pique': 2589,
#  'pinter': 2588,
#  'pint': 2587,
#  'ping': 2586,
#  'pinche': 2585,
#  'pinch': 2584,
#  'pinata': 2583,
#  'pina': 2582,
#  'pin': 2581,
#  'pimiento': 2580,
#  'pilot': 2579,
#  'pills': 2578,
#  'pillar': 2577,
#  'pile': 2576,
#  'pig': 2575,
#  'pieta': 2574,
#  'pies': 2573,
#  'piernas': 2572,
#  'pierce': 2571,
#  'pienso': 2570,
#  'piensas': 2569,
#  'piedras': 2568,
#  'piedra': 2567,
#  'piece': 2566,
#  'pie': 2565,
#  'pide': 2564,
#  'pick': 2563,
#  'picadillo': 2562,
#  'piano': 2561,
#  'photo': 2560,
#  'phone': 2559,
#  'pezzo': 2558,
#  'petra': 2557,
#  'pesto': 2556,
#  'pesos': 2555,
#  'pescado': 2554,
#  'personas': 2553,
#  'personalize': 2552,
#  'personal': 2551,
#  'personage': 2550,
#  'persona': 2549,
#  'person': 2548,
#  'persist': 2547,
#  'perseverance': 2546,
#  'persecution': 2545,
#  'perros': 2544,
#  'perro': 2543,
#  'perrit': 2542,
#  'perra': 2541,
#  'pero': 2540,
#  'permite': 2539,
#  'permit': 2538,
#  'permis': 2537,
#  'perla': 2536,
#  'periods': 2535,
#  'periodistas': 2534,
#  'periodista': 2533,
#  'periodic': 2532,
#  'peril': 2531,
#  'periculo': 2530,
#  'perfecto': 2529,
#  'perfectamente': 2528,
#  'perfect': 2527,
#  'perdido': 2526,
#  'perder': 2525,
#  'perche': 2524,
#  'per': 2523,
#  'pequeno': 2522,
#  'peor': 2521,
#  'pension': 2520,
#  'pense': 2519,
#  'pensativo': 2518,
#  'pensar': 2517,
#  'pensamiento': 2516,
#  'penis': 2515,
#  'pendent': 2514,
#  'pendejos': 2513,
#  'pendejo': 2512,
#  'penalty': 2511,
#  'penal': 2510,
#  'pena': 2509,
#  'pen': 2508,
#  'película': 2507,
#  'pelotudo': 2506,
#  'pelota': 2505,
#  'pelo': 2504,
#  'peligrosos': 2503,
#  'peligro': 2502,
#  'peleando': 2501,
#  'pegar': 2500,
#  ...}

# %%
import pickle

with open("./data/english_vocabulary_.pkl", "wb") as f:
    pickle.dump(english_vectorizer.get_feature_names(), f)
with open("./data/english_vocabulary_.pkl", "rb") as f:   
    english_vectorizer_features = pickle.load(f)

english_vectorizer_features
# Out:
# ['#abolishice',
#  '#americafirst',
#  '#americansfirst',
#  '#asylumseekers',
#  '#backtheblue',
#  '#bansanctuarycities',
#  '#blacktwitter',
#  '#bluewave',
#  '#borderpatrol',
#  '#boycottnfl',
#  '#boycottnike',
#  '#buildthatwall',
#  '#buildthedamnwall',
#  '#buildthewall',
#  '#buildthewallnow',
#  '#burundi',
#  '#cdnpoli',
#  '#climatechange',
#  '#closetheborders',
#  '#deathpenalty',
#  '#declassifyfisa',
#  '#deportallofthem',
#  '#deportationsequalpublicsafety',
#  '#deportillegals',
#  '#deportthemall',
#  '#donaldtrump',
#  '#drainthedeepstate',
#  '#draintheswamp',
#  '#endchainmigration',
#  '#enddaca',
#  '#endillegalbirthrightcitizenship',
#  '#endsanctuarycities',
#  '#endvisalottery',
#  '#enforceuslaws',
#  '#familiesbelongtogether',
#  '#familiesbelongtogethermarch',
#  '#favoritepresident',
#  '#feminismiscancer',
#  '#foxnews',
#  '#fridaymotivation',
#  '#greatawakening',
#  '#greencardsfordaca',
#  '#heretostay',
#  '#hostileenvironment',
#  '#humanrights',
#  '#humantrafficking',
#  '#ilgov',
#  '#illegalalien',
#  '#illegalaliens',
#  '#illegalimmigrants',
#  '#illegalimmigration',
#  '#immigrantchildren',
#  '#immigrantsareus',
#  '#immigrationreform',
#  '#jaredkushner',
#  '#keepamericagreat',
#  '#keepamericanssafe',
#  '#keepamericasafe',
#  '#keepfamiliestogether',
#  '#kindays',
#  '#liberalismisamentaldisorder',
#  '#lockherup',
#  '#lockthemup',
#  '#maledominance',
#  '#noamnesty',
#  '#nochainmigration',
#  '#nodaca',
#  '#nodacadeal',
#  '#noillegals',
#  '#nomorerefugees',
#  '#notallmen',
#  '#nrcassam',
#  '#openborders',
#  '#preventabledeath',
#  '#rednationrising',
#  '#refugeesnotwelcome',
#  '#refugeeswelcome',
#  '#rohingya',
#  '#sanctuarycities',
#  '#saturdaymorning',
#  '#secureourborder',
#  '#securetheborder',
#  '#sendthemback',
#  '#sendthemhome',
#  '#spygate',
#  '#stopimmigration',
#  '#stoptheinvasion',
#  '#theicemancometh',
#  '#thereforthevoiceless',
#  '#therismoreofthemoutthere',
#  '#trumptrain',
#  '#ucanews',
#  '#unitednations',
#  '#unitedstates',
#  '#visegrad',
#  '#voiceforthevoiceless',
#  '#votedemsout',
#  '#votered',
#  '#voteredtosaveamerica',
#  '#wakeupamerica',
#  '#walkawayfromdemocrats',
#  '#wethepeople',
#  '#wewelcomerefugees',
#  '#whitegenocide',
#  '#withrefugees',
#  '#womendisobey',
#  '#womensuck',
#  '#worldrefugeeday',
#  '#wwgwga',
#  '#yesallmen',
#  '#yesallwomen',
#  '@ajenews',
#  '@alexnowrasteh',
#  '@alyssa_milano',
#  '@amnestykenya',
#  '@amnestyslovenia',
#  '@andrewscheer',
#  '@anncoulter',
#  '@antonioguterres',
#  '@artbychristinem',
#  '@arvindkejriwal',
#  '@aviacusa',
#  '@barackobama',
#  '@barenakedislam',
#  '@bbcnews',
#  '@bd_rock',
#  '@bensasse',
#  '@benshapiro',
#  '@billfrelick',
#  '@bjpindia',
#  '@breitbartnews',
#  '@breitbarttexas',
#  '@bryn_adams',
#  '@cabreraangel',
#  '@cbcpnews',
#  '@cbsnews',
#  '@charliekirk',
#  '@chelseahandler',
#  '@chengonsol',
#  '@cnnpolitics',
#  '@corybooker',
#  '@cpc_hq',
#  '@daily_express',
#  '@daily_record',
#  '@dailycaller',
#  '@dailymailuk',
#  '@dailymirror',
#  '@dcexaminer',
#  '@dhsgov',
#  '@diamondandsilk',
#  '@donaldjtrumpjr',
#  '@drchorn_africay',
#  '@drckenya',
#  '@drudge_report',
#  '@emmanuelmacron',
#  '@ericsontina',
#  '@fairimmigration',
#  '@femfreq',
#  '@fortifyrights',
#  '@foxandfriends',
#  '@foxbusiness',
#  '@foxnews',
#  '@fuck________off',
#  '@gopleader',
#  '@hillaryclinton',
#  '@httweets',
#  '@icegov',
#  '@icmc_news',
#  '@iirgmu',
#  '@ilctr',
#  '@imaana',
#  '@ingrahamangle',
#  '@irinnews',
#  '@isupport_israel',
#  '@ivankatrump',
#  '@janjan_collins',
#  '@jihadwatchrs',
#  '@jim_jordan',
#  '@johnzaw',
#  '@judgejeanine',
#  '@juliahb',
#  '@julianassange',
#  '@justintrudeau',
#  '@kamalaharris',
#  '@keitholbermann',
#  '@kthopkins',
#  '@lindseygrahamsc',
#  '@loudobbs',
#  '@m_rsection',
#  '@mailonline',
#  '@matteosalvinimi',
#  '@matthewsoerens',
#  '@msnbc',
#  '@nancypelosi',
#  '@narendramodi',
#  '@nbcnews',
#  '@nrc_hoa',
#  '@nyamoriv',
#  '@oprohingya',
#  '@pennyred',
#  '@phillycustoms',
#  '@phoenixkhost',
#  '@presssec',
#  '@protectrohingya',
#  '@queensoverbitch',
#  '@rajnathsingh',
#  '@ramzpaul',
#  '@rckdirector',
#  '@realcandaceo',
#  '@realdonaldtrump',
#  '@realjameswoods',
#  '@redss_hoay',
#  '@refugeeaffairs',
#  '@refugeewatcher',
#  '@repwilson',
#  '@rohingyablogger',
#  '@rosemcgowan',
#  '@sabine_durden',
#  '@santinadimaggio',
#  '@sc_humanitarian',
#  '@scouse_ma',
#  '@seanhannity',
#  '@secnielsen',
#  '@senatedems',
#  '@senategop',
#  '@senatemajldr',
#  '@senkamalaharris',
#  '@senschumer',
#  '@senwarren',
#  '@speakerryan',
#  '@stefanmolyneux',
#  '@stephanuttom',
#  '@taxo__',
#  '@taylornikola',
#  '@telegraphnews',
#  '@thedemocrats',
#  '@theeconomist',
#  '@themeredith',
#  '@theresa_may',
#  '@thomaspaine',
#  '@timesofindia',
#  '@tomilahren',
#  '@tooedit',
#  '@tuckercarlson',
#  '@tyrusmaina',
#  '@ucanbd',
#  '@ucanindia',
#  '@ucanindonesia',
#  '@ucanphilippines',
#  '@unhcr_kenya',
#  '@unhumanrights',
#  '@unitedwedream',
#  '@unmigration',
#  '@usaidffp',
#  '@usiacrimereport',
#  '@v_of_europe',
#  '@valentinaveshi',
#  '@volalupi',
#  '@washingtonpost',
#  '@whitehouse',
#  '@womensmarch',
#  '@wordpressdotcom',
#  '@yourfuckboy',
#  'Canada',
#  'I',
#  'OK',
#  'States',
#  'United',
#  '_',
#  '_xf_',
#  'ab',
#  'abandon',
#  'abc',
#  'abide',
#  'ability',
#  'able',
#  'abolish',
#  'abortion',
#  'abroad',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'abt',
#  'abuse',
#  'abusive',
#  'acc',
#  'accept',
#  'acceptable',
#  'access',
#  'accident',
#  'accord',
#  'account',
#  'accountable',
#  'accurate',
#  'accusations',
#  'accuse',
#  'acknowledge',
#  'aclu',
#  'across',
#  'act',
#  'actin',
#  'action',
#  'actively',
#  'activist',
#  'activists',
#  'activities',
#  'actress',
#  'actual',
#  'actually',
#  'ad',
#  'add',
#  'addict',
#  'address',
#  'admin',
#  'administration',
#  'admission',
#  'admit',
#  'adopt',
#  'adult',
#  'adults',
#  'advance',
#  'advantage',
#  'advertise',
#  'advocate',
#  'af',
#  'affairs',
#  'affect',
#  'afford',
#  'afghan',
#  'afghani',
#  'afghanistan',
#  'afghans',
#  'afraid',
#  'africa',
#  'african',
#  'africans',
#  'ag',
#  'age',
#  'agencies',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'aggressive',
#  'ago',
#  'agree',
#  'agreement',
#  'ah',
#  'ahead',
#  'aid',
#  'aim',
#  'air',
#  'airport',
#  'aka',
#  'akuma',
#  'al',
#  'alabama',
#  'alarm',
#  'alaska',
#  'alcohol',
#  'alert',
#  'alex',
#  'algeria',
#  'alien',
#  'alive',
#  'allah',
#  'allegations',
#  'allege',
#  'allegedly',
#  'alliance',
#  'allow',
#  'ally',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'already',
#  'alright',
#  'also',
#  'alt',
#  'alternative',
#  'although',
#  'always',
#  'amaze',
#  'ambassador',
#  'amen',
#  'amendment',
#  'america',
#  'american',
#  'americans',
#  'americas',
#  'amid',
#  'amnesty',
#  'among',
#  'amount',
#  'amp',
#  'ams',
#  'amuse',
#  'anal',
#  'analysis',
#  'ancestors',
#  'anchor',
#  'ancient',
#  'andrew',
#  'android',
#  'andto',
#  'angel',
#  'angela',
#  'angry',
#  'animal',
#  'animals',
#  'ann',
#  'announce',
#  'annoy',
#  'annual',
#  'another',
#  'answer',
#  'anti',
#  'antisemitism',
#  'antonio',
#  'anybody',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'ap',
#  'apart',
#  'apartment',
#  'apologize',
#  'apology',
#  'app',
#  'appal',
#  'apparently',
#  'appeal',
#  'appear',
#  'appeasement',
#  'applaud',
#  'apple',
#  'application',
#  'apply',
#  'appoint',
#  'appointment',
#  'appointments',
#  'appreciate',
#  'approach',
#  'appropriate',
#  'approval',
#  'approve',
#  'april',
#  'aquarius',
#  'arab',
#  'arabia',
#  'arc',
#  'area',
#  'areas',
#  'argue',
#  'argument',
#  'arizona',
#  'arm',
#  'armstrong',
#  'army',
#  'around',
#  'arrest',
#  'arrival',
#  'arrivals',
#  'arrive',
#  'arrogant',
#  'arrow',
#  'art',
#  'article',
#  'artist',
#  'artists',
#  'arts',
#  'asap',
#  'ash',
#  'ashamed',
#  'asia',
#  'asian',
#  'ask',
#  'ass',
#  'assad',
#  'assault',
#  'assay',
#  'asses',
#  'asshole',
#  'assholes',
#  'assimilate',
#  'assimilation',
#  'assist',
#  'assistance',
#  'associate',
#  'assume',
#  'assure',
#  'asylum',
#  'athletes',
#  'atl',
#  'atrocities',
#  'attack',
#  'attempt',
#  'attend',
#  'attention',
#  'attitude',
#  'attorney',
#  'attract',
#  'attractive',
#  'audacity',
#  'aug',
#  'august',
#  'australia',
#  'australian',
#  'australians',
#  'austria',
#  'austrian',
#  'austrians',
#  'author',
#  'authorities',
#  'authority',
#  'automatically',
#  'available',
#  'average',
#  'avoid',
#  'aw',
#  'await',
#  'award',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  'awful',
#  'aye',
#  'ba',
#  'baby',
#  'bac',
#  'back',
#  'background',
#  'backhand',
#  'backlash',
#  'bad',
#  'badass',
#  'bae',
#  'bag',
#  'balance',
#  'ball',
#  'ban',
#  'bangladesh',
#  'bank',
#  'bankrupt',
#  'bar',
#  'barbara',
#  'bare',
#  'barrier',
#  'base',
#  'bash',
#  'basic',
#  'basically',
#  'bastard',
#  'bastards',
#  'bat',
#  'battle',
#  'bazar',
#  'beach',
#  'beam',
#  'bean',
#  'bear',
#  'beat',
#  'beautiful',
#  'become',
#  'bed',
#  'beef',
#  'beer',
#  'beg',
#  'begin',
#  'behalf',
#  'behavior',
#  'behead',
#  'behind',
#  'belief',
#  'believe',
#  'belittle',
#  'belly',
#  'belong',
#  'beloved',
#  'belt',
#  'bend',
#  'beneficiaries',
#  'benefit',
#  'berlin',
#  'besides',
#  'best',
#  'bet',
#  'betray',
#  'better',
#  'beware',
#  'beyond',
#  'bias',
#  'bible',
#  'biceps',
#  'big',
#  'bigger',
#  'biggest',
#  'bill',
#  'billion',
#  'billions',
#  'bin',
#  'bind',
#  'bio',
#  'bird',
#  'birth',
#  'birthday',
#  'bishop',
#  'bishops',
#  'bitch',
#  'bitcoin',
#  'bite',
#  'black',
#  'blackout',
#  'blair',
#  'blame',
#  'blank',
#  'bleed',
#  'bless',
#  'blind',
#  'bloc',
#  'block',
#  'blog',
#  'blonde',
#  'blood',
#  'bloody',
#  'blow',
#  'blue',
#  'board',
#  'boat',
#  'bob',
#  'body',
#  'bomb',
#  'bond',
#  'boo',
#  'boob',
#  'book',
#  'booker',
#  'boot',
#  'booty',
#  'bop',
#  'border',
#  'bore',
#  'boss',
#  'bot',
#  'bother',
#  'bottle',
#  'bottom',
#  'bout',
#  'bow',
#  'box',
#  'boy',
#  'boycott',
#  'boyfriend',
#  'boys',
#  'brag',
#  'brain',
#  'brainless',
#  'brand',
#  'brave',
#  'brazil',
#  'break',
#  'breakfast',
#  'breath',
#  'breed',
#  'breitbart',
#  'brexit',
#  'brian',
#  'bribe',
#  'brick',
#  'bricks',
#  'bridge',
#  'brilliant',
#  'bring',
#  'britain',
#  'british',
#  'bro',
#  'broad',
#  'broadcast',
#  'brother',
#  'brothers',
#  'brown',
#  'bruh',
#  'brush',
#  'brussels',
#  'brutal',
#  'budget',
#  'build',
#  'bullshit',
#  'bully',
#  'bunch',
#  'burden',
#  'bureau',
#  'burgundian',
#  'burgundy',
#  'burma',
#  'burn',
#  'burqa',
#  'bury',
#  'bus',
#  'business',
#  'businesses',
#  'bust',
#  'busy',
#  'butt',
#  'button',
#  'buy',
#  'bye',
#  'ca',
#  'cabinet',
#  'caca',
#  'cage',
#  'cake',
#  'calais',
#  'california',
#  'caliphate',
#  'call',
#  'calm',
#  'cam',
#  'camera',
#  'cameron',
#  'cameroon',
#  'camp',
#  'campaign',
#  'campus',
#  'canada',
#  'canadian',
#  'canadians',
#  'cancel',
#  'cancer',
#  'candace',
#  'candidate',
#  'candidates',
#  'candy',
#  'cannot',
#  'canon',
#  'cap',
#  'capital',
#  'capture',
#  'car',
#  'card',
#  'care',
#  'career',
#  'careful',
#  'carolina',
#  'carry',
#  'cars',
#  'cartel',
#  'case',
#  'cash',
#  'cat',
#  'catastrophe',
#  'catch',
#  'category',
#  'cater',
#  'catholic',
#  'cause',
#  'celebrate',
#  'census',
#  'cent',
#  'center',
#  'central',
#  'centre',
#  'century',
#  'ceo',
#  'certa',
#  'certain',
#  'certainly',
#  'chain',
#  'chair',
#  'challenge',
#  'chance',
#  'change',
#  'chaos',
#  'char',
#  'character',
#  'charge',
#  'charities',
#  'charity',
#  'charlie',
#  'chat',
#  'chavez',
#  'cheap',
#  'cheat',
#  'check',
#  'cheer',
#  'cheese',
#  'chelsea',
#  'cher',
#  'chew',
#  'chicago',
#  'chick',
#  'chicken',
#  'chicks',
#  'chief',
#  'child',
#  'childish',
#  'children',
#  'chill',
#  'china',
#  'chinese',
#  'choice',
#  'choke',
#  'choose',
#  'chop',
#  'christ',
#  'christian',
#  'christianity',
#  'christians',
#  'christmas',
#  'church',
#  'cia',
#  'circle',
#  'cities',
#  'citizen',
#  'citizens',
#  'citizenship',
#  'city',
#  'civil',
#  'civilization',
#  'claim',
#  'clap',
#  'class',
#  'classic',
#  'classy',
#  'clean',
#  'clear',
#  'clearly',
#  'client',
#  'climate',
#  'climb',
#  'clinton',
#  'close',
#  'closer',
#  'clothe',
#  'clout',
#  'clown',
#  'club',
#  'clue',
#  'clueless',
#  'co',
#  'coach',
#  'coalition',
#  'coast',
#  'coastguard',
#  'cock',
#  'cod',
#  'code',
#  'coke',
#  'cold',
#  'collapse',
#  'collect',
#  'college',
#  'cologne',
#  'color',
#  'colorado',
#  'colour',
#  'come',
#  'comedy',
#  'comfortable',
#  'comment',
#  'commit',
#  'common',
#  'commonwealth',
#  'communist',
#  'communities',
#  'community',
#  'company',
#  'compare',
#  'compassion',
#  'compete',
#  'complain',
#  'complaint',
#  'complete',
#  'completely',
#  'complex',
#  'complicit',
#  'compromise',
#  'con',
#  'concern',
#  'condition',
#  'condom',
#  'condoms',
#  'conference',
#  'confirm',
#  'conflict',
#  'confuse',
#  'cong',
#  'congratulations',
#  'congress',
#  'conquer',
#  'consensual',
#  'consent',
#  'consequences',
#  'conservative',
#  'conservatives',
#  'consider',
#  'conspiracy',
#  'constant',
#  'constantly',
#  'constitution',
#  'contact',
#  'conte',
#  'context',
#  'continue',
#  'contribute',
#  'control',
#  'conversation',
#  'convict',
#  'convince',
#  'cook',
#  'cool',
#  'cop',
#  'coptic',
#  'copyright',
#  'corner',
#  'correct',
#  'corrupt',
#  'corruption',
#  'cory',
#  'cos',
#  'cost',
#  'cot',
#  'cough',
#  'could',
#  'council',
#  'count',
#  'counter',
#  'countries',
#  'country',
#  'county',
#  'couple',
#  'course',
#  'court',
#  'cousin',
#  'cover',
#  'cow',
#  'coward',
#  'cowards',
#  'cox',
#  'cpu',
#  'crack',
#  'crap',
#  'crash',
#  'crawl',
#  'crazy',
#  'create',
#  'credit',
#  'creepy',
#  'crew',
#  'crime',
#  'crimes',
#  'criminal',
#  'criminals',
#  'crisis',
#  'criteria',
#  'critical',
#  'criticize',
#  'croatia',
#  'croatian',
#  'crook',
#  'cross',
#  'crowd',
#  'crown',
#  'cruel',
#  'crush',
#  'cry',
#  'cube',
#  'cult',
#  'cultural',
#  'culture',
#  'cum',
#  'cunt',
#  'cunts',
#  'cup',
#  'curb',
#  'current',
#  'currently',
#  'custody',
#  'customs',
#  'cut',
#  'cute',
#  'cuz',
#  'czech',
#  'da',
#  'daca',
#  'dad',
#  'daddy',
#  'daily',
#  'damage',
#  'damn',
#  'dance',
#  'danger',
#  'dangerous',
#  'daniel',
#  'dare',
#  ...]

# %%
with open("./data/spanish_vocabulary_.pkl", "wb") as f:
    pickle.dump(spanish_vectorizer.get_feature_names(), f)
with open("./data/spanish_vocabulary_.pkl", "rb") as f:   
    spanish_vectorizer_features = pickle.load(f)

spanish_vectorizer_features
# Out:
# ['#arandina',
#  '#defiendeespaña',
#  '#eleccionesgeneralesya',
#  '#eleccionesya',
#  '#finalgh',
#  '#hacemuchoque',
#  '#indocumentados',
#  '#inmigracion',
#  '#inmigración',
#  '#inmigrantes',
#  '#lomásleído',
#  '#moromierdas',
#  '#otdirectod',
#  '#otgala',
#  '#refugiados',
#  '#sanchezdimision',
#  '#stopinvasion',
#  '#todasputas',
#  '@_brix__',
#  '@_eckoyg',
#  '@abc_es',
#  '@adacolau',
#  '@ahorapodemos',
#  '@albert_rivera',
#  '@albiol_xg',
#  '@anaisbernal',
#  '@anoticias',
#  '@antonioadan',
#  '@as_tomasroncero',
#  '@ash_london',
#  '@aurelionuno',
#  '@auronplay',
#  '@barbijaputa',
#  '@beeluarzola',
#  '@bts_twt',
#  '@dalasreview',
#  '@dcabellor',
#  '@deluxesabado',
#  '@drodriguezven',
#  '@el_pais',
#  '@elchiringuitotv',
#  '@eldiarioes',
#  '@elisacarrio',
#  '@elmundoes',
#  '@elperiodico',
#  '@ertenembaum',
#  '@faunafeminazi',
#  '@flor_vigna',
#  '@gabrielrufian',
#  '@guardiacivil',
#  '@hectorbecerrilr',
#  '@interiorgob',
#  '@irantzuvarela',
#  '@jlozanoa',
#  '@joseameadek',
#  '@juandedios_p',
#  '@juliamengo',
#  '@kimberlyloaiza_',
#  '@la_patilla',
#  '@leticiadolera',
#  '@lopezdoriga',
#  '@lopezobrador_',
#  '@lortegadiaz',
#  '@marianorajoy',
#  '@mashirafael',
#  '@nestorreverol',
#  '@nicolasmaduro',
#  '@oficialyuri',
#  '@okdiario',
#  '@pablo_iglesias_',
#  '@pablocasado_',
#  '@patobullrich',
#  '@poderfeminazi',
#  '@pontifex_es',
#  '@pri_nacional',
#  '@prssrx',
#  '@realdonaldtrump',
#  '@realmadrid',
#  '@relatofeminista',
#  '@salvameoficial',
#  '@sanchezcastejon',
#  '@sebastianpinera',
#  '@sergiomassa',
#  '@sextanoticias',
#  '@solanopo',
#  '@sr_hater_',
#  '@tiafeminazi',
#  '@titohunterlol',
#  '@todonoticias',
#  '@tonialba',
#  '@towandarebels',
#  '@vicentefoxque',
#  '@vikidonda',
#  '@xxxeyeless',
#  '@yaoecabrera',
#  '@yenivilcatoma',
#  'Chile',
#  'OK',
#  'Panama',
#  'Purpura',
#  'abajo',
#  'abandon',
#  'abandonados',
#  'abierto',
#  'abogado',
#  'abort',
#  'abran',
#  'abrazando',
#  'abre',
#  'abrir',
#  'absolute',
#  'absurd',
#  'abuela',
#  'abuelo',
#  'abusadores',
#  'abuse',
#  'aca',
#  'acaba',
#  'acaban',
#  'acabo',
#  'accident',
#  'acerca',
#  'acid',
#  'acids',
#  'acolo',
#  'acosador',
#  'acres',
#  'across',
#  'act',
#  'action',
#  'active',
#  'actor',
#  'actrice',
#  'actual',
#  'actuation',
#  'acuerdo',
#  'acusaciones',
#  'acusados',
#  'acute',
#  'ad',
#  "adam's",
#  'adamas',
#  'add',
#  'adelante',
#  'admit',
#  'adn',
#  'adolescents',
#  'adorn',
#  'adults',
#  'adverse',
#  'affect',
#  'africa',
#  'african',
#  'africans',
#  'agarras',
#  'agate',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'aggressor',
#  'ago',
#  'agredido',
#  'agrediendo',
#  'agree',
#  'agresiones',
#  'agression',
#  'agua',
#  'aguafiestas',
#  'aguascalientes',
#  'aguentar',
#  'ah',
#  'ahah',
#  'ahi',
#  'ahora',
#  'ahorita',
#  'aidan',
#  'ailments',
#  'air',
#  'aire',
#  'ajoy',
#  'aki',
#  'al',
#  'ala',
#  'alarm',
#  'alaska',
#  'albania',
#  'albert',
#  'album',
#  'alcalde',
#  'alcanzar',
#  'alcohol',
#  'ale',
#  'alegria',
#  'alert',
#  'alfred',
#  'algeciras',
#  'algo',
#  'alguien',
#  'algun',
#  'alguna',
#  'algunas',
#  'algunos',
#  'alias',
#  'alienate',
#  'alimentary',
#  'aliviada',
#  'aliviado',
#  'allan',
#  'allegro',
#  'almeida',
#  'also',
#  'alta',
#  'altar',
#  'alter',
#  'alto',
#  'alumnus',
#  'ama',
#  'amada',
#  'amanda',
#  'amar',
#  'amarillo',
#  'amas',
#  'ambos',
#  'amelia',
#  'amenaza',
#  'america',
#  'americano',
#  'amiga',
#  'amigas',
#  'amigo',
#  'amigos',
#  'amo',
#  'amor',
#  'amos',
#  'amp',
#  'amparo',
#  'ana',
#  'analfabetos',
#  'analysis',
#  'anata',
#  'ancients',
#  'anda',
#  'andals',
#  'andan',
#  'andar',
#  'andas',
#  'andate',
#  'ando',
#  'andres',
#  'anemones',
#  'angel',
#  'angioma',
#  'angustiado',
#  'animal',
#  'animals',
#  'ante',
#  'antecedents',
#  'antenna',
#  'antonio',
#  'anuncio',
#  'apart',
#  'apenas',
#  'aplaudir',
#  'apreciate',
#  'aprendido',
#  'apricots',
#  'aprovechando',
#  'apuntando',
#  'aqua',
#  'aquarius',
#  'aquel',
#  'aqui',
#  'arab',
#  'arabia',
#  'arabs',
#  'ardennes',
#  'area',
#  'areas',
#  'arena',
#  'argentina',
#  'argentine',
#  'argentines',
#  'argue',
#  'arizona',
#  'arm',
#  'arma',
#  'armadas',
#  'armando',
#  'armas',
#  'armenian',
#  'army',
#  'aroma',
#  'aromas',
#  'arquitectura',
#  'arrange',
#  'arranger',
#  'arras',
#  'arrastrado',
#  'arriba',
#  'arrow',
#  'arte',
#  'artista',
#  'artists',
#  'artículo',
#  'aruba',
#  'asada',
#  'asaltantes',
#  'asante',
#  'asbestos',
#  'ascot',
#  'asesino',
#  'asesinos',
#  'asesoramiento',
#  'asi',
#  'aspirational',
#  'asquerosa',
#  'asqueroso',
#  'ass',
#  'asunto',
#  'atack',
#  'ataman',
#  'atención',
#  'atentado',
#  'atque',
#  'atras',
#  'atravesada',
#  'attention',
#  'attica',
#  'attitude',
#  'audience',
#  'audit',
#  'aun',
#  'auras',
#  'austin',
#  'auto',
#  'autobus',
#  'autoridades',
#  'auténtica',
#  'avalanche',
#  'avatar',
#  'avian',
#  'avis',
#  'avocado',
#  'avocados',
#  'axel',
#  'ay',
#  'ayer',
#  'ayuda',
#  'ayudar',
#  'ayuntamiento',
#  'azul',
#  'baby',
#  'badlands',
#  'bah',
#  'bail',
#  'baila',
#  'bailar',
#  'baja',
#  'bajo',
#  'balan',
#  'ballad',
#  'ballads',
#  'bamos',
#  'banco',
#  'band',
#  'banda',
#  'bandera',
#  'banquet',
#  'bao',
#  'bar',
#  'barada',
#  'barcelona',
#  'baron',
#  'barrio',
#  'base',
#  'basra',
#  'basta',
#  'bastante',
#  'bastar',
#  'bastardo',
#  'beaner',
#  'bebe',
#  'beber',
#  'beca',
#  'becerro',
#  'begin',
#  'bella',
#  'beneficial',
#  'benito',
#  'berlin',
#  'besides',
#  'beso',
#  'besos',
#  'best',
#  'bestir',
#  'bet',
#  'bias',
#  'biceps',
#  'bichon',
#  'bid',
#  'bien',
#  'bienestar',
#  'bienvenido',
#  'bienvenidos',
#  'big',
#  'bigot',
#  'billet',
#  'bin',
#  'biology',
#  'bisque',
#  'bitch',
#  'bizarre',
#  'bla',
#  'black',
#  'blanca',
#  'blanco',
#  'blog',
#  'board',
#  'boat',
#  'boba',
#  'bobo',
#  'boca',
#  'boda',
#  'bogota',
#  'bola',
#  'bolas',
#  'bold',
#  'bolivian',
#  'bolivianos',
#  'bolos',
#  'bolsa',
#  'bolsillos',
#  'bomb',
#  'bomba',
#  'bombas',
#  'bonita',
#  'bonito',
#  'boom',
#  'boot',
#  'bore',
#  'borracha',
#  'borrachas',
#  'borracho',
#  'bot',
#  'bow',
#  'bravado',
#  'bravo',
#  'brazos',
#  'brillant',
#  'bronc',
#  'brussels',
#  'buen',
#  'buena',
#  'buenas',
#  'bueno',
#  'buenos',
#  'burro',
#  'bus',
#  'busca',
#  'buscando',
#  'buscar',
#  'busco',
#  'bush',
#  'ca',
#  'caballero',
#  'caballo',
#  'cabana',
#  'cabe',
#  'cabeza',
#  'cabin',
#  'cabinet',
#  'cabron',
#  'cabrones',
#  'caca',
#  'cachonda',
#  'cachondeo',
#  'cada',
#  'cadenza',
#  'cae',
#  'caer',
#  'cage',
#  'cago',
#  'cal',
#  'calderon',
#  'caliente',
#  'california',
#  'calista',
#  'call',
#  'calla',
#  'callateee',
#  'calle',
#  'calleda',
#  'callejero',
#  'calor',
#  'calvados',
#  'cama',
#  'cambiar',
#  'cambio',
#  'camel',
#  'camera',
#  'cameras',
#  'cameron',
#  'camila',
#  'camino',
#  'camp',
#  'campana',
#  'campo',
#  'canada',
#  'canal',
#  'cancel',
#  'cancer',
#  'cancion',
#  'candidates',
#  'candle',
#  'cando',
#  'canines',
#  'canta',
#  'cantaba',
#  'cantando',
#  'cantar',
#  'cantate',
#  'cante',
#  'canto',
#  'canvas',
#  'capa',
#  'capades',
#  'capital',
#  'capitan',
#  'caprice',
#  'capture',
#  'capítulo',
#  'cara',
#  'carajo',
#  'caras',
#  'card',
#  'cardio',
#  'care',
#  'cargo',
#  'carl',
#  'carla',
#  'carlitos',
#  'carlos',
#  'carmen',
#  'carne',
#  'carol',
#  'carpet',
#  'carrillo',
#  'carro',
#  'cars',
#  'carta',
#  'cartage',
#  'cartel',
#  'cas',
#  'casa',
#  'casaba',
#  'casas',
#  'case',
#  'casi',
#  'casino',
#  'casinos',
#  'caso',
#  'cast',
#  'caste',
#  'castellano',
#  'castidad',
#  'castro',
#  'casualmente',
#  'catalan',
#  'catalans',
#  'catalina',
#  'catalufo',
#  'catalufos',
#  'cater',
#  'catherine',
#  'causa',
#  'caviar',
#  'cede',
#  'cela',
#  'celebrate',
#  'celery',
#  'cello',
#  'cells',
#  'cellular',
#  'cena',
#  'centavos',
#  'centenary',
#  'central',
#  'centre',
#  'centro',
#  'cents',
#  'ceo',
#  'cerca',
#  'cerebro',
#  'certa',
#  'cerveza',
#  'challenge',
#  'chamalla',
#  'champ',
#  'chant',
#  'chantal',
#  'chap',
#  'char',
#  'chara',
#  'character',
#  'charge',
#  'charisma',
#  'charla',
#  'charlatan',
#  'charles',
#  'charon',
#  'chaste',
#  'chat',
#  'chau',
#  'chavez',
#  'check',
#  'cheese',
#  'cheval',
#  'chica',
#  'chicago',
#  'chicas',
#  'chicks',
#  'chico',
#  'chide',
#  'chile',
#  'chilean',
#  'chileans',
#  'chill',
#  'china',
#  'chinga',
#  'chingado',
#  'chingo',
#  'chinos',
#  'chip',
#  'chiquita',
#  'chismosa',
#  'chispeante',
#  'chivas',
#  'chivo',
#  'chola',
#  'choose',
#  'chopra',
#  'chorizo',
#  'christians',
#  'chula',
#  'chuparse',
#  'ciao',
#  'cicada',
#  'cicadas',
#  'cielo',
#  'ciento',
#  'ciera',
#  'cierra',
#  'cierre',
#  'cigar',
#  'cigars',
#  'cinco',
#  'cine',
#  'city',
#  'ciudad',
#  'ciudadanos',
#  'ciudadanía',
#  'civies',
#  'civil',
#  'clara',
#  'claramente',
#  'claro',
#  'clase',
#  'class',
#  'clave',
#  'clean',
#  'clear',
#  'cliente',
#  'clients',
#  'clinica',
#  'clip',
#  'cloaca',
#  'close',
#  'club',
#  'co',
#  'coalition',
#  'cobra',
#  'cobras',
#  'coca',
#  'cocaine',
#  'coche',
#  'cochinita',
#  'cod',
#  'codis',
#  'coercion',
#  'cogito',
#  'cohere',
#  'coherent',
#  'coincide',
#  'cojones',
#  'cola',
#  'colaboración',
#  'colada',
#  'coladas',
#  'colegios',
#  'collapse',
#  'collar',
#  'collate',
#  'collective',
#  'college',
#  'collegia',
#  'collision',
#  'colombia',
#  'colombian',
#  'colombians',
#  'colon',
#  'colony',
#  'color',
#  'colorado',
#  'com',
#  'coma',
#  'comas',
#  'combat',
#  'combination',
#  'combo',
#  'come',
#  'comedian',
#  'comemela',
#  'comen',
#  'comentario',
#  'comenzando',
#  'comepollas',
#  'comer',
#  'comercial',
#  'comerciantes',
#  'cometemos',
#  'cometidas',
#  'comi',
#  'comida',
#  'comiendo',
#  'comin',
#  'comission',
#  'comm',
#  'commando',
#  'commentaries',
#  'commerce',
#  'communist',
#  'communists',
#  'como',
#  'compa',
#  'compactor',
#  'companeros',
#  'compare',
#  'compartido',
#  'compartiendo',
#  'compatriots',
#  'compañera',
#  'compete',
#  'competence',
#  'complete',
#  'complicate',
#  'compline',
#  'comply',
#  'comprar',
#  'comprende',
#  'computer',
#  'comrade',
#  'comunication',
#  'comunidad',
#  'comunidades',
#  'con',
#  'concede',
#  'concept',
#  'concern',
#  'concha',
#  'conchetumare',
#  'conclude',
#  'conclusion',
#  'condemn',
#  'condition',
#  'condo',
#  'condos',
#  'conduct',
#  'conductor',
#  'conference',
#  'confetti',
#  'confirm',
#  'conflict',
#  'confundida',
#  'congress',
#  'conmigo',
#  'conoce',
#  'conocer',
#  'conoces',
#  'conocido',
#  'conocimiento',
#  'conozco',
#  'consecuencias',
#  'conseguir',
#  'consent',
#  'consider',
#  'considera',
#  'consign',
#  'contact',
#  'content',
#  'contest',
#  'contestants',
#  'contigo',
#  'continue',
#  'contra',
#  'contract',
#  'contralto',
#  'contrary',
#  'contribute',
#  'control',
#  'convene',
#  'convert',
#  'converter',
#  'cool',
#  'cop',
#  'copa',
#  'coquette',
#  'corazon',
#  'corazones',
#  'core',
#  'cornea',
#  'corrado',
#  'corre',
#  'correct',
#  'corrida',
#  'corrido',
#  'corrientes',
#  'corrupt',
#  'corruption',
#  'corta',
#  'cortes',
#  'corto',
#  'cosa',
#  'cosas',
#  'cost',
#  'costa',
#  'costar',
#  'costas',
#  'costume',
#  'cougar',
#  'cover',
#  'coverture',
#  'coward',
#  'crack',
#  'crea',
#  'crecimiento',
#  'credit',
#  'credo',
#  'cree',
#  'creen',
#  'creencias',
#  'creer',
#  'crees',
#  'crema',
#  'creo',
#  'cretin',
#  'crime',
#  'crisis',
#  'cristina',
#  'cristo',
#  'critical',
#  'crown',
#  'cruel',
#  'crumple',
#  'crusade',
#  'crush',
#  'cruz',
#  'crímenes',
#  'cuadernos',
#  'cual',
#  'cualquier',
#  'cuando',
#  'cuanto',
#  'cuarto',
#  'cuatro',
#  'cuba',
#  'cuban',
#  'cubanos',
#  'cuchillo',
#  'cucina',
#  'cuenta',
#  'cuerpo',
#  'cuesta',
#  'cuidado',
#  'culeros',
#  'culo',
#  'culpa',
#  'culpable',
#  'cultural',
#  'culture',
#  'cumpleaños',
#  'cunts',
#  'cure',
#  'curios',
#  'curl',
#  'curry',
#  'curse',
#  'd_nacional',
#  'da',
#  'daba',
#  'daca',
#  'daddy',
#  'dado',
#  'dago',
#  'dais',
#  'dale',
#  'dame',
#  'damian',
#  'dan',
#  'dana',
#  'danas',
#  'dandy',
#  'dani',
#  'daniel',
#  'dar',
#  'dara',
#  'daran',
#  'dare',
#  'daria',
#  'dario',
#  'dark',
#  'darle',
#  'darte',
#  'das',
#  'data',
#  'date',
#  'dato',
#  'david',
#  'de',
#  'deacon',
#  'dead',
#  'deado',
#  'dean',
#  'dear',
#  'debate',
#  'debe',
#  'debemos',
#  'deben',
#  'deberia',
#  'deberíamos',
#  'debes',
#  'debit',
#  'debo',
#  'decades',
#  'decent',
#  'decepcionada',
#  'deception',
#  'decide',
#  'decir',
#  'decirte',
#  'decis',
#  'decisions',
#  'deck',
#  'declan',
#  'declarations',
#  'declare',
#  'dedicate',
#  'deen',
#  'deeper',
#  'deer',
#  'dees',
#  'defend',
#  'defende',
#  'defender',
#  'defenders',
#  'defendiendo',
#  'defense',
#  'define',
#  'definitivamente',
#  'deja',
#  'dejame',
#  'dejar',
#  'dejas',
#  'deje',
#  'dejemos',
#  'dejo',
#  'del',
#  'deli',
#  'delicious',
#  'delicto',
#  'delincuencia',
#  'delinquent',
#  'delinquents',
#  'delinquir',
#  'demagogy',
#  'demand',
#  'demasiado',
#  'demented',
#  'demi',
#  'demo',
#  'democratic',
#  'demon',
#  'demostrate',
#  'demuestra',
#  'demuestran',
#  'den',
#  'dengan',
#  'denigrate',
#  'denominator',
#  'dentro',
#  ...]

# %%
from sklearn.preprocessing import StandardScaler

def extra_data(data):
    """Generates extra data from the text. Currently it just counts the number of uppercase letters
    and the number of uppercase words
    """
    uppercase_leters = data.apply(lambda text: sum(1 for c in text if c.isupper()))
    uppercase_words = data.apply(lambda text: sum(1 for word in text.split() if word.isupper()))
    
    return np.c_[(uppercase_leters, uppercase_words)]

extra_pipe = Pipeline([
    ('extra_data', FunctionTransformer(func=extra_data, validate=False)),
    #('standarize', StandardScaler()),
    ('sparse',  FunctionTransformer(func=lambda data: sparse.csr_matrix(data), validate=False))
])

# Calculates the extra data for both train and dev datasets
X_extra_train_english = extra_pipe.fit_transform(english_train['text'])
X_extra_dev_english = extra_pipe.transform(english_dev['text'])
X_extra_test_english = extra_pipe.transform(english_test['text'])

X_extra_train_spanish = extra_pipe.fit_transform(spanish_train['text'])
X_extra_dev_spanish = extra_pipe.transform(spanish_dev['text'])
X_extra_test_spanish = extra_pipe.transform(spanish_test['text'])

# %%
# Joins the Tf-Idf matrix and the extra data
X_train_english = X_basic_train_english #sparse.hstack((X_basic_train_english, X_extra_train_english))
X_dev_english = X_basic_dev_english #sparse.hstack((X_basic_dev_english, X_extra_dev_english))
X_test_english = X_basic_test_english #sparse.hstack((X_basic_test_english, X_extra_test_english))

X_train_spanish = X_basic_train_spanish #sparse.hstack((X_basic_train_spanish, X_extra_train_spanish))
X_dev_spanish = X_basic_dev_spanish #sparse.hstack((X_basic_dev_spanish, X_extra_dev_spanish))
X_test_spanish = X_basic_test_spanish #sparse.hstack((X_basic_test_spanish, X_extra_test_spanish))

# %% [markdown]
# ## Save results

# %%
import pandas as pd
import os
from enum import Enum

metadata_file = "./results/metadata.pkl"
dataset_types =  Enum("dataset_types", "train development test")

def save_results(y_pred, index, name, task, lenguage, dataset_type, group=None, description=None, truth=False, filename=None):
    
    path = f"./results/{task}/{lenguage}/{dataset_type.name}{'/' + group if group is not None else ''}/{name if filename is None else filename}.pkl"
    
    directory = "/".join(path.split("/")[:-1])
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    if os.path.exists(metadata_file):
        metadata = pd.read_pickle(metadata_file)
    else:
        metadata = pd.DataFrame({
            "Path": pd.Series([], dtype=str),
            "Name": pd.Series([], dtype=str),
            "Description": pd.Series([], dtype=str),
            "Dataset type": pd.Categorical([], categories=dataset_types, ordered=False),
            "Groud Truth": pd.Series([], dtype=bool),
            "Group": pd.Series([], dtype=str),
            "Task": pd.Series([], dtype=str),
            "Lenguage": pd.Series([], dtype=str),
        }).set_index("Path")
    
    if path in metadata.index:
        metadata = remove_results(path)

    metadata.loc[path] = {"Name": name, "Description": description, "Dataset type": dataset_type, "Groud Truth": truth, "Group": group, "Task": task, "Lenguage": lenguage}
    results = pd.DataFrame({"id": index, "y_pred": y_pred}).set_index("id") 
    
    results.to_pickle(path)
    metadata.to_pickle(metadata_file)
    
    print("Results saved on: " + path)

def remove_results(path=None):
    if os.path.exists(metadata_file):
        metadata = pd.read_pickle(metadata_file)
        if path is not None:
            if os.path.exists(path):
                metadata = metadata.drop(path)
                os.remove(path)
                metadata.to_pickle(metadata_file)
        else:
            if os.path.exists(metadata_file):
                used_files = [os.path.normpath(f) for f in metadata.index]
                all_files = set([os.path.normpath(os.path.join(dp, f)) for dp, dn, filenames in os.walk('./results') for f in filenames][1:])
                for f in used_files:
                    if f not in all_files:
                        os.remove(f)
        return metadata

    
def load_results():
    if os.path.exists(metadata_file):
        metadata = pd.read_pickle(metadata_file)
    else:
        return None
    
    metadata["Results"] = [pd.read_pickle(path) for path in metadata.index]
    return metadata

# %%
save_results(english_train["HS"], english_train.index, "English Train", "hateval2019/task1", "english", dataset_types.train, truth=True, filename="train_truth_task1")
save_results(english_dev["HS"], english_dev.index, "English Development", "hateval2019/task1", "english", dataset_types.development, truth=True, filename="dev_truth_task1")
save_results(english_test["HS"], english_test.index, "English Test", "hateval2019/task1", "english", dataset_types.test, truth=True, filename="test_truth_task1")

save_results(spanish_train["HS"], spanish_train.index, "Spanish Train", "hateval2019/task1", "spanish", dataset_types.train, truth=True, filename="train_truth_task1")
save_results(spanish_dev["HS"], spanish_dev.index, "Spanish Development", "hateval2019/task1", "spanish", dataset_types.development, truth=True, filename="dev_truth_task1")
save_results(spanish_test["HS"], spanish_test.index, "Spanish Test", "hateval2019/task1", "spanish", dataset_types.test, truth=True, filename="test_truth_task1")
# Out:
# Results saved on: ./results/hateval2019/task1/english/train/train_truth_task1.pkl
# Results saved on: ./results/hateval2019/task1/english/development/dev_truth_task1.pkl
# Results saved on: ./results/hateval2019/task1/english/test/test_truth_task1.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/train_truth_task1.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/dev_truth_task1.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/test_truth_task1.pkl

# %% [markdown]
# ## Classification models

# %%
from sklearn.metrics import accuracy_score, classification_report, f1_score

def print_score(y_true, y_pred, name):
    classification_report_results = classification_report(y_true, y_pred)
    
    acc, f1 = accuracy_score(y_true, y_pred), f1_score(y_true, y_pred, average='macro')

    print(name)
    print('\nAccuracy: ', acc)
    print('F1 macro: ', f1)
    print('\nClassification Report')
    print('======================================================')
    print('\n', classification_report_results)
    
    return {"Accuracy": acc, "F1 macro": f1}

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.dummy import DummyClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

multinomial = MultinomialNB()
bernoulli = BernoulliNB()
ridge = RidgeClassifier(random_state=42)
random_forest = RandomForestClassifier(random_state=42)
dummy = DummyClassifier(strategy="prior")
mlp = MLPClassifier(early_stopping=True, random_state=42) 
svc = SVC(random_state=42)
adaboost = AdaBoostClassifier(random_state=42)

models = {
    dummy: "Dummy Classifier",
    multinomial: "Multinomial Naive Bayes classifier",
    bernoulli: "Bernoulli Naive Bayes classifier",
    ridge: "Ridge Classifier",
    random_forest: "Random Forest classifier",
    svc: "Support Vector Classification",
    adaboost: "AdaBoost classifier",
    mlp: "Multi-layer Perceptron classifier"
}

def fit_models(X, y, models):
    for model, name in models.items():
        model.fit(X, y)
        print(f"Model {name} fitted")


def print_scores(X, y_true, models):
    """Prints the accuarcy and the classification report of the list of models.
    """
    results, y_preds = [], []
    for model, name in models.items():
        y_pred = model.predict(X)
        y_preds.append(y_pred)
        results.append(print_score(y_true, y_pred, name))
    return pd.DataFrame(results, index=models.values()), pd.DataFrame(y_preds, index=models.values())

fit_models(X_train_english, english_train['HS'], models)

print("TRAIN:")
train_scores_english, train_preds_english = print_scores(X_train_english, english_train["HS"], models)

print("\n\nDEV:")
dev_scores_english, dev_preds_english = print_scores(X_dev_english, english_dev["HS"], models)
# Out:
# Model Dummy Classifier fitted
# Model Multinomial Naive Bayes classifier fitted
# Model Bernoulli Naive Bayes classifier fitted
# Model Ridge Classifier fitted
# Model Random Forest classifier fitted
# Model Support Vector Classification fitted
# Model AdaBoost classifier fitted
# Model Multi-layer Perceptron classifier fitted
# TRAIN:
# Dummy Classifier
#
# Accuracy:  0.5796666666666667
# F1 macro:  0.3669550538088204
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73      5217
#            1       0.00      0.00      0.00      3783
#
#     accuracy                           0.58      9000
#    macro avg       0.29      0.50      0.37      9000
# weighted avg       0.34      0.58      0.43      9000
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.8204444444444444
# F1 macro:  0.8126298508371801
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      5217
#            1       0.82      0.73      0.77      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.82      0.81      0.81      9000
# weighted avg       0.82      0.82      0.82      9000
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.826
# F1 macro:  0.8210285714285713
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      5217
#            1       0.80      0.78      0.79      3783
#
#     accuracy                           0.83      9000
#    macro avg       0.82      0.82      0.82      9000
# weighted avg       0.83      0.83      0.83      9000
#
# Ridge Classifier
#
# Accuracy:  0.8816666666666667
# F1 macro:  0.8774313461768318
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      5217
#            1       0.88      0.83      0.85      3783
#
#     accuracy                           0.88      9000
#    macro avg       0.88      0.87      0.88      9000
# weighted avg       0.88      0.88      0.88      9000
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest classifier
#
# Accuracy:  0.999
# F1 macro:  0.9989737648560049
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5217
#            1       1.00      1.00      1.00      3783
#
#     accuracy                           1.00      9000
#    macro avg       1.00      1.00      1.00      9000
# weighted avg       1.00      1.00      1.00      9000
#
# Support Vector Classification
#
# Accuracy:  0.9575555555555556
# F1 macro:  0.9563093471055895
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      5217
#            1       0.96      0.94      0.95      3783
#
#     accuracy                           0.96      9000
#    macro avg       0.96      0.95      0.96      9000
# weighted avg       0.96      0.96      0.96      9000
#
# AdaBoost classifier
#
# Accuracy:  0.7816666666666666
# F1 macro:  0.7679385989020957
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82      5217
#            1       0.80      0.64      0.71      3783
#
#     accuracy                           0.78      9000
#    macro avg       0.79      0.76      0.77      9000
# weighted avg       0.78      0.78      0.78      9000
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.8914444444444445
# F1 macro:  0.8880149007808582
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      5217
#            1       0.89      0.85      0.87      3783
#
#     accuracy                           0.89      9000
#    macro avg       0.89      0.89      0.89      9000
# weighted avg       0.89      0.89      0.89      9000
#
#
#
# DEV:
# Dummy Classifier
#
# Accuracy:  0.573
# F1 macro:  0.3642720915448188
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73       573
#            1       0.00      0.00      0.00       427
#
#     accuracy                           0.57      1000
#    macro avg       0.29      0.50      0.36      1000
# weighted avg       0.33      0.57      0.42      1000
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.738
# F1 macro:  0.7302028627329833
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78       573
#            1       0.70      0.67      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.738
# F1 macro:  0.734550214588796
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       573
#            1       0.68      0.73      0.70       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.74      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Ridge Classifier
#
# Accuracy:  0.717
# F1 macro:  0.7098480444475885
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76       573
#            1       0.67      0.66      0.66       427
#
#     accuracy                           0.72      1000
#    macro avg       0.71      0.71      0.71      1000
# weighted avg       0.72      0.72      0.72      1000
#
# Random Forest classifier
#
# Accuracy:  0.74
# F1 macro:  0.7314926119159448
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       573
#            1       0.71      0.66      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Support Vector Classification
#
# Accuracy:  0.745
# F1 macro:  0.7344853545245258
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79       573
#            1       0.73      0.64      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# AdaBoost classifier
#
# Accuracy:  0.739
# F1 macro:  0.7258515670051333
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79       573
#            1       0.73      0.61      0.67       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.72      0.73      1000
# weighted avg       0.74      0.74      0.73      1000
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.7
# F1 macro:  0.6930946291560103
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74       573
#            1       0.65      0.64      0.65       427
#
#     accuracy                           0.70      1000
#    macro avg       0.69      0.69      0.69      1000
# weighted avg       0.70      0.70      0.70      1000

# %%
print("TRAIN:\n", train_scores_english)
print("\n\nDEV:\n", dev_scores_english)
# Out:
# TRAIN:
#                                      Accuracy  F1 macro
# Dummy Classifier                    0.579667  0.366955
# Multinomial Naive Bayes classifier  0.820444  0.812630
# Bernoulli Naive Bayes classifier    0.826000  0.821029
# Ridge Classifier                    0.881667  0.877431
# Random Forest classifier            0.999000  0.998974
# Support Vector Classification       0.957556  0.956309
# AdaBoost classifier                 0.781667  0.767939
# Multi-layer Perceptron classifier   0.891444  0.888015
#
#
# DEV:
#                                      Accuracy  F1 macro
# Dummy Classifier                       0.573  0.364272
# Multinomial Naive Bayes classifier     0.738  0.730203
# Bernoulli Naive Bayes classifier       0.738  0.734550
# Ridge Classifier                       0.717  0.709848
# Random Forest classifier               0.740  0.731493
# Support Vector Classification          0.745  0.734485
# AdaBoost classifier                    0.739  0.725852
# Multi-layer Perceptron classifier      0.700  0.693095

# %%
fit_models(X_train_spanish, spanish_train['HS'], models)

print("TRAIN:")
train_scores_spanish, train_preds_spanish = print_scores(X_train_spanish, spanish_train["HS"], models)

print("\n\nDEV:")
dev_scores_spanish, dev_preds_spanish = print_scores(X_dev_spanish, spanish_dev["HS"], models)
# Out:
# Model Dummy Classifier fitted
# Model Multinomial Naive Bayes classifier fitted
# Model Bernoulli Naive Bayes classifier fitted
# Model Ridge Classifier fitted
# Model Random Forest classifier fitted
# Model Support Vector Classification fitted
# Model AdaBoost classifier fitted
# Model Multi-layer Perceptron classifier fitted
# TRAIN:
# Dummy Classifier
#
# Accuracy:  0.5873333333333334
# F1 macro:  0.37001259974800504
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74      2643
#            1       0.00      0.00      0.00      1857
#
#     accuracy                           0.59      4500
#    macro avg       0.29      0.50      0.37      4500
# weighted avg       0.34      0.59      0.43      4500
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.8624444444444445
# F1 macro:  0.8514738322806575
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      2643
#            1       0.94      0.72      0.81      1857
#
#     accuracy                           0.86      4500
#    macro avg       0.88      0.84      0.85      4500
# weighted avg       0.87      0.86      0.86      4500
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.8808888888888889
# F1 macro:  0.8776877260140155
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      2643
#            1       0.84      0.87      0.86      1857
#
#     accuracy                           0.88      4500
#    macro avg       0.88      0.88      0.88      4500
# weighted avg       0.88      0.88      0.88      4500
#
# Ridge Classifier
#
# Accuracy:  0.936
# F1 macro:  0.9337121832097052
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      2643
#            1       0.93      0.91      0.92      1857
#
#     accuracy                           0.94      4500
#    macro avg       0.94      0.93      0.93      4500
# weighted avg       0.94      0.94      0.94      4500
#
# Random Forest classifier
#
# Accuracy:  0.9997777777777778
# F1 macro:  0.9997708031186054
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2643
#            1       1.00      1.00      1.00      1857
#
#     accuracy                           1.00      4500
#    macro avg       1.00      1.00      1.00      4500
# weighted avg       1.00      1.00      1.00      4500
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Support Vector Classification
#
# Accuracy:  0.9771111111111112
# F1 macro:  0.9763348654827293
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2643
#            1       0.98      0.96      0.97      1857
#
#     accuracy                           0.98      4500
#    macro avg       0.98      0.98      0.98      4500
# weighted avg       0.98      0.98      0.98      4500
#
# AdaBoost classifier
#
# Accuracy:  0.7824444444444445
# F1 macro:  0.7697403786836509
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.82      2643
#            1       0.78      0.66      0.72      1857
#
#     accuracy                           0.78      4500
#    macro avg       0.78      0.76      0.77      4500
# weighted avg       0.78      0.78      0.78      4500
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.9153333333333333
# F1 macro:  0.9123738230327386
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      2643
#            1       0.91      0.89      0.90      1857
#
#     accuracy                           0.92      4500
#    macro avg       0.91      0.91      0.91      4500
# weighted avg       0.92      0.92      0.92      4500
#
#
#
# DEV:
# Dummy Classifier
#
# Accuracy:  0.556
# F1 macro:  0.3573264781491003
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71       278
#            1       0.00      0.00      0.00       222
#
#     accuracy                           0.56       500
#    macro avg       0.28      0.50      0.36       500
# weighted avg       0.31      0.56      0.40       500
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.73
# F1 macro:  0.7094412231878817
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.90      0.79       278
#            1       0.80      0.52      0.63       222
#
#     accuracy                           0.73       500
#    macro avg       0.75      0.71      0.71       500
# weighted avg       0.75      0.73      0.72       500
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.764
# F1 macro:  0.7614195134575569
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       278
#            1       0.73      0.74      0.74       222
#
#     accuracy                           0.76       500
#    macro avg       0.76      0.76      0.76       500
# weighted avg       0.76      0.76      0.76       500
#
# Ridge Classifier
#
# Accuracy:  0.74
# F1 macro:  0.733850890985325
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       278
#            1       0.73      0.66      0.69       222
#
#     accuracy                           0.74       500
#    macro avg       0.74      0.73      0.73       500
# weighted avg       0.74      0.74      0.74       500
#
# Random Forest classifier
#
# Accuracy:  0.742
# F1 macro:  0.7281131049483416
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79       278
#            1       0.78      0.58      0.67       222
#
#     accuracy                           0.74       500
#    macro avg       0.75      0.73      0.73       500
# weighted avg       0.75      0.74      0.73       500
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Support Vector Classification
#
# Accuracy:  0.752
# F1 macro:  0.7416666666666666
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.86      0.79       278
#            1       0.78      0.62      0.69       222
#
#     accuracy                           0.75       500
#    macro avg       0.76      0.74      0.74       500
# weighted avg       0.76      0.75      0.75       500
#
# AdaBoost classifier
#
# Accuracy:  0.75
# F1 macro:  0.741819819149947
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79       278
#            1       0.76      0.64      0.70       222
#
#     accuracy                           0.75       500
#    macro avg       0.75      0.74      0.74       500
# weighted avg       0.75      0.75      0.75       500
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.734
# F1 macro:  0.7291363727083511
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77       278
#            1       0.71      0.68      0.69       222
#
#     accuracy                           0.73       500
#    macro avg       0.73      0.73      0.73       500
# weighted avg       0.73      0.73      0.73       500

# %%
print("TRAIN:\n", train_scores_spanish)
print("\n\nDEV:\n", dev_scores_spanish)
# Out:
# TRAIN:
#                                      Accuracy  F1 macro
# Dummy Classifier                    0.587333  0.370013
# Multinomial Naive Bayes classifier  0.862444  0.851474
# Bernoulli Naive Bayes classifier    0.880889  0.877688
# Ridge Classifier                    0.936000  0.933712
# Random Forest classifier            0.999778  0.999771
# Support Vector Classification       0.977111  0.976335
# AdaBoost classifier                 0.782444  0.769740
# Multi-layer Perceptron classifier   0.915333  0.912374
#
#
# DEV:
#                                      Accuracy  F1 macro
# Dummy Classifier                       0.556  0.357326
# Multinomial Naive Bayes classifier     0.730  0.709441
# Bernoulli Naive Bayes classifier       0.764  0.761420
# Ridge Classifier                       0.740  0.733851
# Random Forest classifier               0.742  0.728113
# Support Vector Classification          0.752  0.741667
# AdaBoost classifier                    0.750  0.741820
# Multi-layer Perceptron classifier      0.734  0.729136

# %% [markdown]
# # Chack relevance of the extra data in the predicition
# print(ridge.coef_.max(), ridge.coef_.min())
# print(ridge.coef_[0, -2:])
#
# print(random_forest.feature_importances_.max(), random_forest.feature_importances_.min())
# print(random_forest.feature_importances_[-2:])

# %% [markdown]
# ## Best hyperparameters

# %%
from sklearn.model_selection import GridSearchCV

def plot_gridsearch(results, feature, model_name):
    #plot the results
    plt.figure(figsize=(13, 13))
    plt.title(model_name, fontsize=16)

    plt.xlabel(feature)
    plt.ylabel("Score")

    ax = plt.gca()

    # Get the regular numpy array from the MaskedArray
    X_axis = np.array(results['param_' + feature].data, dtype=float)


    for sample, style in (('train', '--'), ('test', '-')):
        sample_score_mean = (results['mean_%s_score' % (sample)])
        sample_score_std = (results['std_%s_score' % (sample)])
        ax.fill_between(X_axis, sample_score_mean - sample_score_std, sample_score_mean + sample_score_std, alpha=0.1 if sample == 'test' else 0)
        ax.plot(X_axis, sample_score_mean, style, alpha=1 if sample == 'test' else 0.7, label="(%s)" % ( sample))

    best_index = np.nonzero(results['rank_test_score' ] == 1)[0][0]
    best_score =  (results['mean_test_score' ][best_index])

    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [best_score, best_score], linestyle='-.',  marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.2f" % best_score, (X_axis[best_index], best_score + 0.005))

    plt.legend(loc="best")
    plt.grid(False)
    
    print(f"Best {feature}: {X_axis[best_index]} ({best_score})")
    plt.show()

# %%
def print_grid_search(grid_search, k=10):
    for iteration, i in enumerate((-grid_search.cv_results_['mean_test_score']).argsort()[:k]):
        print(iteration + 1, grid_search.cv_results_['params'][i])
        print("score: ", grid_search.cv_results_['mean_test_score'][i], grid_search.cv_results_['mean_train_score'][i])
        print("std: ", grid_search.cv_results_['std_test_score'][i], grid_search.cv_results_['std_train_score'][i], "\n")

# %% [markdown]
# ### Multinomial Naive Bayes classifier

# %%
from sklearn.model_selection import GridSearchCV

grid_search_multinomial = GridSearchCV(multinomial, param_grid={'alpha': [1.1 ** (-i) for i in range(-20,20)]}, scoring='f1_macro', return_train_score=True, n_jobs = -1, cv=10)
grid_search_multinomial.fit(X_train_english, english_train['HS'])

plot_gridsearch(grid_search_multinomial.cv_results_, 'alpha', models[multinomial])
# Out:
# Best alpha: 1.4641000000000004 (0.7030152737733213)

# %% [markdown]
# ### Bernoulli Naive Bayes classifier

# %%
grid_search_bernoulli = GridSearchCV(bernoulli, param_grid={'alpha': [1.1 ** (-i) for i in range(-20,20)]}, scoring='f1_macro', return_train_score=True, n_jobs = -1, cv=10)
grid_search_bernoulli.fit(X_train_english, english_train['HS'])

plot_gridsearch(grid_search_bernoulli.cv_results_, 'alpha', models[bernoulli])
# Out:
# Best alpha: 1.6105100000000006 (0.7257916414512791)

# %% [markdown]
# ### Ridge Classifier

# %%
grid_search_ridge = GridSearchCV(ridge, param_grid={'alpha': [1.1 ** (-i) for i in range(-20,20)]}, scoring='f1_macro', return_train_score=True, n_jobs=-1, cv=10)
grid_search_ridge.fit(X_train_english, english_train['HS'])

plot_gridsearch(grid_search_ridge.cv_results_, 'alpha', models[ridge])
# Out:
# Best alpha: 4.594972986357222 (0.7178032859645559)

# %% [markdown]
# ### Random Forest classifier

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [2 ** (i) for i in range(1,10)] + [None],
    'n_estimators': [2 ** (i) for i in range(1,10)],
    'min_samples_leaf': [1, 2, 4],
    'min_samples_split': [2, 5, 10],
}

grid_search_random_forest = GridSearchCV(random_forest,
                  param_grid=param_grid,
                  scoring='f1_macro', return_train_score=True, verbose=1, n_jobs=-1, cv=5)
grid_search_random_forest.fit(X_train_english, english_train['HS'])

print(grid_search_random_forest.best_params_)
# Out:
# Fitting 5 folds for each of 810 candidates, totalling 4050 fits
# {'bootstrap': True, 'max_depth': 256, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 512}

# %%
print_grid_search(grid_search_random_forest)
# Out:
# 1 {'bootstrap': True, 'max_depth': 256, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 512}
# score:  0.7211771061422689 0.9980325117916463
# std:  0.08187084155098506 0.0005134463995595155
#
# 2 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 256}
# score:  0.72044761855465 0.9982609116809344
# std:  0.0796261259988122 0.00031754154690730635
#
# 3 {'bootstrap': True, 'max_depth': 512, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 256}
# score:  0.72044761855465 0.9982609116809344
# std:  0.0796261259988122 0.00031754154690730635
#
# 4 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 512}
# score:  0.7204397371724452 0.9990021998265055
# std:  0.07955299985830881 0.00015620659571933672
#
# 5 {'bootstrap': True, 'max_depth': 512, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 512}
# score:  0.7204397371724452 0.9990021998265055
# std:  0.07955299985830881 0.00015620659571933672
#
# 6 {'bootstrap': True, 'max_depth': 512, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 256}
# score:  0.7201689240299123 0.9953538695067466
# std:  0.0817548202118252 0.0007133690337179664
#
# 7 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 256}
# score:  0.7201689240299123 0.9953538695067466
# std:  0.0817548202118252 0.0007133690337179664
#
# 8 {'bootstrap': True, 'max_depth': 256, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 256}
# score:  0.7200840590584321 0.9979184372092986
# std:  0.08205563719248969 0.0004652066023504834
#
# 9 {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 512}
# score:  0.719786802425056 0.9959530003764998
# std:  0.08268145043937486 0.0007301004565822838
#
# 10 {'bootstrap': True, 'max_depth': 512, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 512}
# score:  0.719786802425056 0.9959530003764998
# std:  0.08268145043937486 0.0007301004565822838

# %%
grid_search_random_forest_2 = GridSearchCV(RandomForestClassifier(bootstrap=True, max_depth=256, min_samples_leaf=1, min_samples_split=5, n_estimators=512, random_state=42),
                  param_grid={'max_features': [1.25 ** (-i) for i in range(40)] + [X_train.shape[1] ** 0.5, np.log2(X_train.shape[1])]}, # last two = sqrt and log2
                  scoring='f1_macro', return_train_score=True, verbose=1, n_jobs=-1, cv=10)
 
grid_search_random_forest_2.fit(X_train_english, english_train['HS'])
plot_gridsearch(grid_search_random_forest_2.cv_results_, 'max_features', models[random_forest])
# Out:
# Fitting 10 folds for each of 42 candidates, totalling 420 fits
# C:\Users\BlondeFer\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:921: UserWarning: One or more of the test scores are non-finite: [0.72753618 0.72799779 0.72755404 0.7302256  0.72969537 0.72878214
#  0.72841067 0.73011699 0.72913017 0.73078005 0.73065794 0.73109594
#  0.73399913 0.73418059 0.73607925 0.73397923 0.73584949 0.73470235
#  0.73656865 0.73626748 0.73544326 0.73669929 0.73341643 0.73119733
#  0.72598107 0.72434664 0.71865583 0.71450503 0.70671673 0.69639988
#  0.68612221 0.67615627 0.64423944 0.64423944 0.56441776 0.56441776
#  0.56441776 0.56441776 0.56441776 0.56441776        nan        nan]
#   category=UserWarning
# C:\Users\BlondeFer\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:921: UserWarning: One or more of the train scores are non-finite: [0.99793434 0.99787102 0.99778232 0.99787104 0.997833   0.99785831
#  0.99792166 0.99787103 0.99783303 0.99783308 0.99794713 0.99797246
#  0.99793446 0.9978965  0.99792182 0.9980359  0.99807391 0.99812459
#  0.99794697 0.99774393 0.99724906 0.99644942 0.99528091 0.99381905
#  0.99211377 0.99027904 0.98782941 0.9860658  0.98240366 0.9802988
#  0.97635006 0.97012504 0.95864207 0.95864207 0.90589377 0.90589377
#  0.90589377 0.90589377 0.90589377 0.90589377        nan        nan]
#   category=UserWarning
# Best max_features: 0.009223372036854775 (0.7366992862857142)

# %% [markdown]
# ### Support Vector Classification

# %%
param_grid = [{'kernel': ['rbf', 'linear', 'sigmoid'], 'C': [1.25 ** i for i in range(30)]}]

grid_search_svc = GridSearchCV(svc,
                  param_grid=param_grid,
                  scoring='f1_macro', return_train_score=True, verbose=1, n_jobs=-1, cv=10)
grid_search_svc.fit(X_train_english, english_train['HS'])

print(grid_search_svc.best_params_)
# Out:
# Fitting 10 folds for each of 90 candidates, totalling 900 fits
# {'C': 1.25, 'kernel': 'rbf'}

# %%
print_grid_search(grid_search_svc)
# Out:
# 1 {'C': 1.25, 'kernel': 'rbf'}
# score:  0.7256869632572098 0.9774198944245172
# std:  0.07028980487619943 0.0012667417379980542
#
# 2 {'C': 1.0, 'kernel': 'linear'}
# score:  0.7232218938518609 0.8598128177472508
# std:  0.06889058375778051 0.004916139578449366
#
# 3 {'C': 1.0, 'kernel': 'rbf'}
# score:  0.722420000756059 0.9584546599227813
# std:  0.06598793856917287 0.002093336645136775
#
# 4 {'C': 1.5625, 'kernel': 'rbf'}
# score:  0.722399479782383 0.9888443224537624
# std:  0.07199664225359012 0.0009368204650846254
#
# 5 {'C': 1.0, 'kernel': 'sigmoid'}
# score:  0.7221347437317223 0.8078676840747624
# std:  0.0681506862158759 0.0065270911145425626
#
# 6 {'C': 86.73617379884035, 'kernel': 'rbf'}
# score:  0.7221273976430322 0.9989863676139541
# std:  0.07096146020651312 0.00011337364572931995
#
# 7 {'C': 69.38893903907228, 'kernel': 'rbf'}
# score:  0.7221273976430322 0.9989863676139541
# std:  0.07096146020651312 0.00011337364572931995
#
# 8 {'C': 169.40658945086008, 'kernel': 'rbf'}
# score:  0.7221273976430322 0.9989863676139541
# std:  0.07096146020651312 0.00011337364572931995
#
# 9 {'C': 211.75823681357508, 'kernel': 'rbf'}
# score:  0.7221273976430322 0.9989863676139541
# std:  0.07096146020651312 0.00011337364572931995
#
# 10 {'C': 264.6977960169689, 'kernel': 'rbf'}
# score:  0.7221273976430322 0.9989863676139541
# std:  0.07096146020651312 0.00011337364572931995

# %%
grid_search_svc_2 = GridSearchCV(SVC(C=1.25, kernel='rbf', random_state=42),
                  param_grid={'gamma': [1.25 ** (-i) for i in range(30)] + ['scale', 'auto']},
                  scoring='f1_macro', return_train_score=True, verbose=1, n_jobs = -1, cv=10)
 
grid_search_svc_2.fit(X_train_english, english_train['HS'])
print(grid_search_svc_2.best_params_)
# Out:
# Fitting 10 folds for each of 32 candidates, totalling 320 fits
# {'gamma': 1.0}

# %%
print_grid_search(grid_search_svc_2)
# Out:
# 1 {'gamma': 1.0}
# score:  0.7258167249329469 0.9768872942096092
# std:  0.07015162428504602 0.0011478902579258189
#
# 2 {'gamma': 'scale'}
# score:  0.7256869632572098 0.9774198944245172
# std:  0.07028980487619943 0.0012667417379980542
#
# 3 {'gamma': 0.512}
# score:  0.7256270521632684 0.9120121046613694
# std:  0.0670308196299068 0.0035684427699647866
#
# 4 {'gamma': 0.8}
# score:  0.7252856747864351 0.9566877057811034
# std:  0.06964197556390557 0.002091927136888322
#
# 5 {'gamma': 0.4096}
# score:  0.7251920681535109 0.8891064922596577
# std:  0.06542802596203082 0.004197298399689287
#
# 6 {'gamma': 0.64}
# score:  0.7239659936641247 0.9341322339556578
# std:  0.06760723945339617 0.003783087858440654
#
# 7 {'gamma': 0.32768}
# score:  0.721696352447401 0.8691349812109233
# std:  0.06654800289044162 0.004734614685150616
#
# 8 {'gamma': 0.262144}
# score:  0.7197053739060524 0.8505602228177448
# std:  0.06725191719465788 0.005925083728178732
#
# 9 {'gamma': 0.2097152}
# score:  0.7174080629610617 0.8349670010798305
# std:  0.06644761138893143 0.006694903536933474
#
# 10 {'gamma': 0.16777216}
# score:  0.7130305798517248 0.8196698445201243
# std:  0.06417609848235754 0.00641887927972816

# %% [markdown]
# ### AdaBoost Classifier

# %%
param_grid = {'n_estimators': [2 ** (i) for i in range(1,10)],
              'learning_rate': [0.1 * (i) for i in range(5,25)],
              'algorithm': ['SAMME.R']
              }

grid_search_adaboost = GridSearchCV(adaboost,
                  param_grid=param_grid,
                  scoring='f1_macro', return_train_score=True, verbose=1, n_jobs=-1, cv=10)
grid_search_adaboost.fit(X_train_english, english_train['HS'])

print(grid_search_adaboost.best_params_)
# Out:
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# {'algorithm': 'SAMME.R', 'learning_rate': 0.7000000000000001, 'n_estimators': 256}

# %%
print_grid_search(grid_search_adaboost)
# Out:
# 1 {'algorithm': 'SAMME.R', 'learning_rate': 0.7000000000000001, 'n_estimators': 256}
# score:  0.712632840377788 0.8225154311835787
# std:  0.07431863130127009 0.005443977718236347
#
# 2 {'algorithm': 'SAMME.R', 'learning_rate': 0.8, 'n_estimators': 64}
# score:  0.7122050882008215 0.772450693631815
# std:  0.069500974393686 0.007492901374299629
#
# 3 {'algorithm': 'SAMME.R', 'learning_rate': 0.5, 'n_estimators': 128}
# score:  0.7116679806780868 0.778595058978006
# std:  0.06722244161020745 0.007001627564099785
#
# 4 {'algorithm': 'SAMME.R', 'learning_rate': 0.6000000000000001, 'n_estimators': 128}
# score:  0.7113469979807773 0.786507603974096
# std:  0.06672722747095258 0.005200297834457556
#
# 5 {'algorithm': 'SAMME.R', 'learning_rate': 0.5, 'n_estimators': 512}
# score:  0.7107423269448259 0.8535302723231736
# std:  0.07109881685510672 0.005990052574239738
#
# 6 {'algorithm': 'SAMME.R', 'learning_rate': 1.1, 'n_estimators': 64}
# score:  0.7106128401735436 0.7770678418857161
# std:  0.0744645576842317 0.00802260046784705
#
# 7 {'algorithm': 'SAMME.R', 'learning_rate': 0.5, 'n_estimators': 64}
# score:  0.7103708910440321 0.7545566506322745
# std:  0.0639917994653713 0.007368639722764853
#
# 8 {'algorithm': 'SAMME.R', 'learning_rate': 0.5, 'n_estimators': 256}
# score:  0.7098415580813509 0.8115665381282616
# std:  0.07143702047069894 0.005907674948142027
#
# 9 {'algorithm': 'SAMME.R', 'learning_rate': 0.7000000000000001, 'n_estimators': 64}
# score:  0.7092375554383852 0.7674050567074298
# std:  0.06892075972117793 0.007454477926654814
#
# 10 {'algorithm': 'SAMME.R', 'learning_rate': 0.6000000000000001, 'n_estimators': 256}
# score:  0.7091443197837048 0.8175476261706978
# std:  0.07553183351971213 0.005801729283953699

# %% [markdown]
# ### MLP Classifier

# %%
param_grid = {
    'hidden_layer_sizes': [(512, 128, 32), (256, 256, 256), (512, 64), (256, 256), (1024,), (256,)],
    'activation': ['logistic', 'tanh', 'relu'],
}

grid_search_mlp = GridSearchCV(mlp,
                  param_grid=param_grid,
                  scoring='f1_macro', return_train_score=True, verbose=2, n_jobs=-1, cv=10)
grid_search_mlp.fit(X_train_english, english_train['HS'])

print(grid_search_mlp.best_params_)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 39.3min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed: 47.3min finished
# {'activation': 'logistic', 'hidden_layer_sizes': (512, 128, 32)}

# %%
print_grid_search(grid_search_mlp)
# Out:
# 1 {'activation': 'logistic', 'hidden_layer_sizes': (512, 128, 32)}
# score:  0.718382993298716 0.8460031721480291
# std:  0.06713930161269371 0.02480298959577832
#
# 2 {'activation': 'relu', 'hidden_layer_sizes': (512, 64)}
# score:  0.7169288809003502 0.879979117961833
# std:  0.07933498113457435 0.0041029103023282176
#
# 3 {'activation': 'relu', 'hidden_layer_sizes': (256, 256, 256)}
# score:  0.7139740368795363 0.8508657637330131
# std:  0.07220429799195167 0.036845099371234986
#
# 4 {'activation': 'relu', 'hidden_layer_sizes': (1024,)}
# score:  0.7127306752842438 0.8531087366776328
# std:  0.07192598029106499 0.03093290619837004
#
# 5 {'activation': 'logistic', 'hidden_layer_sizes': (512, 64)}
# score:  0.7118848567415542 0.8458758515718525
# std:  0.07888406010718442 0.015987047845431132
#
# 6 {'activation': 'tanh', 'hidden_layer_sizes': (512, 128, 32)}
# score:  0.7118232016563286 0.8486536645794113
# std:  0.07866574339037274 0.011966381083145133
#
# 7 {'activation': 'tanh', 'hidden_layer_sizes': (256, 256)}
# score:  0.7114399941848071 0.8204888879133689
# std:  0.07326685931696204 0.005738807606690854
#
# 8 {'activation': 'logistic', 'hidden_layer_sizes': (256, 256, 256)}
# score:  0.7101703359801246 0.8494945779243549
# std:  0.07728034166980217 0.019068190655885026
#
# 9 {'activation': 'relu', 'hidden_layer_sizes': (256, 256)}
# score:  0.7098822185887663 0.8684012734820591
# std:  0.07568064927394876 0.0361673145596886
#
# 10 {'activation': 'relu', 'hidden_layer_sizes': (256,)}
# score:  0.7084087986109797 0.8491857087010033
# std:  0.0755852390741969 0.01940433556053671

# %%
param_grid = {
    'solver': ['adam'],
    'beta_1': [0.9 + 0.025 * i for i in range(-3, 4)],
    'beta_2': [0.999 + 0.00025 * i for i in range(-3, 4)],
    'epsilon': [1e-8 + 25e-10 * i for i in range(-3, 4)]
}

grid_search_mlp_2 = GridSearchCV(MLPClassifier(activation='logistic', hidden_layer_sizes=(512, 128, 32), early_stopping=True, random_state=42),
                  param_grid=param_grid,
                  scoring='f1_macro', return_train_score=True, verbose=2, n_jobs=-1, cv=5)
grid_search_mlp_2.fit(X_train_english, english_train['HS'])

print(grid_search_mlp_2.best_params_)
# Out:
# Fitting 5 folds for each of 343 candidates, totalling 1715 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 48.7min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 115.6min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 216.9min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed: 344.8min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed: 515.8min
# [Parallel(n_jobs=-1)]: Done 1715 out of 1715 | elapsed: 636.4min finished
# {'beta_1': 0.875, 'beta_2': 0.99975, 'epsilon': 5e-09, 'solver': 'adam'}

# %%
print_grid_search(grid_search_mlp_2)
# Out:
# 1 {'beta_1': 0.875, 'beta_2': 0.99975, 'epsilon': 5e-09, 'solver': 'adam'}
# score:  0.7060063669510639 0.8396589959329888
# std:  0.06061712830006985 0.014195862176696222
#
# 2 {'beta_1': 0.875, 'beta_2': 0.99875, 'epsilon': 1e-08, 'solver': 'adam'}
# score:  0.7059735458106069 0.8386175107250015
# std:  0.061095089808428 0.013198932931836516
#
# 3 {'beta_1': 0.875, 'beta_2': 0.9985, 'epsilon': 1.25e-08, 'solver': 'adam'}
# score:  0.7058894059881171 0.8375222307149819
# std:  0.060872326030128515 0.013299767711536197
#
# 4 {'beta_1': 0.9750000000000001, 'beta_2': 0.999, 'epsilon': 1.5000000000000002e-08, 'solver': 'adam'}
# score:  0.7055577674237155 0.8369602940839368
# std:  0.05549091771553361 0.02553158170021679
#
# 5 {'beta_1': 0.875, 'beta_2': 0.9985, 'epsilon': 1e-08, 'solver': 'adam'}
# score:  0.7055374424551338 0.8384077219872175
# std:  0.060951873926050046 0.013294981002692746
#
# 6 {'beta_1': 0.875, 'beta_2': 0.99925, 'epsilon': 5e-09, 'solver': 'adam'}
# score:  0.7053667509009288 0.8411264643568913
# std:  0.060167808618067344 0.013887682160838778
#
# 7 {'beta_1': 0.875, 'beta_2': 0.9985, 'epsilon': 7.500000000000001e-09, 'solver': 'adam'}
# score:  0.7049027364298835 0.8395439820498722
# std:  0.06031707055068963 0.013401312890112052
#
# 8 {'beta_1': 0.875, 'beta_2': 0.999, 'epsilon': 5e-09, 'solver': 'adam'}
# score:  0.7048824433296876 0.8411035704290388
# std:  0.05999968049000832 0.013767980012225883
#
# 9 {'beta_1': 0.875, 'beta_2': 0.99875, 'epsilon': 7.500000000000001e-09, 'solver': 'adam'}
# score:  0.7047830273683537 0.8426517678025984
# std:  0.06036162730607876 0.016019266229898143
#
# 10 {'beta_1': 0.875, 'beta_2': 0.99975, 'epsilon': 1.25e-08, 'solver': 'adam'}
# score:  0.7045845782240077 0.838008826365803
# std:  0.058185851104477486 0.018440757143757237

# %%
import pickle

with open("./data/grid_search_mlp_2.pkl", "wb") as f:
    #pickle.dump(grid_search_mlp_2.cv_results_, f)
    
    grid_search_mlp_2_cv_results_ = pickle.load(f)

grid_search_mlp_2_cv_results_

# %% [markdown]
# ## Best Models

# %%
#Dummy is same
best_multinomial = MultinomialNB(alpha=1.5)
best_bernoulli = BernoulliNB(alpha=1.6)
best_ridge = RidgeClassifier(alpha=4.6, random_state=42)
best_random_forest = RandomForestClassifier(bootstrap=True, max_depth=256, min_samples_leaf=1, min_samples_split=5, n_estimators=512, max_features=0.01, random_state=42)
best_mlp = MLPClassifier(solver='adam', beta_1=0.875, beta_2=0.99975, epsilon=5e-09, activation='logistic', hidden_layer_sizes=(512, 128, 32), early_stopping=True, random_state=42)
best_svc = SVC(C=0.512, kernel='rbf', gamma=0.4, random_state=42)
best_adaboost = AdaBoostClassifier(algorithm='SAMME.R', learning_rate=0.7, n_estimators=256, random_state=42)

best_models = {
    dummy: "Dummy Classifier",
    best_multinomial: "Best Multinomial Naive Bayes classifier",
    best_bernoulli: "Best Bernoulli Naive Bayes classifier",
    best_ridge: "Best Ridge Classifier",
    best_random_forest: "Best Random Forest classifier",
    best_svc: "Best Support Vector Classification",
    best_adaboost: "Best AdaBoost classifier",
    best_mlp: "Best Multi-layer Perceptron classifier"
}

all_models = {x: y for two_models in zip(models.items(), best_models.items()) for x, y in two_models}
fit_models(X_train_english, english_train['HS'], all_models)

print("\n\nTRAIN:")
all_train_scores_english, all_train_preds_english = print_scores(X_train_english, english_train["HS"], all_models)

print("\n\nDEV:")
all_dev_scores_english, all_dev_preds_english = print_scores(X_dev_english, english_dev["HS"], all_models)

print("\n\nTEST:")
all_test_scores_english, all_test_preds_english = print_scores(X_test_english, english_test["HS"], all_models)
# Out:
# Model Dummy Classifier fitted
# Model Multinomial Naive Bayes classifier fitted
# Model Best Multinomial Naive Bayes classifier fitted
# Model Bernoulli Naive Bayes classifier fitted
# Model Best Bernoulli Naive Bayes classifier fitted
# Model Ridge Classifier fitted
# Model Best Ridge Classifier fitted
# Model Random Forest classifier fitted
# Model Best Random Forest classifier fitted
# Model Support Vector Classification fitted
# Model Best Support Vector Classification fitted
# Model AdaBoost classifier fitted
# Model Best AdaBoost classifier fitted
# Model Multi-layer Perceptron classifier fitted
# Model Best Multi-layer Perceptron classifier fitted
#
#
# TRAIN:
# Dummy Classifier
#
# Accuracy:  0.5796666666666667
# F1 macro:  0.3669550538088204
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73      5217
#            1       0.00      0.00      0.00      3783
#
#     accuracy                           0.58      9000
#    macro avg       0.29      0.50      0.37      9000
# weighted avg       0.34      0.58      0.43      9000
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.8204444444444444
# F1 macro:  0.8126298508371801
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      5217
#            1       0.82      0.73      0.77      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.82      0.81      0.81      9000
# weighted avg       0.82      0.82      0.82      9000
#
# Best Multinomial Naive Bayes classifier
#
# Accuracy:  0.8162222222222222
# F1 macro:  0.8071309065220538
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      5217
#            1       0.83      0.71      0.77      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.82      0.80      0.81      9000
# weighted avg       0.82      0.82      0.81      9000
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.826
# F1 macro:  0.8210285714285713
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      5217
#            1       0.80      0.78      0.79      3783
#
#     accuracy                           0.83      9000
#    macro avg       0.82      0.82      0.82      9000
# weighted avg       0.83      0.83      0.83      9000
#
# Best Bernoulli Naive Bayes classifier
#
# Accuracy:  0.8208888888888889
# F1 macro:  0.8151335065345999
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      5217
#            1       0.80      0.77      0.78      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.82      0.81      0.82      9000
# weighted avg       0.82      0.82      0.82      9000
#
# Ridge Classifier
#
# Accuracy:  0.8816666666666667
# F1 macro:  0.8774313461768318
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      5217
#            1       0.88      0.83      0.85      3783
#
#     accuracy                           0.88      9000
#    macro avg       0.88      0.87      0.88      9000
# weighted avg       0.88      0.88      0.88      9000
#
# Best Ridge Classifier
#
# Accuracy:  0.8356666666666667
# F1 macro:  0.8271567865321129
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87      5217
#            1       0.86      0.73      0.79      3783
#
#     accuracy                           0.84      9000
#    macro avg       0.84      0.82      0.83      9000
# weighted avg       0.84      0.84      0.83      9000
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest classifier
#
# Accuracy:  0.999
# F1 macro:  0.9989737648560049
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5217
#            1       1.00      1.00      1.00      3783
#
#     accuracy                           1.00      9000
#    macro avg       1.00      1.00      1.00      9000
# weighted avg       1.00      1.00      1.00      9000
#
# Best Random Forest classifier
#
# Accuracy:  0.9966666666666667
# F1 macro:  0.9965763219746517
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5217
#            1       1.00      0.99      1.00      3783
#
#     accuracy                           1.00      9000
#    macro avg       1.00      1.00      1.00      9000
# weighted avg       1.00      1.00      1.00      9000
#
# Support Vector Classification
#
# Accuracy:  0.9575555555555556
# F1 macro:  0.9563093471055895
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      5217
#            1       0.96      0.94      0.95      3783
#
#     accuracy                           0.96      9000
#    macro avg       0.96      0.95      0.96      9000
# weighted avg       0.96      0.96      0.96      9000
#
# Best Support Vector Classification
#
# Accuracy:  0.8206666666666667
# F1 macro:  0.8078546622506662
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86      5217
#            1       0.87      0.67      0.76      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.83      0.80      0.81      9000
# weighted avg       0.83      0.82      0.82      9000
#
# AdaBoost classifier
#
# Accuracy:  0.7816666666666666
# F1 macro:  0.7679385989020957
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82      5217
#            1       0.80      0.64      0.71      3783
#
#     accuracy                           0.78      9000
#    macro avg       0.79      0.76      0.77      9000
# weighted avg       0.78      0.78      0.78      9000
#
# Best AdaBoost classifier
#
# Accuracy:  0.824
# F1 macro:  0.8148955676525538
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.90      0.86      5217
#            1       0.84      0.72      0.77      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.83      0.81      0.81      9000
# weighted avg       0.83      0.82      0.82      9000
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.8914444444444445
# F1 macro:  0.8880149007808582
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      5217
#            1       0.89      0.85      0.87      3783
#
#     accuracy                           0.89      9000
#    macro avg       0.89      0.89      0.89      9000
# weighted avg       0.89      0.89      0.89      9000
#
# Best Multi-layer Perceptron classifier
#
# Accuracy:  0.8217777777777778
# F1 macro:  0.8173712296381446
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      5217
#            1       0.79      0.79      0.79      3783
#
#     accuracy                           0.82      9000
#    macro avg       0.82      0.82      0.82      9000
# weighted avg       0.82      0.82      0.82      9000
#
#
#
# DEV:
# Dummy Classifier
#
# Accuracy:  0.573
# F1 macro:  0.3642720915448188
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73       573
#            1       0.00      0.00      0.00       427
#
#     accuracy                           0.57      1000
#    macro avg       0.29      0.50      0.36      1000
# weighted avg       0.33      0.57      0.42      1000
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.738
# F1 macro:  0.7302028627329833
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78       573
#            1       0.70      0.67      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Best Multinomial Naive Bayes classifier
#
# Accuracy:  0.742
# F1 macro:  0.7329590620031796
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78       573
#            1       0.72      0.65      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.738
# F1 macro:  0.734550214588796
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       573
#            1       0.68      0.73      0.70       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.74      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Best Bernoulli Naive Bayes classifier
#
# Accuracy:  0.738
# F1 macro:  0.7344264422063284
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77       573
#            1       0.68      0.73      0.70       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.74      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Ridge Classifier
#
# Accuracy:  0.717
# F1 macro:  0.7098480444475885
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76       573
#            1       0.67      0.66      0.66       427
#
#     accuracy                           0.72      1000
#    macro avg       0.71      0.71      0.71      1000
# weighted avg       0.72      0.72      0.72      1000
#
# Best Ridge Classifier
#
# Accuracy:  0.744
# F1 macro:  0.7335542612583733
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79       573
#            1       0.73      0.64      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Random Forest classifier
#
# Accuracy:  0.74
# F1 macro:  0.7314926119159448
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       573
#            1       0.71      0.66      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Best Random Forest classifier
#
# Accuracy:  0.758
# F1 macro:  0.7506224134804043
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.81      0.79       573
#            1       0.73      0.69      0.71       427
#
#     accuracy                           0.76      1000
#    macro avg       0.75      0.75      0.75      1000
# weighted avg       0.76      0.76      0.76      1000
#
# Support Vector Classification
#
# Accuracy:  0.745
# F1 macro:  0.7344853545245258
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79       573
#            1       0.73      0.64      0.68       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
# Best Support Vector Classification
#
# Accuracy:  0.728
# F1 macro:  0.7069521297684922
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79       573
#            1       0.75      0.54      0.63       427
#
#     accuracy                           0.73      1000
#    macro avg       0.74      0.70      0.71      1000
# weighted avg       0.73      0.73      0.72      1000
#
# AdaBoost classifier
#
# Accuracy:  0.739
# F1 macro:  0.7258515670051333
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.84      0.79       573
#            1       0.73      0.61      0.67       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.72      0.73      1000
# weighted avg       0.74      0.74      0.73      1000
#
# Best AdaBoost classifier
#
# Accuracy:  0.716
# F1 macro:  0.7046539875871478
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76       573
#            1       0.69      0.61      0.65       427
#
#     accuracy                           0.72      1000
#    macro avg       0.71      0.70      0.70      1000
# weighted avg       0.71      0.72      0.71      1000
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.7
# F1 macro:  0.6930946291560103
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74       573
#            1       0.65      0.64      0.65       427
#
#     accuracy                           0.70      1000
#    macro avg       0.69      0.69      0.69      1000
# weighted avg       0.70      0.70      0.70      1000
#
# Best Multi-layer Perceptron classifier
#
# Accuracy:  0.736
# F1 macro:  0.7323991631392012
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       573
#            1       0.68      0.73      0.70       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.73      0.73      1000
# weighted avg       0.74      0.74      0.74      1000
#
#
#
# TEST:
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Dummy Classifier
#
# Accuracy:  0.58
# F1 macro:  0.36708860759493667
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73      1740
#            1       0.00      0.00      0.00      1260
#
#     accuracy                           0.58      3000
#    macro avg       0.29      0.50      0.37      3000
# weighted avg       0.34      0.58      0.43      3000
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.5056666666666667
# F1 macro:  0.4784764572972561
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.24      0.36      1740
#            1       0.45      0.87      0.60      1260
#
#     accuracy                           0.51      3000
#    macro avg       0.59      0.56      0.48      3000
# weighted avg       0.61      0.51      0.46      3000
#
# Best Multinomial Naive Bayes classifier
#
# Accuracy:  0.509
# F1 macro:  0.48378767377483683
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.25      0.37      1740
#            1       0.46      0.87      0.60      1260
#
#     accuracy                           0.51      3000
#    macro avg       0.59      0.56      0.48      3000
# weighted avg       0.61      0.51      0.47      3000
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.4726666666666667
# F1 macro:  0.4181881304494295
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.14      0.24      1740
#            1       0.44      0.93      0.60      1260
#
#     accuracy                           0.47      3000
#    macro avg       0.59      0.54      0.42      3000
# weighted avg       0.61      0.47      0.39      3000
#
# Best Bernoulli Naive Bayes classifier
#
# Accuracy:  0.47933333333333333
# F1 macro:  0.4290866116789922
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.16      0.26      1740
#            1       0.44      0.92      0.60      1260
#
#     accuracy                           0.48      3000
#    macro avg       0.59      0.54      0.43      3000
# weighted avg       0.62      0.48      0.40      3000
#
# Ridge Classifier
#
# Accuracy:  0.5136666666666667
# F1 macro:  0.4877331577792407
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.25      0.37      1740
#            1       0.46      0.88      0.60      1260
#
#     accuracy                           0.51      3000
#    macro avg       0.60      0.56      0.49      3000
# weighted avg       0.62      0.51      0.47      3000
#
# Best Ridge Classifier
#
# Accuracy:  0.5076666666666667
# F1 macro:  0.4802516140527483
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.24      0.36      1740
#            1       0.46      0.88      0.60      1260
#
#     accuracy                           0.51      3000
#    macro avg       0.59      0.56      0.48      3000
# weighted avg       0.61      0.51      0.46      3000
#
# Random Forest classifier
#
# Accuracy:  0.451
# F1 macro:  0.39359880393776636
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.64      0.12      0.21      1740
#            1       0.43      0.90      0.58      1260
#
#     accuracy                           0.45      3000
#    macro avg       0.53      0.51      0.39      3000
# weighted avg       0.55      0.45      0.36      3000
#
# Best Random Forest classifier
#
# Accuracy:  0.4513333333333333
# F1 macro:  0.39131991130872873
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.65      0.12      0.20      1740
#            1       0.43      0.91      0.58      1260
#
#     accuracy                           0.45      3000
#    macro avg       0.54      0.51      0.39      3000
# weighted avg       0.56      0.45      0.36      3000
#
# Support Vector Classification
#
# Accuracy:  0.48633333333333334
# F1 macro:  0.44732629900735116
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.71      0.19      0.30      1740
#            1       0.44      0.90      0.59      1260
#
#     accuracy                           0.49      3000
#    macro avg       0.58      0.54      0.45      3000
# weighted avg       0.60      0.49      0.42      3000
#
# Best Support Vector Classification
#
# Accuracy:  0.47533333333333333
# F1 macro:  0.4456682057728456
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.65      0.21      0.32      1740
#            1       0.44      0.84      0.57      1260
#
#     accuracy                           0.48      3000
#    macro avg       0.54      0.53      0.45      3000
# weighted avg       0.56      0.48      0.43      3000
#
# AdaBoost classifier
#
# Accuracy:  0.46366666666666667
# F1 macro:  0.41955762522951046
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.65      0.16      0.26      1740
#            1       0.43      0.88      0.58      1260
#
#     accuracy                           0.46      3000
#    macro avg       0.54      0.52      0.42      3000
# weighted avg       0.56      0.46      0.39      3000
#
# Best AdaBoost classifier
#
# Accuracy:  0.48533333333333334
# F1 macro:  0.4428953278257908
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.18      0.29      1740
#            1       0.44      0.91      0.60      1260
#
#     accuracy                           0.49      3000
#    macro avg       0.59      0.54      0.44      3000
# weighted avg       0.61      0.49      0.42      3000
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.5113333333333333
# F1 macro:  0.4837036783119388
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.24      0.36      1740
#            1       0.46      0.88      0.60      1260
#
#     accuracy                           0.51      3000
#    macro avg       0.60      0.56      0.48      3000
# weighted avg       0.62      0.51      0.46      3000
#
# Best Multi-layer Perceptron classifier
#
# Accuracy:  0.518
# F1 macro:  0.4883659271050003
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.24      0.37      1740
#            1       0.46      0.90      0.61      1260
#
#     accuracy                           0.52      3000
#    macro avg       0.62      0.57      0.49      3000
# weighted avg       0.64      0.52      0.47      3000

# %%
print("TRAIN:\n", all_train_scores_english)
print("\n\nDEV:\n", all_dev_scores_english)
print("\n\nTEST:\n", all_test_scores_english)
# Out:
# TRAIN:
#                                           Accuracy  F1 macro
# Dummy Classifier                         0.579667  0.366955
# Multinomial Naive Bayes classifier       0.820444  0.812630
# Best Multinomial Naive Bayes classifier  0.816222  0.807131
# Bernoulli Naive Bayes classifier         0.826000  0.821029
# Best Bernoulli Naive Bayes classifier    0.820889  0.815134
# Ridge Classifier                         0.881667  0.877431
# Best Ridge Classifier                    0.835667  0.827157
# Random Forest classifier                 0.999000  0.998974
# Best Random Forest classifier            0.996667  0.996576
# Support Vector Classification            0.957556  0.956309
# Best Support Vector Classification       0.820667  0.807855
# AdaBoost classifier                      0.781667  0.767939
# Best AdaBoost classifier                 0.824000  0.814896
# Multi-layer Perceptron classifier        0.891444  0.888015
# Best Multi-layer Perceptron classifier   0.821778  0.817371
#
#
# DEV:
#                                           Accuracy  F1 macro
# Dummy Classifier                            0.573  0.364272
# Multinomial Naive Bayes classifier          0.738  0.730203
# Best Multinomial Naive Bayes classifier     0.742  0.732959
# Bernoulli Naive Bayes classifier            0.738  0.734550
# Best Bernoulli Naive Bayes classifier       0.738  0.734426
# Ridge Classifier                            0.717  0.709848
# Best Ridge Classifier                       0.744  0.733554
# Random Forest classifier                    0.740  0.731493
# Best Random Forest classifier               0.758  0.750622
# Support Vector Classification               0.745  0.734485
# Best Support Vector Classification          0.728  0.706952
# AdaBoost classifier                         0.739  0.725852
# Best AdaBoost classifier                    0.716  0.704654
# Multi-layer Perceptron classifier           0.700  0.693095
# Best Multi-layer Perceptron classifier      0.736  0.732399
#
#
# TEST:
#                                           Accuracy  F1 macro
# Dummy Classifier                         0.580000  0.367089
# Multinomial Naive Bayes classifier       0.505667  0.478476
# Best Multinomial Naive Bayes classifier  0.509000  0.483788
# Bernoulli Naive Bayes classifier         0.472667  0.418188
# Best Bernoulli Naive Bayes classifier    0.479333  0.429087
# Ridge Classifier                         0.513667  0.487733
# Best Ridge Classifier                    0.507667  0.480252
# Random Forest classifier                 0.451000  0.393599
# Best Random Forest classifier            0.451333  0.391320
# Support Vector Classification            0.486333  0.447326
# Best Support Vector Classification       0.475333  0.445668
# AdaBoost classifier                      0.463667  0.419558
# Best AdaBoost classifier                 0.485333  0.442895
# Multi-layer Perceptron classifier        0.511333  0.483704
# Best Multi-layer Perceptron classifier   0.518000  0.488366

# %%
all_models = {x: y for two_models in zip(models.items(), best_models.items()) for x, y in two_models}

fit_models(X_train_spanish, spanish_train['HS'], all_models)

print("\n\nTRAIN:")
all_train_scores_spanish, all_train_preds_spanish = print_scores(X_train_spanish, spanish_train["HS"], all_models)

print("\n\nDEV:")
all_dev_scores_spanish, all_dev_preds_spanish = print_scores(X_dev_spanish, spanish_dev["HS"], all_models)

print("\n\nTEST:")
all_test_scores_spanish, all_test_preds_spanish = print_scores(X_test_spanish, spanish_test["HS"], all_models)
# Out:
# Model Dummy Classifier fitted
# Model Multinomial Naive Bayes classifier fitted
# Model Best Multinomial Naive Bayes classifier fitted
# Model Bernoulli Naive Bayes classifier fitted
# Model Best Bernoulli Naive Bayes classifier fitted
# Model Ridge Classifier fitted
# Model Best Ridge Classifier fitted
# Model Random Forest classifier fitted
# Model Best Random Forest classifier fitted
# Model Support Vector Classification fitted
# Model Best Support Vector Classification fitted
# Model AdaBoost classifier fitted
# Model Best AdaBoost classifier fitted
# Model Multi-layer Perceptron classifier fitted
# Model Best Multi-layer Perceptron classifier fitted
#
#
# TRAIN:
# Dummy Classifier
#
# Accuracy:  0.5873333333333334
# F1 macro:  0.37001259974800504
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74      2643
#            1       0.00      0.00      0.00      1857
#
#     accuracy                           0.59      4500
#    macro avg       0.29      0.50      0.37      4500
# weighted avg       0.34      0.59      0.43      4500
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.8624444444444445
# F1 macro:  0.8514738322806575
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      2643
#            1       0.94      0.72      0.81      1857
#
#     accuracy                           0.86      4500
#    macro avg       0.88      0.84      0.85      4500
# weighted avg       0.87      0.86      0.86      4500
#
# Best Multinomial Naive Bayes classifier
#
# Accuracy:  0.8366666666666667
# F1 macro:  0.8195755730146153
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.97      0.88      2643
#            1       0.95      0.64      0.76      1857
#
#     accuracy                           0.84      4500
#    macro avg       0.87      0.81      0.82      4500
# weighted avg       0.86      0.84      0.83      4500
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.8808888888888889
# F1 macro:  0.8776877260140155
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      2643
#            1       0.84      0.87      0.86      1857
#
#     accuracy                           0.88      4500
#    macro avg       0.88      0.88      0.88      4500
# weighted avg       0.88      0.88      0.88      4500
#
# Best Bernoulli Naive Bayes classifier
#
# Accuracy:  0.8755555555555555
# F1 macro:  0.871494135645079
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89      2643
#            1       0.85      0.85      0.85      1857
#
#     accuracy                           0.88      4500
#    macro avg       0.87      0.87      0.87      4500
# weighted avg       0.88      0.88      0.88      4500
#
# Ridge Classifier
#
# Accuracy:  0.936
# F1 macro:  0.9337121832097052
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95      2643
#            1       0.93      0.91      0.92      1857
#
#     accuracy                           0.94      4500
#    macro avg       0.94      0.93      0.93      4500
# weighted avg       0.94      0.94      0.94      4500
#
# Best Ridge Classifier
#
# Accuracy:  0.8713333333333333
# F1 macro:  0.8634846012673638
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      2643
#            1       0.91      0.77      0.83      1857
#
#     accuracy                           0.87      4500
#    macro avg       0.88      0.86      0.86      4500
# weighted avg       0.88      0.87      0.87      4500
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest classifier
#
# Accuracy:  0.9997777777777778
# F1 macro:  0.9997708031186054
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2643
#            1       1.00      1.00      1.00      1857
#
#     accuracy                           1.00      4500
#    macro avg       1.00      1.00      1.00      4500
# weighted avg       1.00      1.00      1.00      4500
#
# Best Random Forest classifier
#
# Accuracy:  0.9995555555555555
# F1 macro:  0.9995416428660481
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2643
#            1       1.00      1.00      1.00      1857
#
#     accuracy                           1.00      4500
#    macro avg       1.00      1.00      1.00      4500
# weighted avg       1.00      1.00      1.00      4500
#
# Support Vector Classification
#
# Accuracy:  0.9771111111111112
# F1 macro:  0.9763348654827293
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2643
#            1       0.98      0.96      0.97      1857
#
#     accuracy                           0.98      4500
#    macro avg       0.98      0.98      0.98      4500
# weighted avg       0.98      0.98      0.98      4500
#
# Best Support Vector Classification
#
# Accuracy:  0.8291111111111111
# F1 macro:  0.8116820679589106
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87      2643
#            1       0.93      0.64      0.75      1857
#
#     accuracy                           0.83      4500
#    macro avg       0.86      0.80      0.81      4500
# weighted avg       0.85      0.83      0.82      4500
#
# AdaBoost classifier
#
# Accuracy:  0.7824444444444445
# F1 macro:  0.7697403786836509
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.82      2643
#            1       0.78      0.66      0.72      1857
#
#     accuracy                           0.78      4500
#    macro avg       0.78      0.76      0.77      4500
# weighted avg       0.78      0.78      0.78      4500
#
# Best AdaBoost classifier
#
# Accuracy:  0.8697777777777778
# F1 macro:  0.8637300571496607
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      2643
#            1       0.87      0.80      0.84      1857
#
#     accuracy                           0.87      4500
#    macro avg       0.87      0.86      0.86      4500
# weighted avg       0.87      0.87      0.87      4500
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.9153333333333333
# F1 macro:  0.9123738230327386
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      2643
#            1       0.91      0.89      0.90      1857
#
#     accuracy                           0.92      4500
#    macro avg       0.91      0.91      0.91      4500
# weighted avg       0.92      0.92      0.92      4500
#
# Best Multi-layer Perceptron classifier
#
# Accuracy:  0.8766666666666667
# F1 macro:  0.8696649452350105
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      2643
#            1       0.91      0.78      0.84      1857
#
#     accuracy                           0.88      4500
#    macro avg       0.88      0.86      0.87      4500
# weighted avg       0.88      0.88      0.87      4500
#
#
#
# DEV:
# Dummy Classifier
#
# Accuracy:  0.556
# F1 macro:  0.3573264781491003
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.56      1.00      0.71       278
#            1       0.00      0.00      0.00       222
#
#     accuracy                           0.56       500
#    macro avg       0.28      0.50      0.36       500
# weighted avg       0.31      0.56      0.40       500
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.73
# F1 macro:  0.7094412231878817
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.90      0.79       278
#            1       0.80      0.52      0.63       222
#
#     accuracy                           0.73       500
#    macro avg       0.75      0.71      0.71       500
# weighted avg       0.75      0.73      0.72       500
#
# Best Multinomial Naive Bayes classifier
#
# Accuracy:  0.72
# F1 macro:  0.6898043108338061
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79       278
#            1       0.84      0.46      0.59       222
#
#     accuracy                           0.72       500
#    macro avg       0.76      0.69      0.69       500
# weighted avg       0.75      0.72      0.70       500
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.764
# F1 macro:  0.7614195134575569
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       278
#            1       0.73      0.74      0.74       222
#
#     accuracy                           0.76       500
#    macro avg       0.76      0.76      0.76       500
# weighted avg       0.76      0.76      0.76       500
#
# Best Bernoulli Naive Bayes classifier
#
# Accuracy:  0.77
# F1 macro:  0.7669715624252791
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       278
#            1       0.74      0.74      0.74       222
#
#     accuracy                           0.77       500
#    macro avg       0.77      0.77      0.77       500
# weighted avg       0.77      0.77      0.77       500
#
# Ridge Classifier
#
# Accuracy:  0.74
# F1 macro:  0.733850890985325
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       278
#            1       0.73      0.66      0.69       222
#
#     accuracy                           0.74       500
#    macro avg       0.74      0.73      0.73       500
# weighted avg       0.74      0.74      0.74       500
#
# Best Ridge Classifier
#
# Accuracy:  0.746
# F1 macro:  0.7356358685922922
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79       278
#            1       0.77      0.62      0.68       222
#
#     accuracy                           0.75       500
#    macro avg       0.75      0.73      0.74       500
# weighted avg       0.75      0.75      0.74       500
#
# Random Forest classifier
#
# Accuracy:  0.742
# F1 macro:  0.7281131049483416
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79       278
#            1       0.78      0.58      0.67       222
#
#     accuracy                           0.74       500
#    macro avg       0.75      0.73      0.73       500
# weighted avg       0.75      0.74      0.73       500
#
# Best Random Forest classifier
#
# Accuracy:  0.742
# F1 macro:  0.7259505691305623
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79       278
#            1       0.80      0.56      0.66       222
#
#     accuracy                           0.74       500
#    macro avg       0.76      0.72      0.73       500
# weighted avg       0.75      0.74      0.73       500
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Support Vector Classification
#
# Accuracy:  0.752
# F1 macro:  0.7416666666666666
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.86      0.79       278
#            1       0.78      0.62      0.69       222
#
#     accuracy                           0.75       500
#    macro avg       0.76      0.74      0.74       500
# weighted avg       0.76      0.75      0.75       500
#
# Best Support Vector Classification
#
# Accuracy:  0.738
# F1 macro:  0.7173983389062669
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.71      0.91      0.79       278
#            1       0.82      0.53      0.64       222
#
#     accuracy                           0.74       500
#    macro avg       0.76      0.72      0.72       500
# weighted avg       0.76      0.74      0.73       500
#
# AdaBoost classifier
#
# Accuracy:  0.75
# F1 macro:  0.741819819149947
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79       278
#            1       0.76      0.64      0.70       222
#
#     accuracy                           0.75       500
#    macro avg       0.75      0.74      0.74       500
# weighted avg       0.75      0.75      0.75       500
#
# Best AdaBoost classifier
#
# Accuracy:  0.752
# F1 macro:  0.74581413273422
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79       278
#            1       0.74      0.67      0.71       222
#
#     accuracy                           0.75       500
#    macro avg       0.75      0.74      0.75       500
# weighted avg       0.75      0.75      0.75       500
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.734
# F1 macro:  0.7291363727083511
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.78      0.77       278
#            1       0.71      0.68      0.69       222
#
#     accuracy                           0.73       500
#    macro avg       0.73      0.73      0.73       500
# weighted avg       0.73      0.73      0.73       500
#
# Best Multi-layer Perceptron classifier
#
# Accuracy:  0.716
# F1 macro:  0.6998444264069263
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77       278
#            1       0.75      0.55      0.63       222
#
#     accuracy                           0.72       500
#    macro avg       0.72      0.70      0.70       500
# weighted avg       0.72      0.72      0.71       500
#
#
#
# TEST:
# Dummy Classifier
#
# Accuracy:  0.5875
# F1 macro:  0.3700787401574803
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74       940
#            1       0.00      0.00      0.00       660
#
#     accuracy                           0.59      1600
#    macro avg       0.29      0.50      0.37      1600
# weighted avg       0.35      0.59      0.43      1600
#
# Multinomial Naive Bayes classifier
#
# Accuracy:  0.700625
# F1 macro:  0.6706079955783077
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77       940
#            1       0.70      0.48      0.57       660
#
#     accuracy                           0.70      1600
#    macro avg       0.70      0.67      0.67      1600
# weighted avg       0.70      0.70      0.69      1600
#
# Best Multinomial Naive Bayes classifier
#
# Accuracy:  0.6975
# F1 macro:  0.6552706552706553
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.69      0.89      0.78       940
#            1       0.73      0.42      0.53       660
#
#     accuracy                           0.70      1600
#    macro avg       0.71      0.66      0.66      1600
# weighted avg       0.71      0.70      0.68      1600
#
# Bernoulli Naive Bayes classifier
#
# Accuracy:  0.703125
# F1 macro:  0.6993622127574062
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.69      0.73       940
#            1       0.62      0.72      0.67       660
#
#     accuracy                           0.70      1600
#    macro avg       0.70      0.71      0.70      1600
# weighted avg       0.71      0.70      0.71      1600
#
# Best Bernoulli Naive Bayes classifier
#
# Accuracy:  0.7025
# F1 macro:  0.6981534090909092
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73       940
#            1       0.62      0.71      0.66       660
#
#     accuracy                           0.70      1600
#    macro avg       0.70      0.70      0.70      1600
# weighted avg       0.71      0.70      0.70      1600
#
# Ridge Classifier
#
# Accuracy:  0.705
# F1 macro:  0.6991024071807426
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       940
#            1       0.63      0.68      0.66       660
#
#     accuracy                           0.70      1600
#    macro avg       0.70      0.70      0.70      1600
# weighted avg       0.71      0.70      0.71      1600
#
# Best Ridge Classifier
#
# Accuracy:  0.725625
# F1 macro:  0.7120828860247476
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       940
#            1       0.69      0.62      0.65       660
#
#     accuracy                           0.73      1600
#    macro avg       0.72      0.71      0.71      1600
# weighted avg       0.72      0.73      0.72      1600
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ferran\anaconda3\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Random Forest classifier
#
# Accuracy:  0.72625
# F1 macro:  0.6991758241758242
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79       940
#            1       0.74      0.52      0.61       660
#
#     accuracy                           0.73      1600
#    macro avg       0.73      0.70      0.70      1600
# weighted avg       0.73      0.73      0.71      1600
#
# Best Random Forest classifier
#
# Accuracy:  0.73625
# F1 macro:  0.7115732925070568
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80       940
#            1       0.75      0.54      0.63       660
#
#     accuracy                           0.74      1600
#    macro avg       0.74      0.71      0.71      1600
# weighted avg       0.74      0.74      0.73      1600
#
# Support Vector Classification
#
# Accuracy:  0.72375
# F1 macro:  0.7100327361232296
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       940
#            1       0.68      0.61      0.65       660
#
#     accuracy                           0.72      1600
#    macro avg       0.72      0.71      0.71      1600
# weighted avg       0.72      0.72      0.72      1600
#
# Best Support Vector Classification
#
# Accuracy:  0.725
# F1 macro:  0.6827319661965332
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.70      0.93      0.80       940
#            1       0.81      0.44      0.57       660
#
#     accuracy                           0.73      1600
#    macro avg       0.75      0.68      0.68      1600
# weighted avg       0.75      0.72      0.70      1600
#
# AdaBoost classifier
#
# Accuracy:  0.6675
# F1 macro:  0.6597154594400976
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.70      0.71       940
#            1       0.59      0.63      0.61       660
#
#     accuracy                           0.67      1600
#    macro avg       0.66      0.66      0.66      1600
# weighted avg       0.67      0.67      0.67      1600
#
# Best AdaBoost classifier
#
# Accuracy:  0.691875
# F1 macro:  0.6863158053805907
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73       940
#            1       0.61      0.68      0.64       660
#
#     accuracy                           0.69      1600
#    macro avg       0.69      0.69      0.69      1600
# weighted avg       0.70      0.69      0.69      1600
#
# Multi-layer Perceptron classifier
#
# Accuracy:  0.71375
# F1 macro:  0.7067035528573992
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75       940
#            1       0.65      0.68      0.66       660
#
#     accuracy                           0.71      1600
#    macro avg       0.71      0.71      0.71      1600
# weighted avg       0.72      0.71      0.71      1600
#
# Best Multi-layer Perceptron classifier
#
# Accuracy:  0.715
# F1 macro:  0.6949705255236424
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.83      0.77       940
#            1       0.69      0.56      0.62       660
#
#     accuracy                           0.71      1600
#    macro avg       0.71      0.69      0.69      1600
# weighted avg       0.71      0.71      0.71      1600

# %%
print("TRAIN:\n", all_train_scores_spanish)
print("\n\nDEV:\n", all_dev_scores_spanish)
print("\n\nTEST:\n", all_test_scores_spanish)
# Out:
# TRAIN:
#                                           Accuracy  F1 macro
# Dummy Classifier                         0.587333  0.370013
# Multinomial Naive Bayes classifier       0.862444  0.851474
# Best Multinomial Naive Bayes classifier  0.836667  0.819576
# Bernoulli Naive Bayes classifier         0.880889  0.877688
# Best Bernoulli Naive Bayes classifier    0.875556  0.871494
# Ridge Classifier                         0.936000  0.933712
# Best Ridge Classifier                    0.871333  0.863485
# Random Forest classifier                 0.999778  0.999771
# Best Random Forest classifier            0.999556  0.999542
# Support Vector Classification            0.977111  0.976335
# Best Support Vector Classification       0.829111  0.811682
# AdaBoost classifier                      0.782444  0.769740
# Best AdaBoost classifier                 0.869778  0.863730
# Multi-layer Perceptron classifier        0.915333  0.912374
# Best Multi-layer Perceptron classifier   0.876667  0.869665
#
#
# DEV:
#                                           Accuracy  F1 macro
# Dummy Classifier                            0.556  0.357326
# Multinomial Naive Bayes classifier          0.730  0.709441
# Best Multinomial Naive Bayes classifier     0.720  0.689804
# Bernoulli Naive Bayes classifier            0.764  0.761420
# Best Bernoulli Naive Bayes classifier       0.770  0.766972
# Ridge Classifier                            0.740  0.733851
# Best Ridge Classifier                       0.746  0.735636
# Random Forest classifier                    0.742  0.728113
# Best Random Forest classifier               0.742  0.725951
# Support Vector Classification               0.752  0.741667
# Best Support Vector Classification          0.738  0.717398
# AdaBoost classifier                         0.750  0.741820
# Best AdaBoost classifier                    0.752  0.745814
# Multi-layer Perceptron classifier           0.734  0.729136
# Best Multi-layer Perceptron classifier      0.716  0.699844
#
#
# TEST:
#                                           Accuracy  F1 macro
# Dummy Classifier                         0.587500  0.370079
# Multinomial Naive Bayes classifier       0.700625  0.670608
# Best Multinomial Naive Bayes classifier  0.697500  0.655271
# Bernoulli Naive Bayes classifier         0.703125  0.699362
# Best Bernoulli Naive Bayes classifier    0.702500  0.698153
# Ridge Classifier                         0.705000  0.699102
# Best Ridge Classifier                    0.725625  0.712083
# Random Forest classifier                 0.726250  0.699176
# Best Random Forest classifier            0.736250  0.711573
# Support Vector Classification            0.723750  0.710033
# Best Support Vector Classification       0.725000  0.682732
# AdaBoost classifier                      0.667500  0.659715
# Best AdaBoost classifier                 0.691875  0.686316
# Multi-layer Perceptron classifier        0.713750  0.706704
# Best Multi-layer Perceptron classifier   0.715000  0.694971

# %%
for name, y_pred in all_train_preds_english.iterrows():
    save_results(y_pred, english_train.index, name, "hateval2019/task1", "english", dataset_types.train, group=("best_" if "Best" in name else "") + "traditional", filename="_".join(name.lower().split(" ")))
    
for name, y_pred in all_dev_preds_english.iterrows():
    save_results(y_pred, english_dev.index, name, "hateval2019/task1", "english", dataset_types.development, group=("best_" if "Best" in name else "") + "traditional", filename="_".join(name.lower().split(" ")))
    
for name, y_pred in all_test_preds_english.iterrows():
    save_results(y_pred, english_test.index, name, "hateval2019/task1", "english", dataset_types.test, group=("best_" if "Best" in name else "") + "traditional", filename="_".join(name.lower().split(" ")))
# Out:
# Results saved on: ./results/hateval2019/task1/english/train/traditional/dummy_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/traditional/multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/train/best_traditional/best_multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/dummy_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/traditional/multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/development/best_traditional/best_multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/dummy_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/traditional/multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/english/test/best_traditional/best_multi-layer_perceptron_classifier.pkl

# %%
for name, y_pred in all_train_preds_spanish.iterrows():
    save_results(y_pred, spanish_train.index, name, "hateval2019/task1", "spanish", dataset_types.train, group=("best_" if "Best" in name else "") + "traditional", filename="_".join(name.lower().split(" ")))
    
for name, y_pred in all_dev_preds_spanish.iterrows():
    save_results(y_pred, spanish_dev.index, name, "hateval2019/task1", "spanish", dataset_types.development, group=("best_" if "Best" in name else "") + "traditional", filename="_".join(name.lower().split(" ")))
    
for name, y_pred in all_test_preds_spanish.iterrows():
    save_results(y_pred, spanish_test.index, name, "hateval2019/task1", "spanish", dataset_types.test, group=("best_" if "Best" in name else "") + "traditional", filename="_".join(name.lower().split(" ")))
# Out:
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/dummy_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/traditional/multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/train/best_traditional/best_multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/dummy_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/traditional/multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/best_traditional/best_multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/dummy_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_multinomial_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_bernoulli_naive_bayes_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_ridge_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_random_forest_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_support_vector_classification.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_adaboost_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/traditional/multi-layer_perceptron_classifier.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/best_traditional/best_multi-layer_perceptron_classifier.pkl

# %% [markdown]
# # NN

# %%
def preprocessing_nn(data):
    return direct_replacement(data.apply(lambda text: re.sub(r"[@#]\w+", "", text)))

def preprocessing_gpt2(data):
    return direct_replacement(data.apply(lambda text: re.sub(r"@\w+", "user", text)).apply(lambda text: re.sub(r"#\w+", "hashtag", text)).apply(lambda text: re.sub(r"https?\S*", "link", text)))

# %%
from transformers import BertPreTrainedModel, BertModel
from transformers.modeling_outputs import SequenceClassifierOutput
from torch import nn
from torch.nn import CrossEntropyLoss, MSELoss

class AvarageBertPooler(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.dense = nn.Linear(config.hidden_size, config.hidden_size)
        self.activation = nn.Tanh()

    def forward(self, hidden_states):
        # We "pool" the model by simply taking the hidden state corresponding
        # to the first token.
        
        #first_token_tensor = torch.stack(hidden_states[-2:]).mean(0)[:, 0] #Avarage two last CLS layers
        #first_token_tensor = hidden_states[-1][:, -2:].mean(1) #Avarage two last tokens
        first_token_tensor = torch.stack(hidden_states[-2:]).mean(0).mean(1) #Avarage all two last layers

        pooled_output = self.dense(first_token_tensor)
        pooled_output = self.activation(pooled_output)
        return pooled_output

class BertForSequenceClassificationAvarage(BertPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels

        self.bert = BertModel(config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        self.classifier = nn.Linear(config.hidden_size, config.num_labels)
        self.pooler = AvarageBertPooler(config)

        self.init_weights()

    def forward(self, input_ids=None, attention_mask=None, token_type_ids=None, position_ids=None, head_mask=None, inputs_embeds=None, labels=None, output_attentions=None, output_hidden_states=None, return_dict=None,):
        r"""
        labels (:obj:`torch.LongTensor` of shape :obj:`(batch_size,)`, `optional`):
            Labels for computing the sequence classification/regression loss. Indices should be in :obj:`[0, ...,
            config.num_labels - 1]`. If :obj:`config.num_labels == 1` a regression loss is computed (Mean-Square loss),
            If :obj:`config.num_labels > 1` a classification loss is computed (Cross-Entropy).
        """
        return_dict = return_dict if return_dict is not None else self.config.use_return_dict

        outputs = self.bert(
            input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
            position_ids=position_ids,
            head_mask=head_mask,
            inputs_embeds=inputs_embeds,
            output_attentions=output_attentions,
            output_hidden_states=True,
            return_dict=return_dict,
        )

        pooled_output = self.pooler(outputs[2])
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)

        loss = None
        if labels is not None:
            if self.num_labels == 1:
                #  We are doing regression
                loss_fct = MSELoss()
                loss = loss_fct(logits.view(-1), labels.view(-1))
            else:
                loss_fct = CrossEntropyLoss()
                loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))

        if not return_dict:
            output = (logits,) + outputs[2:]
            return ((loss,) + output) if loss is not None else output

        return SequenceClassifierOutput(
            loss=loss,
            logits=logits,
            hidden_states=outputs.hidden_states,
            attentions=outputs.attentions,
        )

# %%
def print_example_nn(tokenizer, orig_text, nn_text):

    # Print the original sentence.
    print(' Original: ', orig_text)
    # Print the sentence split into tokens.
    print('Tokenized: ', tokenizer.tokenize(orig_text))
    # Print the sentence mapped to token ids.
    print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(orig_text)))


    # Print the original sentence.
    print('\n Replaced: ', nn_text)
    # Print the sentence split into tokens.
    print('Tokenized: ', tokenizer.tokenize(nn_text))
    # Print the sentence mapped to token ids.
    print('Token IDs: ', tokenizer.convert_tokens_to_ids(tokenizer.tokenize(nn_text)))

# %%
import math

def measure_max_length(tokenizer, list_datasets, add_special_tokens=True):

    max_len = 0

    # For every sentence...
    for text in np.hstack(list_datasets):

        # Tokenize the text and add `[CLS]` and `[SEP]` tokens.
        input_ids = tokenizer.encode(text, add_special_tokens=add_special_tokens)

        # Update the maximum sentence length.
        max_len = max(max_len, len(input_ids))

    print('Max sentence length: ', max_len)
    
    return max_len #2 ** math.ceil(math.log(max_len, 2))

# %%
from torch.utils.data import TensorDataset

def tokenize(tokenizer, X, y, max_length, add_special_tokens=True):

    # Tokenize all of the sentences and map the tokens to thier word IDs.
    input_ids = []
    attention_masks = []

    # For every sentence...
    for text in X:
        # `encode_plus` will:
        #   (1) Tokenize the sentence.
        #   (2) Prepend the `[CLS]` token to the start.
        #   (3) Append the `[SEP]` token to the end.
        #   (4) Map tokens to their IDs.
        #   (5) Pad or truncate the sentence to `max_length`
        #   (6) Create attention masks for [PAD] tokens.
        encoded_dict = tokenizer.encode_plus(
                            text,                      # Sentence to encode.
                            add_special_tokens = add_special_tokens, # Add '[CLS]' and '[SEP]'
                            max_length = max_length,           # Pad & truncate all sentences.
                            padding='max_length',
                            return_attention_mask = True,   # Construct attn. masks.
                            return_tensors = 'pt',     # Return pytorch tensors.
                       )

        # Add the encoded sentence to the list.    
        input_ids.append(encoded_dict['input_ids'])

        # And its attention mask (simply differentiates padding from non-padding).
        attention_masks.append(encoded_dict['attention_mask'])

    # Convert the lists into tensors.
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)
    labels = torch.tensor(y.values)

    return input_ids, attention_masks, labels

# %%
import datetime
import time


# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

def flat_f1(preds, labels):
    y_pred = np.argmax(preds, axis=1).flatten()
    y_true = labels.flatten()
    return f1_score(y_true, y_pred, average='macro')


def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import random  
from transformers import get_linear_schedule_with_warmup
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler


def train(model, train_dataset, validation_dataset, optimizer, batch_size, epochs, device):
    
    # Create the DataLoaders for our training and validation sets.
    # We'll take training samples in random order. 
    train_dataloader = DataLoader(
                train_dataset,  # The training samples.
                sampler = RandomSampler(train_dataset), # Select batches randomly
                batch_size = batch_size # Trains with this batch size.
            )

    # For validation the order doesn't matter, so we'll just read them sequentially.
    validation_dataloader = DataLoader(
                validation_dataset, # The validation samples.
                sampler = SequentialSampler(validation_dataset), # Pull out batches sequentially.
                batch_size = batch_size # Evaluate with this batch size.
            )


    # Total number of training steps is [number of batches] x [number of epochs]. 
    # (Note that this is not the same as the number of training samples).
    total_steps = len(train_dataloader) * epochs

    # Create the learning rate scheduler.
    scheduler = get_linear_schedule_with_warmup(optimizer, 
                                                num_warmup_steps = 0, # Default value in run_glue.py
                                                num_training_steps = total_steps)
    
    # This training code is based on the `run_glue.py` script here:
    

    # Set the seed value all over the place to make this reproducible.

    random.seed(seed_val)
    np.random.seed(seed_val)
    torch.manual_seed(seed_val)
    torch.cuda.manual_seed_all(seed_val)

    # We'll store a number of quantities such as training and validation loss, 
    # validation accuracy, and timings.
    training_stats = []

    # Measure the total training time for the whole run.
    total_t0 = time.time()

    # For each epoch...
    for epoch_i in range(0, epochs):

        # ========================================
        #               Training
        # ========================================

        # Perform one full pass over the training set.

        print("")
        print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
        print('Training...')

        # Measure how long the training epoch takes.
        t0 = time.time()

        # Reset the total loss for this epoch.
        total_train_loss = 0

        # Put the model into training mode. Don't be mislead--the call to 
        # `train` just changes the *mode*, it doesn't *perform* the training.
        # `dropout` and `batchnorm` layers behave differently during training
        # vs. test (source: https://stackoverflow.com/questions/51433378/what-does-model-train-do-in-pytorch)
        model.train()

        # For each batch of training data...
        for step, batch in enumerate(train_dataloader):

            # Progress update every 40 batches.
            if step % 40 == 0 and not step == 0:
                # Calculate elapsed time in minutes.
                elapsed = format_time(time.time() - t0)

                # Report progress.
                print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

            # Unpack this training batch from our dataloader. 
            #
            # As we unpack the batch, we'll also copy each tensor to the GPU using the 
            # `to` method.
            #
            # `batch` contains three pytorch tensors:
            #   [0]: input ids 
            #   [1]: attention masks
            #   [2]: labels 
            b_input_ids = batch[0].to(device)
            b_input_mask = batch[1].to(device)
            b_labels = batch[2].to(device)

            # Always clear any previously calculated gradients before performing a
            # backward pass. PyTorch doesn't do this automatically because 
            # accumulating the gradients is "convenient while training RNNs". 
            # (source: https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch)
            model.zero_grad()        

            # Perform a forward pass (evaluate the model on this training batch).
            # The documentation for this `model` function is here: 
            # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
            # It returns different numbers of parameters depending on what arguments
            # arge given and what flags are set. For our useage here, it returns
            # the loss (because we provided labels) and the "logits"--the model
            # outputs prior to activation.
            output = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask, labels=b_labels)
            loss = output.loss
            logits = output.logits

            # Accumulate the training loss over all of the batches so that we can
            # calculate the average loss at the end. `loss` is a Tensor containing a
            # single value; the `.item()` function just returns the Python value 
            # from the tensor.
            total_train_loss += loss.item()

            # Perform a backward pass to calculate the gradients.
            loss.backward()

            # Clip the norm of the gradients to 1.0.
            # This is to help prevent the "exploding gradients" problem.
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            # Update parameters and take a step using the computed gradient.
            # The optimizer dictates the "update rule"--how the parameters are
            # modified based on their gradients, the learning rate, etc.
            optimizer.step()

            # Update the learning rate.
            scheduler.step()

        # Calculate the average loss over all of the batches.
        avg_train_loss = total_train_loss / len(train_dataloader)            

        # Measure how long this epoch took.
        training_time = format_time(time.time() - t0)

        print("")
        print("  Average training loss: {0:.2f}".format(avg_train_loss))
        print("  Training epcoh took: {:}".format(training_time))

        # ========================================
        #               Validation
        # ========================================
        # After the completion of each training epoch, measure our performance on
        # our validation set.

        print("")
        print("Running Validation...")

        t0 = time.time()

        # Put the model in evaluation mode--the dropout layers behave differently
        # during evaluation.
        model.eval()

        # Tracking variables 
        total_eval_accuracy = 0
        total_eval_f1 = 0
        total_eval_loss = 0
        nb_eval_steps = 0

        # Evaluate data for one epoch
        for batch in validation_dataloader:

            # Unpack this training batch from our dataloader. 
            #
            # As we unpack the batch, we'll also copy each tensor to the GPU using 
            # the `to` method.
            #
            # `batch` contains three pytorch tensors:
            #   [0]: input ids 
            #   [1]: attention masks
            #   [2]: labels 
            b_input_ids = batch[0].to(device)
            b_input_mask = batch[1].to(device)
            b_labels = batch[2].to(device)

            # Tell pytorch not to bother with constructing the compute graph during
            # the forward pass, since this is only needed for backprop (training).
            with torch.no_grad():        

                # Forward pass, calculate logit predictions.
                # token_type_ids is the same as the "segment ids", which 
                # differentiates sentence 1 and 2 in 2-sentence tasks.
                # The documentation for this `model` function is here: 
                # https://huggingface.co/transformers/v2.2.0/model_doc/bert.html#transformers.BertForSequenceClassification
                # Get the "logits" output by the model. The "logits" are the output
                # values prior to applying an activation function like the softmax.
                output = model(b_input_ids, token_type_ids=None, attention_mask=b_input_mask, labels=b_labels)
                loss = output.loss
                logits = output.logits

            # Accumulate the validation loss.
            total_eval_loss += loss

            # Move logits and labels to CPU
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()

            # Calculate the accuracy for this batch of test sentences, and
            # accumulate it over all batches.
            total_eval_accuracy += flat_accuracy(logits, label_ids)

            total_eval_f1 += flat_f1(logits, label_ids)


        # Report the final accuracy for this validation run.
        avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
        print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

        avg_val_f1 = total_eval_f1 / len(validation_dataloader)
        print("  F1 macro: {0:.2f}".format(avg_val_f1))

        # Calculate the average loss over all of the batches.
        avg_val_loss = total_eval_loss / len(validation_dataloader)

        # Measure how long the validation run took.
        validation_time = format_time(time.time() - t0)

        print("  Validation Loss: {0:.2f}".format(avg_val_loss))
        print("  Validation took: {:}".format(validation_time))

        # Record all statistics from this epoch.
        training_stats.append(
            {
                'epoch': epoch_i + 1,
                'Training Loss': avg_train_loss,
                'Valid. Loss': avg_val_loss,
                'Valid. Accur': avg_val_accuracy,
                'Valid. F1 macro': avg_val_f1,
                'Training Time': training_time,
                'Validation Time': validation_time
            }
        )

    print("")
    print("Training complete!")

    print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
    
    return training_stats

# %%
def stats_training(training_stats):

    df_stats = pd.DataFrame(data=training_stats)

    # Use the 'epoch' as the row index.
    df_stats = df_stats.set_index('epoch')
    
    # Use plot styling from seaborn.
    sns.set(style='darkgrid')

    # Increase the plot size and font size.
    sns.set(font_scale=1.5)
    plt.rcParams["figure.figsize"] = (12,6)

    # Plot the learning curve.
    plt.plot(df_stats['Training Loss'], 'b-o', label="Training")
    plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation")

    # Label the plot.
    plt.title("Training & Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.xticks([1, 2, 3, 4])

    plt.show()

    # Display the table.
    return df_stats

# %%
def evaluate(model, dataset, device, batch_size, model_name):
    
    dataloader = DataLoader(
            dataset, # The validation samples.
            sampler = SequentialSampler(dataset), # Pull out batches sequentially.
            batch_size = batch_size # Evaluate with this batch size.
        )

    # Put model in evaluation mode
    model.eval()

    # Tracking variables 
    predictions, true_labels = [], []

    # Predict 
    for batch in dataloader:
        # Add batch to GPU
        batch = tuple(t.to(device) for t in batch)

        # Unpack the inputs from our dataloader
        b_input_ids, b_input_mask, b_labels = batch

        # Telling the model not to compute or store gradients, saving memory and 
        # speeding up prediction
        with torch.no_grad():
          # Forward pass, calculate logit predictions
          outputs = model(b_input_ids, token_type_ids=None, 
                          attention_mask=b_input_mask)

        logits = outputs.logits

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        # Store predictions and true labels
        predictions.append(logits)
        true_labels.append(label_ids)

    y_true = np.hstack(true_labels)
    y_pred = np.vstack(predictions).argmax(axis=1)
    print_score(y_true, y_pred, model_name)
    
    return y_pred

# %% [markdown]
# # Bert

# %%
X_train_english_nn = preprocessing_nn(english_train.text)
X_dev_english_nn = preprocessing_nn(english_dev.text)
X_test_english_nn = preprocessing_nn(english_test.text)

X_train_spanish_nn = preprocessing_nn(spanish_train.text)
X_dev_spanish_nn = preprocessing_nn(spanish_dev.text)
X_test_spanish_nn = preprocessing_nn(spanish_test.text)

# %% [markdown]
# ## english

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

#model_english = BertForSequenceClassification.from_pretrained('bert-base-uncased')
model_english = BertForSequenceClassificationAvarage.from_pretrained('bert-base-uncased')
tokenizer_english = BertTokenizer.from_pretrained('bert-base-uncased')

model_english.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassificationAvarage: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassificationAvarage from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassificationAvarage from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassificationAvarage were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias', 'pooler.dense.weight', 'pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassificationAvarage(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (pooler): AvarageBertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
from transformers import AdamW

print_example_nn(tokenizer_english, english_train.text.iloc[0], X_train_english_nn.iloc[0])

max_length_english = measure_max_length(tokenizer_english, [X_train_english_nn, X_dev_english_nn, X_test_english_nn])

english_train_english_bert = TensorDataset(*tokenize(tokenizer_english, X_train_english_nn, english_train["HS"], max_length_english))
english_dev_english_bert = TensorDataset(*tokenize(tokenizer_english, X_dev_english_nn, english_dev["HS"], max_length_english))
english_test_english_bert = TensorDataset(*tokenize(tokenizer_english, X_test_english_nn, english_test["HS"], max_length_english))

device = torch.device('cuda:0')

optimizer = AdamW(model_english.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

batch_size = 32
epochs = 3
# Out:
#  Original:  Hurray, saving us $$$ in so many ways @potus @realDonaldTrump #LockThemUp #BuildTheWall #EndDACA #BoycottNFL #BoycottNike
# Tokenized:  ['hu', '##rra', '##y', ',', 'saving', 'us', '$', '$', '$', 'in', 'so', 'many', 'ways', '@', 'pot', '##us', '@', 'real', '##don', '##ald', '##trum', '##p', '#', 'lock', '##the', '##mu', '##p', '#', 'build', '##the', '##wall', '#', 'end', '##da', '##ca', '#', 'boycott', '##n', '##fl', '#', 'boycott', '##nik', '##e']
# Token IDs:  [15876, 11335, 2100, 1010, 7494, 2149, 1002, 1002, 1002, 1999, 2061, 2116, 3971, 1030, 8962, 2271, 1030, 2613, 5280, 19058, 24456, 2361, 1001, 5843, 10760, 12274, 2361, 1001, 3857, 10760, 9628, 1001, 2203, 2850, 3540, 1001, 17757, 2078, 10258, 1001, 17757, 8238, 2063]
#
#  Replaced:  hurray, saving us $$$ in significant other many ways
# Tokenized:  ['hu', '##rra', '##y', ',', 'saving', 'us', '$', '$', '$', 'in', 'significant', 'other', 'many', 'ways']
# Token IDs:  [15876, 11335, 2100, 1010, 7494, 2149, 1002, 1002, 1002, 1999, 3278, 2060, 2116, 3971]
# Max sentence length:  103

# %%
training_stats = train(model_english, english_train_english_bert, english_dev_english_bert, optimizer, batch_size, epochs, device)
# Out:
# ======== Epoch 1 / 3 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:18.
#   Batch    80  of    282.    Elapsed: 0:00:35.
#   Batch   120  of    282.    Elapsed: 0:00:51.
#   Batch   160  of    282.    Elapsed: 0:01:08.
#   Batch   200  of    282.    Elapsed: 0:01:25.
#   Batch   240  of    282.    Elapsed: 0:01:42.
#   Batch   280  of    282.    Elapsed: 0:02:00.
#
#   Average training loss: 0.52
#   Training epcoh took: 0:02:00
#
# Running Validation...
#   Accuracy: 0.74
#   F1 macro: 0.73
#   Validation Loss: 0.51
#   Validation took: 0:00:04
#
# ======== Epoch 2 / 3 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:18.
#   Batch    80  of    282.    Elapsed: 0:00:36.
#   Batch   120  of    282.    Elapsed: 0:00:54.
#   Batch   160  of    282.    Elapsed: 0:01:12.
#   Batch   200  of    282.    Elapsed: 0:01:30.
#   Batch   240  of    282.    Elapsed: 0:01:48.
#   Batch   280  of    282.    Elapsed: 0:02:06.
#
#   Average training loss: 0.36
#   Training epcoh took: 0:02:07
#
# Running Validation...
#   Accuracy: 0.75
#   F1 macro: 0.74
#   Validation Loss: 0.54
#   Validation took: 0:00:05
#
# ======== Epoch 3 / 3 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:18.
#   Batch    80  of    282.    Elapsed: 0:00:34.
#   Batch   120  of    282.    Elapsed: 0:00:50.
#   Batch   160  of    282.    Elapsed: 0:01:05.
#   Batch   200  of    282.    Elapsed: 0:01:20.
#   Batch   240  of    282.    Elapsed: 0:01:36.
#   Batch   280  of    282.    Elapsed: 0:01:51.
#
#   Average training loss: 0.25
#   Training epcoh took: 0:01:51
#
# Running Validation...
#   Accuracy: 0.75
#   F1 macro: 0.74
#   Validation Loss: 0.59
#   Validation took: 0:00:04
#
# Training complete!
# Total training took 0:06:11 (h:mm:ss)

# %%
df_stats = stats_training(training_stats)

y_pred_train_english_bert = evaluate(model_english, english_train_english_bert, device, batch_size, "Bert Train")
y_pred_dev_english_bert = evaluate(model_english, english_dev_english_bert, device, batch_size, "Bert Dev")
y_pred_test_english_bert = evaluate(model_english, english_test_english_bert, device, batch_size, "Bert Test")

df_stats
# Out:
# Bert Train
#
# Accuracy:  0.9407777777777778
# F1 macro:  0.9393834282481186
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      5217
#            1       0.92      0.94      0.93      3783
#
#     accuracy                           0.94      9000
#    macro avg       0.94      0.94      0.94      9000
# weighted avg       0.94      0.94      0.94      9000
#
# Bert Dev
#
# Accuracy:  0.753
# F1 macro:  0.7508450589145519
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77       573
#            1       0.69      0.77      0.73       427
#
#     accuracy                           0.75      1000
#    macro avg       0.75      0.76      0.75      1000
# weighted avg       0.76      0.75      0.75      1000
#
# Bert Test
#
# Accuracy:  0.606
# F1 macro:  0.5939885574846252
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.37      0.52      1740
#            1       0.52      0.93      0.66      1260
#
#     accuracy                           0.61      3000
#    macro avg       0.70      0.65      0.59      3000
# weighted avg       0.72      0.61      0.58      3000
#        Training Loss                      Valid. Loss  Valid. Accur  \
# epoch
# 1           0.516987  tensor(0.5125, device='cuda:0')      0.742188
# 2           0.361327  tensor(0.5398, device='cuda:0')      0.751953
# 3           0.250232  tensor(0.5873, device='cuda:0')      0.752930
#
#        Valid. F1 macro Training Time Validation Time
# epoch
# 1             0.728664       0:02:00         0:00:04
# 2             0.736005       0:02:07         0:00:05
# 3             0.737720       0:01:51         0:00:04

# %%
description = """Pretrained model with bert-base-uncased checkpoint (12 layers). Trained 3 epochs with a batch size of 32 and using AdamW optimizer with lr=2e-5 and eps=1e-8.
Hastags and user have been removed from input text, followed by the same procedure as in method direct_replacement().
Bert Pooler layer is modified to use the avarage of the last 2 layers instead of just [CLS]."""

save_results(y_pred_train_english_bert, english_train.index, "Bert Avarage", "hateval2019/task1", "english", dataset_types.train, group="deep_learning", filename="bert-avarage-2layers", description=description)
save_results(y_pred_dev_english_bert, english_dev.index, "Bert Avarage", "hateval2019/task1", "english", dataset_types.development, group="deep_learning", filename="bert-avarage-2layers", description=description)
save_results(y_pred_test_english_bert, english_test.index, "Bert Avarage", "hateval2019/task1", "english", dataset_types.test, group="deep_learning", filename="bert-avarage-2layers", description=description)
# Out:
# Results saved on: ./results/hateval2019/task1/english/train/deep_learning/bert-avarage-2layers.pkl
# Results saved on: ./results/hateval2019/task1/english/development/deep_learning/bert-avarage-2layers.pkl
# Results saved on: ./results/hateval2019/task1/english/test/deep_learning/bert-avarage-2layers.pkl

# %% [markdown]
# ## Spanish

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

#model_spanish = BertForSequenceClassification.from_pretrained('bert-base-multilingual-uncased')
model_spanish = BertForSequenceClassificationAvarage.from_pretrained('bert-base-multilingual-uncased')
tokenizer_spanish = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')

model_spanish.cuda()
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForSequenceClassificationAvarage: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassificationAvarage from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassificationAvarage from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassificationAvarage were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.weight', 'classifier.bias', 'pooler.dense.weight', 'pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassificationAvarage(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(105879, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (pooler): AvarageBertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
from transformers import AdamW

print_example_nn(tokenizer_spanish, spanish_train.text.iloc[0], X_train_spanish_nn.iloc[0])

max_length_spanish = measure_max_length(tokenizer_spanish, [X_train_spanish_nn, X_dev_spanish_nn, X_test_spanish_nn])

spanish_train_bert = TensorDataset(*tokenize(tokenizer_spanish, X_train_spanish_nn, spanish_train["HS"], max_length_spanish))
spanish_dev_bert = TensorDataset(*tokenize(tokenizer_spanish, X_dev_spanish_nn, spanish_dev["HS"], max_length_spanish))
spanish_test_bert = TensorDataset(*tokenize(tokenizer_spanish, X_test_spanish_nn, spanish_test["HS"],max_length_spanish))

device = torch.device('cuda:0')

optimizer = AdamW(model_spanish.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

batch_size = 16
epochs = 4
# Out:
#  Original:  Easyjet quiere duplicar el número de mujeres piloto' Verás tú para aparcar el avión.. http://t.co/46NuLkm09x
# Tokenized:  ['easy', '##jet', 'quiere', 'du', '##pli', '##car', 'el', 'numero', 'de', 'mujeres', 'piloto', "'", 'vera', '##s', 'tu', 'para', 'apa', '##rca', '##r', 'el', 'avion', '.', '.', 'http', ':', '/', '/', 't', '.', 'co', '/', '46', '##nul', '##km', '##0', '##9', '##x']
# Token IDs:  [24806, 17996, 63644, 10169, 64422, 15740, 10117, 11855, 10102, 20594, 33525, 112, 17140, 10107, 10689, 10239, 20986, 30470, 10131, 10117, 25361, 119, 119, 10635, 131, 120, 120, 162, 119, 10348, 120, 11703, 42668, 22782, 10995, 11518, 10661]
#
#  Replaced:  easyjet quiere duplicar el numero de mujeres piloto' veras tu para aparcar el avion..
# Tokenized:  ['easy', '##jet', 'quiere', 'du', '##pli', '##car', 'el', 'numero', 'de', 'mujeres', 'piloto', "'", 'vera', '##s', 'tu', 'para', 'apa', '##rca', '##r', 'el', 'avion', '.', '.']
# Token IDs:  [24806, 17996, 63644, 10169, 64422, 15740, 10117, 11855, 10102, 20594, 33525, 112, 17140, 10107, 10689, 10239, 20986, 30470, 10131, 10117, 25361, 119, 119]
# Max sentence length:  157

# %%
training_stats = train(model_spanish, spanish_train_bert, spanish_dev_bert, optimizer, batch_size, epochs, device)
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:14.
#   Batch    80  of    282.    Elapsed: 0:00:28.
#   Batch   120  of    282.    Elapsed: 0:00:41.
#   Batch   160  of    282.    Elapsed: 0:00:55.
#   Batch   200  of    282.    Elapsed: 0:01:09.
#   Batch   240  of    282.    Elapsed: 0:01:22.
#   Batch   280  of    282.    Elapsed: 0:01:36.
#
#   Average training loss: 0.51
#   Training epcoh took: 0:01:36
#
# Running Validation...
#   Accuracy: 0.81
#   F1 macro: 0.80
#   Validation Loss: 0.48
#   Validation took: 0:00:03
#
# ======== Epoch 2 / 4 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:14.
#   Batch    80  of    282.    Elapsed: 0:00:27.
#   Batch   120  of    282.    Elapsed: 0:00:41.
#   Batch   160  of    282.    Elapsed: 0:00:55.
#   Batch   200  of    282.    Elapsed: 0:01:08.
#   Batch   240  of    282.    Elapsed: 0:01:22.
#   Batch   280  of    282.    Elapsed: 0:01:36.
#
#   Average training loss: 0.33
#   Training epcoh took: 0:01:36
#
# Running Validation...
#   Accuracy: 0.83
#   F1 macro: 0.82
#   Validation Loss: 0.43
#   Validation took: 0:00:03
#
# ======== Epoch 3 / 4 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:14.
#   Batch    80  of    282.    Elapsed: 0:00:27.
#   Batch   120  of    282.    Elapsed: 0:00:41.
#   Batch   160  of    282.    Elapsed: 0:00:55.
#   Batch   200  of    282.    Elapsed: 0:01:09.
#   Batch   240  of    282.    Elapsed: 0:01:22.
#   Batch   280  of    282.    Elapsed: 0:01:36.
#
#   Average training loss: 0.20
#   Training epcoh took: 0:01:36
#
# Running Validation...
#   Accuracy: 0.83
#   F1 macro: 0.83
#   Validation Loss: 0.47
#   Validation took: 0:00:03
#
# ======== Epoch 4 / 4 ========
# Training...
#   Batch    40  of    282.    Elapsed: 0:00:14.
#   Batch    80  of    282.    Elapsed: 0:00:27.
#   Batch   120  of    282.    Elapsed: 0:00:41.
#   Batch   160  of    282.    Elapsed: 0:00:54.
#   Batch   200  of    282.    Elapsed: 0:01:08.
#   Batch   240  of    282.    Elapsed: 0:01:21.
#   Batch   280  of    282.    Elapsed: 0:01:35.
#
#   Average training loss: 0.12
#   Training epcoh took: 0:01:35
#
# Running Validation...
#   Accuracy: 0.83
#   F1 macro: 0.82
#   Validation Loss: 0.62
#   Validation took: 0:00:03
#
# Training complete!
# Total training took 0:06:36 (h:mm:ss)

# %%
df_stats = stats_training(training_stats)

y_pred_train_spanish_bert = evaluate(model_spanish, spanish_train_bert, device, batch_size, "Bert Train")
y_pred_dev_spanish_bert = evaluate(model_spanish, spanish_dev_bert, device, batch_size, "Bert Dev")
y_pred_test_spanish_bert = evaluate(model_spanish, spanish_test_bert, device, batch_size, "Bert Test")

df_stats
# Out:
# Bert Train
#
# Accuracy:  0.984
# F1 macro:  0.9835327664403473
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      2643
#            1       0.97      0.99      0.98      1857
#
#     accuracy                           0.98      4500
#    macro avg       0.98      0.98      0.98      4500
# weighted avg       0.98      0.98      0.98      4500
#
# Bert Dev
#
# Accuracy:  0.832
# F1 macro:  0.8312195592419347
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84       278
#            1       0.78      0.86      0.82       222
#
#     accuracy                           0.83       500
#    macro avg       0.83      0.83      0.83       500
# weighted avg       0.84      0.83      0.83       500
#
# Bert Test
#
# Accuracy:  0.746875
# F1 macro:  0.745737872226218
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76       940
#            1       0.65      0.82      0.73       660
#
#     accuracy                           0.75      1600
#    macro avg       0.75      0.76      0.75      1600
# weighted avg       0.77      0.75      0.75      1600
#        Training Loss                      Valid. Loss  Valid. Accur  \
# epoch
# 1           0.512228  tensor(0.4775, device='cuda:0')      0.808594
# 2           0.326584  tensor(0.4250, device='cuda:0')      0.830078
# 3           0.196445  tensor(0.4735, device='cuda:0')      0.833984
# 4           0.118738  tensor(0.6171, device='cuda:0')      0.830078
#
#        Valid. F1 macro Training Time Validation Time
# epoch
# 1             0.798906       0:01:36         0:00:03
# 2             0.822754       0:01:36         0:00:03
# 3             0.825202       0:01:36         0:00:03
# 4             0.821013       0:01:35         0:00:03

# %%
description = """Pretrained model with bert-base-multilingual-uncased checkpoint (12 layers). Trained 4 epochs with a batch size of 16 and using AdamW optimizer with lr=2e-5 and eps=1e-8.
Hastags and user have been removed from input text, followed by the same procedure as in method direct_replacement(). 
Bert Pooler layer is modified to use the avarage of the last 2 layers instead of just [CLS]."""

save_results(y_pred_train_spanish_bert, spanish_train.index, "Bert Avarage", "hateval2019/task1", "spanish", dataset_types.train, group="deep_learning", filename="bert-avarage-2layers", description=description)
save_results(y_pred_dev_spanish_bert, spanish_dev.index, "Bert Avarage", "hateval2019/task1", "spanish", dataset_types.development, group="deep_learning", filename="bert-avarage-2layers", description=description)
save_results(y_pred_test_spanish_bert, spanish_test.index, "Bert Avarage", "hateval2019/task1", "spanish", dataset_types.test, group="deep_learning", filename="bert-avarage-2layers", description=description)
# Out:
# Results saved on: ./results/hateval2019/task1/spanish/train/deep_learning/bert-avarage-2layers.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/deep_learning/bert-avarage-2layers.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/deep_learning/bert-avarage-2layers.pkl

# %% [markdown]
# # GPT-2

# %%
X_train_english_gpt2 = preprocessing_gpt2(english_train.text)
X_dev_english_gpt2 = preprocessing_gpt2(english_dev.text)
X_test_english_gpt2 = preprocessing_gpt2(english_test.text)

X_train_spanish_gpt2 = preprocessing_gpt2(spanish_train.text)
X_dev_spanish_gpt2 = preprocessing_gpt2(spanish_dev.text)
X_test_spanish_gpt2 = preprocessing_gpt2(spanish_test.text)

# %%
from transformers import GPT2Config, GPT2Tokenizer, GPT2ForSequenceClassification
import torch

print('Loading configuraiton...')
model_config_english = GPT2Config.from_pretrained('gpt2', num_labels=2)

# Get model's tokenizer.
print('Loading tokenizer...')
tokenizer_english = GPT2Tokenizer.from_pretrained('gpt2')
# default to left padding
tokenizer_english.padding_side = "left"
# Define PAD Token = EOS Token = 50256
tokenizer_english.pad_token = tokenizer_english.eos_token


# Get the actual model.
print('Loading model...')
model_english = GPT2ForSequenceClassification.from_pretrained('gpt2', config=model_config_english)

# resize model embedding to match new tokenizer
model_english.resize_token_embeddings(len(tokenizer_english))

# fix model padding token id
model_english.config.pad_token_id = model_english.config.eos_token_id

model_english.cuda()
# Out:
# Loading configuraiton...
# Loading tokenizer...
# Loading model...
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# GPT2ForSequenceClassification(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (score): Linear(in_features=768, out_features=2, bias=False)
# )

# %%
from transformers import AdamW

print_example_nn(tokenizer_english, english_train.text.iloc[0], X_train_english_gpt2.iloc[0])

max_length_english = measure_max_length(tokenizer_english, [X_train_spanish_nn, X_dev_spanish_nn, X_test_spanish_nn], add_special_tokens=False)

english_train_gpt2 = TensorDataset(*tokenize(tokenizer_english, X_train_english_gpt2, english_train["HS"], max_length_english, add_special_tokens=False))
english_dev_gpt2 = TensorDataset(*tokenize(tokenizer_english, X_dev_english_gpt2, english_dev["HS"], max_length_english, add_special_tokens=False))
english_test_gpt2 = TensorDataset(*tokenize(tokenizer_english, X_test_english_gpt2, english_test["HS"],max_length_english, add_special_tokens=False))

device = torch.device('cuda:0')

optimizer = AdamW(model_english.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )

batch_size = 16
epochs = 4
# Out:
#  Original:  Hurray, saving us $$$ in so many ways @potus @realDonaldTrump #LockThemUp #BuildTheWall #EndDACA #BoycottNFL #BoycottNike
# Tokenized:  ['Hur', 'ray', ',', 'Ġsaving', 'Ġus', 'Ġ$', '$$', 'Ġin', 'Ġso', 'Ġmany', 'Ġways', 'Ġ@', 'pot', 'us', 'Ġ@', 'realDonaldTrump', 'Ġ#', 'Lock', 'The', 'm', 'Up', 'Ġ#', 'Build', 'The', 'Wall', 'Ġ#', 'End', 'D', 'ACA', 'Ġ#', 'Boy', 'cott', 'NFL', 'Ġ#', 'Boy', 'cott', 'N', 'ike']
# Token IDs:  [42633, 2433, 11, 8914, 514, 720, 13702, 287, 523, 867, 2842, 2488, 13059, 385, 2488, 28024, 1303, 25392, 464, 76, 4933, 1303, 15580, 464, 22401, 1303, 12915, 35, 26576, 1303, 26554, 14612, 32078, 1303, 26554, 14612, 45, 522]
#
#  Replaced:  hurray, saving us $$$ in significant other many ways user user hashtag hashtag hashtag hashtag hashtag
# Tokenized:  ['hur', 'ray', ',', 'Ġsaving', 'Ġus', 'Ġ$', '$$', 'Ġin', 'Ġsignificant', 'Ġother', 'Ġmany', 'Ġways', 'Ġuser', 'Ġuser', 'Ġhashtag', 'Ġhashtag', 'Ġhashtag', 'Ġhashtag', 'Ġhashtag']
# Token IDs:  [48349, 2433, 11, 8914, 514, 720, 13702, 287, 2383, 584, 867, 2842, 2836, 2836, 23950, 23950, 23950, 23950, 23950]
# Max sentence length:  176

# %%
training_stats = train(model_english, english_train_gpt2, english_dev_gpt2, optimizer, batch_size, epochs, device)
# Out:
# ======== Epoch 1 / 4 ========
# Training...
#   Batch    40  of    563.    Elapsed: 0:00:17.
#   Batch    80  of    563.    Elapsed: 0:00:35.
#   Batch   120  of    563.    Elapsed: 0:00:52.
#   Batch   160  of    563.    Elapsed: 0:01:09.
#   Batch   200  of    563.    Elapsed: 0:01:26.
#   Batch   240  of    563.    Elapsed: 0:01:44.
#   Batch   280  of    563.    Elapsed: 0:02:01.
#   Batch   320  of    563.    Elapsed: 0:02:18.
#   Batch   360  of    563.    Elapsed: 0:02:35.
#   Batch   400  of    563.    Elapsed: 0:02:52.
#   Batch   440  of    563.    Elapsed: 0:03:10.
#   Batch   480  of    563.    Elapsed: 0:03:27.
#   Batch   520  of    563.    Elapsed: 0:03:44.
#   Batch   560  of    563.    Elapsed: 0:04:01.
#
#   Average training loss: 0.63
#   Training epcoh took: 0:04:02
#
# Running Validation...
#   Accuracy: 0.68
#   F1 macro: 0.66
#   Validation Loss: 0.58
#   Validation took: 0:00:08
#
# ======== Epoch 2 / 4 ========
# Training...
#   Batch    40  of    563.    Elapsed: 0:00:17.
#   Batch    80  of    563.    Elapsed: 0:00:34.
#   Batch   120  of    563.    Elapsed: 0:00:52.
#   Batch   160  of    563.    Elapsed: 0:01:09.
#   Batch   200  of    563.    Elapsed: 0:01:26.
#   Batch   240  of    563.    Elapsed: 0:01:43.
#   Batch   280  of    563.    Elapsed: 0:02:00.
#   Batch   320  of    563.    Elapsed: 0:02:18.
#   Batch   360  of    563.    Elapsed: 0:02:35.
#   Batch   400  of    563.    Elapsed: 0:02:52.
#   Batch   440  of    563.    Elapsed: 0:03:09.
#   Batch   480  of    563.    Elapsed: 0:03:27.
#   Batch   520  of    563.    Elapsed: 0:03:44.
#   Batch   560  of    563.    Elapsed: 0:04:01.
#
#   Average training loss: 0.52
#   Training epcoh took: 0:04:02
#
# Running Validation...
#   Accuracy: 0.71
#   F1 macro: 0.66
#   Validation Loss: 0.57
#   Validation took: 0:00:08
#
# ======== Epoch 3 / 4 ========
# Training...
#   Batch    40  of    563.    Elapsed: 0:00:17.
#   Batch    80  of    563.    Elapsed: 0:00:34.
#   Batch   120  of    563.    Elapsed: 0:00:52.
#   Batch   160  of    563.    Elapsed: 0:01:09.
#   Batch   200  of    563.    Elapsed: 0:01:26.
#   Batch   240  of    563.    Elapsed: 0:01:43.
#   Batch   280  of    563.    Elapsed: 0:02:01.
#   Batch   320  of    563.    Elapsed: 0:02:18.
#   Batch   360  of    563.    Elapsed: 0:02:35.
#   Batch   400  of    563.    Elapsed: 0:02:52.
#   Batch   440  of    563.    Elapsed: 0:03:09.
#   Batch   480  of    563.    Elapsed: 0:03:27.
#   Batch   520  of    563.    Elapsed: 0:03:44.
#   Batch   560  of    563.    Elapsed: 0:04:01.
#
#   Average training loss: 0.47
#   Training epcoh took: 0:04:02
#
# Running Validation...
#   Accuracy: 0.73
#   F1 macro: 0.71
#   Validation Loss: 0.53
#   Validation took: 0:00:08
#
# ======== Epoch 4 / 4 ========
# Training...
#   Batch    40  of    563.    Elapsed: 0:00:17.
#   Batch    80  of    563.    Elapsed: 0:00:34.
#   Batch   120  of    563.    Elapsed: 0:00:52.
#   Batch   160  of    563.    Elapsed: 0:01:09.
#   Batch   200  of    563.    Elapsed: 0:01:26.
#   Batch   240  of    563.    Elapsed: 0:01:43.
#   Batch   280  of    563.    Elapsed: 0:02:01.
#   Batch   320  of    563.    Elapsed: 0:02:18.
#   Batch   360  of    563.    Elapsed: 0:02:35.
#   Batch   400  of    563.    Elapsed: 0:02:52.
#   Batch   440  of    563.    Elapsed: 0:03:10.
#   Batch   480  of    563.    Elapsed: 0:03:27.
#   Batch   520  of    563.    Elapsed: 0:03:44.
#   Batch   560  of    563.    Elapsed: 0:04:01.
#
#   Average training loss: 0.44
#   Training epcoh took: 0:04:02
#
# Running Validation...
#   Accuracy: 0.74
#   F1 macro: 0.71
#   Validation Loss: 0.54
#   Validation took: 0:00:08
#
# Training complete!
# Total training took 0:16:43 (h:mm:ss)

# %%
df_stats = stats_training(training_stats)

y_pred_train_english_gpt2 = evaluate(model_english, english_train_gpt2, device, batch_size, "GPT2 Train")
y_pred_dev_english_gpt2 = evaluate(model_english, english_dev_gpt2, device, batch_size, "GPT2 Dev")
y_pred_test_english_gpt2 = evaluate(model_english, english_test_gpt2, device, batch_size, "GPT2 Test")

df_stats
# Out:
# GPT2 Train
#
# Accuracy:  0.8095555555555556
# F1 macro:  0.8054590613779311
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      5217
#            1       0.76      0.79      0.78      3783
#
#     accuracy                           0.81      9000
#    macro avg       0.80      0.81      0.81      9000
# weighted avg       0.81      0.81      0.81      9000
#
# GPT2 Dev
#
# Accuracy:  0.739
# F1 macro:  0.7356241852210881
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.74      0.77       573
#            1       0.68      0.73      0.71       427
#
#     accuracy                           0.74      1000
#    macro avg       0.73      0.74      0.74      1000
# weighted avg       0.74      0.74      0.74      1000
#
# GPT2 Test
#
# Accuracy:  0.49066666666666664
# F1 macro:  0.4359989192440023
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.15      0.26      1740
#            1       0.45      0.95      0.61      1260
#
#     accuracy                           0.49      3000
#    macro avg       0.64      0.55      0.44      3000
# weighted avg       0.67      0.49      0.41      3000
#        Training Loss                      Valid. Loss  Valid. Accur  \
# epoch
# 1           0.628277  tensor(0.5835, device='cuda:0')      0.682540
# 2           0.518077  tensor(0.5681, device='cuda:0')      0.708333
# 3           0.474563  tensor(0.5331, device='cuda:0')      0.728175
# 4           0.437940  tensor(0.5411, device='cuda:0')      0.738095
#
#        Valid. F1 macro Training Time Validation Time
# epoch
# 1             0.658738       0:04:02         0:00:08
# 2             0.661794       0:04:02         0:00:08
# 3             0.706073       0:04:02         0:00:08
# 4             0.713555       0:04:02         0:00:08

# %%
description = """Pretrained model with gpt2 checkpoint (12 layers). Trained 4 epochs with a batch size of 16 and using AdamW optimizer with lr=2e-5 and eps=1e-8.
Hastags, users and links have been replaced with a word from input text, followed by the same procedure as in method direct_replacement()."""

save_results(y_pred_train_english_gpt2, english_train.index, "GPT2 base", "hateval2019/task1", "english", dataset_types.train, group="deep_learning", filename="gpt2", description=description)
save_results(y_pred_dev_english_gpt2, english_dev.index, "GPT2 base", "hateval2019/task1", "english", dataset_types.development, group="deep_learning", filename="gpt2", description=description)
save_results(y_pred_test_english_gpt2, english_test.index, "GPT2 base", "hateval2019/task1", "english", dataset_types.test, group="deep_learning", filename="gpt2", description=description)
# Out:
# Results saved on: ./results/hateval2019/task1/english/train/deep_learning/gpt2.pkl
# Results saved on: ./results/hateval2019/task1/english/development/deep_learning/gpt2.pkl
# Results saved on: ./results/hateval2019/task1/english/test/deep_learning/gpt2.pkl

# %% [markdown]
# # Atalaya

# %%
X_train_english_nn = preprocessing_nn(english_train.text)
X_dev_english_nn = preprocessing_nn(english_dev.text)
X_test_english_nn = preprocessing_nn(english_test.text)

X_train_spanish_nn = preprocessing_nn(spanish_train.text)
X_dev_spanish_nn = preprocessing_nn(spanish_dev.text)
X_test_spanish_nn = preprocessing_nn(spanish_test.text)

# %%
import tensorflow_hub as hub
import tensorflow as tf

elmo = hub.Module("https://tfhub.dev/google/elmo/3", trainable=True)

def ELMoEmbedding(input_text):
    return elmo(tf.reshape(tf.cast(input_text, tf.string), [-1]), signature="default", as_dict=True)["elmo"]

# %%
from tensorflow.keras.layers import Input, Lambda, Bidirectional, Dense, Dropout, LSTM, Concatenate
from tensorflow.keras.models import Model

def build_model():
    # biLSTM-ELMo
    input_layer_elmo = Input(shape=(1,), dtype="string")
    embedding_layer = Lambda(ELMoEmbedding, output_shape=(1024, ), name="Elmo_Embedding")(input_layer_elmo)
    BiLSTM = Bidirectional(LSTM(128, recurrent_dropout=0.2, dropout=0.2), name="BiLSTM")(embedding_layer)
    Dense_layer_1 = Dense(64, activation='relu')(BiLSTM)
    Dropout_layer_1 = Dropout(0.45)(Dense_layer_1)
    
    # BoW
    input_layer_bow = Input(shape=(3500,), dtype=np.float32)
    Dense_layer_2 = Dense(512, activation='relu')(input_layer_bow)
    Dropout_layer_2 = Dropout(0.2)(Dense_layer_2)
    Dense_layer_3 = Dense(64, activation='relu')(Dropout_layer_2)
    Dropout_layer_3 = Dropout(0.45)(Dense_layer_3)
    
    concatenate_layer = Concatenate()([Dropout_layer_1, Dropout_layer_3])
    output_layer = Dense(1, activation='sigmoid')(concatenate_layer)
    
    model = Model(inputs=[input_layer_elmo, input_layer_bow], outputs=output_layer, name="Atalaya")
    model.summary()
    
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=False), optimizer=tf.keras.optimizers.Adam(learning_rate=35e-5, decay=0.01), metrics=['accuracy'])
    return model

# %%
from tensorflow.python.keras import backend as K
import random

def train_atalaya(model, train_nn, dev_nn, test_nn,
                  train_bow, dev_bow, test_bow,
                  train_y, dev_y, test_y, lenguage):

    with tf.Session() as session:
        K.set_session(session)
        session.run(tf.global_variables_initializer()) 
        session.run(tf.tables_initializer())

        random.seed(seed_val)
        np.random.seed(seed_val)
        tf.random.set_random_seed(seed_val)

        early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5)
        model_checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("./models/atalaya_"+ lenguage +".h5", save_best_only=True)
        callbacks = [early_stopping_cb, model_checkpoint_cb]


        model_elmo_history = model.fit([train_nn, train_bow], train_y, epochs=25,
                                                shuffle=True, batch_size=64, validation_data=([dev_nn, dev_bow], dev_y),
                                                callbacks = callbacks)

        train_prediction = model.predict([train_nn, train_bow]) >= 0.5
        dev_prediction = model.predict([dev_nn, dev_bow]) >= 0.5
        test_prediction = model.predict([test_nn, test_bow]) >= 0.5

        print_score(train_y, train_prediction, "Atalya Train")
        print_score(dev_y, dev_prediction, "Atalya Dev")
        print_score(test_y, test_prediction, "Atalya Test")
        
    return model_elmo_history, train_prediction, dev_prediction, test_prediction

# %%
def graph_model_history(model_history):

    accuracy = model_history.history['acc']
    val_accuracy = model_history.history['val_acc']
    loss = model_history.history['loss']
    val_loss = model_history.history['val_loss']

    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'r', label='Training accuracy')
    plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.figure()
    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %%
english_model = build_model()

model_elmo_history_english, train_prediction_english, dev_prediction_english, test_prediction_english = train_atalaya(english_model, X_train_english_nn, X_dev_english_nn, X_test_english_nn,
                                                                                                                      X_train_english, X_dev_english, X_test_english,
                                                                                                                      english_train["HS"], english_dev["HS"], english_test["HS"], "english")

graph_model_history(model_elmo_history_english)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# Model: "Atalaya"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 3500)]       0
# __________________________________________________________________________________________________
# Elmo_Embedding (Lambda)         (None, None, 1024)   0           input_11[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 512)          1792512     input_12[0][0]
# __________________________________________________________________________________________________
# BiLSTM (Bidirectional)          (None, 256)          1180672     Elmo_Embedding[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 512)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 64)           16448       BiLSTM[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 64)           32832       dropout_16[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64)           0           dense_20[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64)           0           dense_22[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128)          0           dropout_15[0][0]
#                                                                  dropout_17[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1)            129         concatenate_5[0][0]
# ==================================================================================================
# Total params: 3,022,593
# Trainable params: 3,022,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/25
# 9000/9000 [==============================] - 62s 7ms/sample - loss: 0.6155 - acc: 0.6491 - val_loss: 0.5879 - val_acc: 0.6710
# Epoch 2/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.5199 - acc: 0.7466 - val_loss: 0.5467 - val_acc: 0.7060
# Epoch 3/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.4642 - acc: 0.7861 - val_loss: 0.5307 - val_acc: 0.7260
# Epoch 4/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.4190 - acc: 0.8174 - val_loss: 0.5155 - val_acc: 0.7440
# Epoch 5/25
# 9000/9000 [==============================] - 58s 6ms/sample - loss: 0.3915 - acc: 0.8389 - val_loss: 0.5142 - val_acc: 0.7400
# Epoch 6/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3702 - acc: 0.8478 - val_loss: 0.5131 - val_acc: 0.7500
# Epoch 7/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3498 - acc: 0.8587 - val_loss: 0.5134 - val_acc: 0.7460
# Epoch 8/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3419 - acc: 0.8607 - val_loss: 0.5126 - val_acc: 0.7420
# Epoch 9/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3243 - acc: 0.8712 - val_loss: 0.5200 - val_acc: 0.7420
# Epoch 10/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3173 - acc: 0.8772 - val_loss: 0.5164 - val_acc: 0.7390
# Epoch 11/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3093 - acc: 0.8793 - val_loss: 0.5222 - val_acc: 0.7410
# Epoch 12/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.3027 - acc: 0.8861 - val_loss: 0.5276 - val_acc: 0.7400
# Epoch 13/25
# 9000/9000 [==============================] - 57s 6ms/sample - loss: 0.2933 - acc: 0.8852 - val_loss: 0.5257 - val_acc: 0.7430
# Atalya Train
#
# Accuracy:  0.9038888888888889
# F1 macro:  0.9015782362817413
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      5217
#            1       0.88      0.89      0.89      3783
#
#     accuracy                           0.90      9000
#    macro avg       0.90      0.90      0.90      9000
# weighted avg       0.90      0.90      0.90      9000
#
# Atalya Dev
#
# Accuracy:  0.743
# F1 macro:  0.7400235293879628
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77       573
#            1       0.68      0.74      0.71       427
#
#     accuracy                           0.74      1000
#    macro avg       0.74      0.74      0.74      1000
# weighted avg       0.75      0.74      0.74      1000
#
# Atalya Test
#
# Accuracy:  0.508
# F1 macro:  0.4707390911055481
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.21      0.33      1740
#            1       0.46      0.92      0.61      1260
#
#     accuracy                           0.51      3000
#    macro avg       0.62      0.56      0.47      3000
# weighted avg       0.65      0.51      0.45      3000

# %%
import pickle5 as pickle

# Replacament of module pickle for pickle5, to allow python < 3.8.3 to run.
pd.io.pickle.pickle = pickle

description = """Reproduction of architecture that the Atalaya. Following the architecture of two inputs:
- Input text is converted into Elmo embeding, followed by a BiLSTM with dropout and a layer composed of a dense and a dropout sublayer.
- BoW embeding, followed by two layers of a dense and a dropout sublayer.
All model architectural and optimizer parameters are the same as the specified on the paper."""

save_results(train_prediction_english[:,0], english_train.index, "Atalaya", "hateval2019/task1", "english", dataset_types.train, group="deep_learning", filename="atalaya", description=description)
save_results(dev_prediction_english[:,0], english_dev.index, "Atalaya", "hateval2019/task1", "english", dataset_types.development, group="deep_learning", filename="atalaya", description=description)
save_results(test_prediction_english[:,0], english_test.index, "Atalaya", "hateval2019/task1", "english", dataset_types.test, group="deep_learning", filename="atalaya", description=description)
# Out:
# Results saved on: ./results/hateval2019/task1/english/train/deep_learning/atalaya.pkl
# Results saved on: ./results/hateval2019/task1/english/development/deep_learning/atalaya.pkl
# Results saved on: ./results/hateval2019/task1/english/test/deep_learning/atalaya.pkl

# %%
spanish_model = build_model()

model_elmo_history_spanish, train_prediction_spanish, dev_prediction_spanish, test_prediction_spanish = train_atalaya(spanish_model, X_train_spanish_nn, X_dev_spanish_nn, X_test_spanish_nn,
                                                                                      X_train_spanish, X_dev_spanish, X_test_spanish,
                                                                                      spanish_train["HS"], spanish_dev["HS"], spanish_test["HS"], "spanish")

graph_model_history(model_elmo_history_spanish)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# Model: "Atalaya"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 3500)]       0
# __________________________________________________________________________________________________
# Elmo_Embedding (Lambda)         (None, None, 1024)   0           input_13[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 512)          1792512     input_14[0][0]
# __________________________________________________________________________________________________
# BiLSTM (Bidirectional)          (None, 256)          1180672     Elmo_Embedding[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 512)          0           dense_25[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 64)           16448       BiLSTM[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 64)           32832       dropout_19[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64)           0           dense_24[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64)           0           dense_26[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128)          0           dropout_18[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            129         concatenate_6[0][0]
# ==================================================================================================
# Total params: 3,022,593
# Trainable params: 3,022,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 4500 samples, validate on 500 samples
# Epoch 1/25
# 4500/4500 [==============================] - 37s 8ms/sample - loss: 0.6684 - acc: 0.6109 - val_loss: 0.6512 - val_acc: 0.6160
# Epoch 2/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.6235 - acc: 0.6724 - val_loss: 0.6093 - val_acc: 0.6660
# Epoch 3/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.5545 - acc: 0.7276 - val_loss: 0.5657 - val_acc: 0.7060
# Epoch 4/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.4878 - acc: 0.7924 - val_loss: 0.5311 - val_acc: 0.7260
# Epoch 5/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.4276 - acc: 0.8396 - val_loss: 0.5062 - val_acc: 0.7420
# Epoch 6/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.3796 - acc: 0.8682 - val_loss: 0.4923 - val_acc: 0.7460
# Epoch 7/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.3431 - acc: 0.8880 - val_loss: 0.4852 - val_acc: 0.7460
# Epoch 8/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.3152 - acc: 0.8993 - val_loss: 0.4825 - val_acc: 0.7520
# Epoch 9/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.2937 - acc: 0.9096 - val_loss: 0.4810 - val_acc: 0.7560
# Epoch 10/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.2770 - acc: 0.9149 - val_loss: 0.4819 - val_acc: 0.7520
# Epoch 11/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.2613 - acc: 0.9218 - val_loss: 0.4837 - val_acc: 0.7460
# Epoch 12/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.2468 - acc: 0.9269 - val_loss: 0.4876 - val_acc: 0.7480
# Epoch 13/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.2392 - acc: 0.9289 - val_loss: 0.4910 - val_acc: 0.7540
# Epoch 14/25
# 4500/4500 [==============================] - 31s 7ms/sample - loss: 0.2280 - acc: 0.9320 - val_loss: 0.4937 - val_acc: 0.7420
# Atalya Train
#
# Accuracy:  0.948
# F1 macro:  0.9465627517716503
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      2643
#            1       0.93      0.95      0.94      1857
#
#     accuracy                           0.95      4500
#    macro avg       0.95      0.95      0.95      4500
# weighted avg       0.95      0.95      0.95      4500
#
# Atalya Dev
#
# Accuracy:  0.742
# F1 macro:  0.7396999891037204
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.75      0.76       278
#            1       0.70      0.73      0.72       222
#
#     accuracy                           0.74       500
#    macro avg       0.74      0.74      0.74       500
# weighted avg       0.74      0.74      0.74       500
#
# Atalya Test
#
# Accuracy:  0.71125
# F1 macro:  0.7082592009648918
#
# Classification Report
# ======================================================
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.69      0.74       940
#            1       0.63      0.74      0.68       660
#
#     accuracy                           0.71      1600
#    macro avg       0.71      0.72      0.71      1600
# weighted avg       0.72      0.71      0.71      1600

# %%
import pickle5 as pickle

# Replacament of module pickle for pickle5, to allow python < 3.8.3 to run.
pd.io.pickle.pickle = pickle

description = """Reproduction of architecture that the Atalaya. Following the architecture of two inputs:
- Input text is converted into Elmo embeding, followed by a BiLSTM with dropout and a layer composed of a dense and a dropout sublayer.
- BoW embeding, followed by two layers of a dense and a dropout sublayer.
All model architectural and optimizer parameters are the same as the specified on the paper."""

save_results(train_prediction_spanish[:,0], spanish_train.index, "Atalaya", "hateval2019/task1", "spanish", dataset_types.train, group="deep_learning", filename="atalaya", description=description)
save_results(dev_prediction_spanish[:,0], spanish_dev.index, "Atalaya", "hateval2019/task1", "spanish", dataset_types.development, group="deep_learning", filename="atalaya", description=description)
save_results(test_prediction_spanish[:,0], spanish_test.index, "Atalaya", "hateval2019/task1", "spanish", dataset_types.test, group="deep_learning", filename="atalaya", description=description)
# Out:
# Results saved on: ./results/hateval2019/task1/spanish/train/deep_learning/atalaya.pkl
# Results saved on: ./results/hateval2019/task1/spanish/development/deep_learning/atalaya.pkl
# Results saved on: ./results/hateval2019/task1/spanish/test/deep_learning/atalaya.pkl
